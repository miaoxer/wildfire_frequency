# %% [markdown]
# ## ML for Predicting Wildfire Frequency per Month

# %%
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
import matplotlib.dates as mdates
from matplotlib.transforms import ScaledTranslation
import seaborn as sns
from scipy.stats import spearmanr

from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import TimeSeriesSplit
from sklearn.pipeline import Pipeline
from sklearn.model_selection import train_test_split

from sklearn.linear_model import LinearRegression
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from xgboost import XGBClassifier
from sklearn.model_selection import GridSearchCV
from sklearn.svm import SVC

from sklearn.metrics import mean_squared_error
from sklearn.metrics import accuracy_score
import random
from sklearn.metrics import make_scorer, recall_score, f1_score, roc_auc_score, average_precision_score, precision_recall_curve, auc

from sklearn.metrics import confusion_matrix
import re
import shap

# %% [markdown]
# #### Reading in the Dataset

# %%
df = pd.read_excel(r"C:\Users\miaox\Desktop\Coding\DATA1030-Fall2024\Independant Project\wildfire_frequency\sheffield_wildfire_and_climate .xlsx")

# %%
print(df.shape)
# Out:
# (537, 8)

# %%
print (df.columns)
# Out:
# Index(['year', 'month', 'tmax_degC', 'tmin_degC', 'airfrost_days',
#        'totalrain_mm', 'totalsun_hours', 'wildfire_quantity'],
#       dtype='object')

# %%
#copy df_original into new df_features ready for feature selection

df_features = df.copy()

# %% [markdown]
# #### Data Exploration

# %%
print(df.describe(include='all'))
# Out:
#               year       month   tmax_degC   tmin_degC  airfrost_days  \
# count   537.000000  537.000000  537.000000  537.000000     537.000000
# mean   1998.122905    6.525140   13.458845    6.690689       2.573557
# std      12.930634    3.447882    5.418308    4.075769       4.408130
# min    1976.000000    1.000000    1.000000   -3.000000       0.000000
# 25%    1987.000000    4.000000    8.900000    3.400000       0.000000
# 50%    1998.000000    7.000000   13.200000    6.100000       0.000000
# 75%    2009.000000   10.000000   18.400000   10.400000       3.000000
# max    2020.000000   12.000000   25.600000   14.500000      25.000000
#
#        totalrain_mm  totalsun_hours  wildfire_quantity
# count    537.000000      537.000000         537.000000
# mean      69.839665      119.700559           0.417132
# std       41.721892       62.933924           1.234276
# min        4.600000        5.800000           0.000000
# 25%       41.200000       60.300000           0.000000
# 50%       61.200000      116.100000           0.000000
# 75%       92.400000      171.200000           0.000000
# max      285.600000      290.800000          15.000000

# %%
#plot of wildfire quantity by year
wildfire_per_year = df.groupby('year')['wildfire_quantity'].sum().reset_index()

# wildfire_per_year column
wildfire_per_year.columns = ['Year', 'Wildfire Count']

# bar plot using the 'wildfire_per_year' DataFrame
plt.figure(figsize=(12, 5), dpi=100)
plt.bar(wildfire_per_year['Year'], wildfire_per_year['Wildfire Count'], color='indianred', edgecolor='black', zorder=2)

plt.xlabel('Year')
plt.ylabel('Wildfire Frequency')
plt.title('Yearly Wildfire Frequency (1976-2020)')
plt.xticks(np.arange(min(wildfire_per_year['Year']), max(wildfire_per_year['Year']) + 1, 2), rotation=45, fontsize=8)
plt.yticks(np.arange(0, 31, 2), fontsize=8)
plt.xlim(1975, 2021)
plt.ylim(0, 28)
plt.grid(axis='y', color='gray', linewidth=0.7, alpha=0.2, zorder=0)
plt.figtext(0.1, -0.05, 'Figure 1: Wildfire frequency per year from 1976-2020',
            wrap=True, fontsize=13)

plt.show()

# %%
#fix 'year_month' format to "YYYY-MM" using string formatting
df['year_month'] = df['year'].astype(str) + '-' + df['month'].apply(lambda x: f'{x:02}')

#convert to datetime
df['year_month'] = pd.to_datetime(df['year_month'], format='%Y-%m')

x = df['year_month']  # X-axis: datetime representation of 'year_month'
y1 = df['tmax_degC']  # Y-axis 1: 'totalrain_mm'
y2 = df['tmin_degC']  # Y-axis 2: 'totalrain_mm_avg4'

#create the plot
plt.figure(figsize=(12, 6))

#plot lines
plt.plot(x, y1, color='lightcoral', label='Maximum', linewidth=2, alpha=0.5, zorder=1)
plt.plot(x, y2, color='skyblue', label='Minimum', linewidth=2, alpha=0.5, zorder=1)

x_as_int = x.astype(np.int64)  # Convert datetime to int64 (nanoseconds since epoch)

#linear fit for Maximum temperature
z1 = np.polyfit(x_as_int, y1, 1)
p1 = np.polyval(z1, x_as_int)  # Calculate trendline values for Maximum temperature

#linear fit for Minimum temperature
z2 = np.polyfit(x_as_int, y2, 1)
p2 = np.polyval(z2, x_as_int)  # Calculate trendline values for Minimum temperature

#plot trendlines
plt.plot(x, p1, color='indianred', linestyle='--', linewidth=2, label='Max Trendline', zorder=2)
plt.plot(x, p2, color='steelblue', linestyle='--', linewidth=2, label='Min Trendline', zorder=2)

#set the x-ticks to display only the years
plt.gca().xaxis.set_major_locator(mdates.YearLocator(2))  # Set major ticks to years
plt.gca().xaxis.set_major_formatter(mdates.DateFormatter('%Y'))  # Format ticks as 'YYYY'

#add limits to the x-axis
plt.xlim(pd.Timestamp('1976-01-01'), pd.Timestamp('2020-12-31'))
plt.ylim(-5,30)

#adding labels, title, and legend
plt.xlabel('Year', fontsize=12)
plt.ylabel('Mean Monthly Temperature (C)', fontsize=12)
plt.title('Mean Monthly Minimum and Maximum Temperature between 1976-2020', fontsize=16)
plt.legend()
plt.grid(True, zorder=0, alpha=0.2)

#format the x-axis labels for better visibility
offset = ScaledTranslation(0/72, 0, plt.gcf().dpi_scale_trans)  # Adjust 10/72 as needed
for label in plt.gca().get_xticklabels():
    label.set_transform(label.get_transform() + offset)

plt.figtext(0.02, -0.05, 'Figure 2: Mean monthly maximum and minimum temperatures from 1976 to 2020, including trendlines',
            wrap=True, fontsize=13)

plt.tight_layout()
plt.show()

# %%
#spearman correlation between temperature and year
corr, p_value = spearmanr(df['tmax_degC'], df['year'])
corr, p_value = spearmanr(df['tmin_degC'], df['year'])

print(f"Spearman Correlation Coefficient (tmax_degC): {corr}")
print(f"P-value: {p_value}")

print(f"Spearman Correlation Coefficient (tmin_degC): {corr}")
print(f"P-value: {p_value}")
# Out:
# Spearman Correlation Coefficient (tmax_degC): 0.0827896989668909
# P-value: 0.05519612507771546
# Spearman Correlation Coefficient (tmin_degC): 0.0827896989668909
# P-value: 0.05519612507771546

# %%
#mean annual summer maximum temperature against wildfire quantity

#combine year and month into datetime column
df['date'] = pd.to_datetime(df[['year', 'month']].assign(day=1))

summer_df = df[df['month'].isin([4, 5, 6, 7, 8, 9])]

average_summer_temp = summer_df.groupby('year')['tmax_degC'].mean().reset_index()
average_summer_temp.columns = ['year', 'avg_summer_temp_degC']

#merge the new average summer temperature data with the original DataFrame, specifying suffixes
df = df.merge(average_summer_temp, on='year', suffixes=('', '_avg_summer'))

#plotting

fig, ax1 = plt.subplots(figsize=(12, 6))

#plot avg_summer_temp_degC on the left y-axis
line1, = ax1.plot(average_summer_temp['year'], average_summer_temp['avg_summer_temp_degC'], label='Avg Summer Temp (°C)', color='salmon')
ax1.set_ylabel('Mean Annual Summer Temp (°C)')
ax1.tick_params(axis='y')

#create a second y-axis for wildfire quantity
ax2 = ax1.twinx()
line2, = ax2.plot(df['year'].unique(), df.groupby('year')['wildfire_quantity'].sum(), label='Wildfire Frequency', color='dimgray', marker='o')
ax2.set_ylabel('Wildfire Frequency')
ax2.tick_params(axis='y')

ax1.set_xlabel('Year')

#adding labels and title
plt.title('Mean Annual Summer Maximum Temperature and Wildfire Quantity Over Time')
ax1.grid(color='grey', alpha=0.2)

#combine legends
lines = [line1, line2]
labels = [line.get_label() for line in lines]
ax1.legend(lines, labels, loc='upper left', bbox_to_anchor=(0.05, 0.95))

plt.xticks(np.arange(1976, 2021, 2), rotation=45)
plt.xlim(1976,2020)
plt.xlabel('Year')

plt.figtext(0.02, -0.05, 'Figure 3: Mean annual summer maximum temperature (mean monthly maximum temperatures averaged per year for the months April-September) against total annual wildfire quantity between 1976-2020',
            wrap=True, fontsize=13)

plt.tight_layout()
plt.show()

# %%
#mean annual summer maximum temperature against mean annual summer total rain and wildfire quanity

#combine year and month into a single datetime column
df['date'] = pd.to_datetime(df[['year', 'month']].assign(day=1))

#filter for summer months (April to September)
summer_df = df[df['month'].isin([4, 5, 6, 7, 8, 9])]

#calculate average summer temperature and rainfall
average_summer_temp = summer_df.groupby('year')['tmax_degC'].mean().reset_index()
average_summer_temp.columns = ['year', 'avg_summer_temp_degC']

average_summer_rain = summer_df.groupby('year')['totalrain_mm'].mean().reset_index()
average_summer_rain.columns = ['year', 'avg_summer_rain_mm']

#merge average summer temperature data with the original DataFrame
df = df.merge(average_summer_temp, on='year', suffixes=('', '_avg_summer'))

#create the plot
fig, ax1 = plt.subplots(figsize=(12, 6))

#plot avg_summer_temp_degC on the left y-axis
line1, = ax1.plot(average_summer_temp['year'], average_summer_temp['avg_summer_temp_degC'], label='Avg Summer Temp (°C)', color='salmon', linewidth=3)
ax1.set_ylabel('Average Summer Maximum Temperature (°C)')
ax1.tick_params(axis='y')
ax1.set_ylim(12, 22)  # Set the y-axis limits for average summer temperature

#create a second y-axis for rainfall
ax2 = ax1.twinx()
line2, = ax2.plot(average_summer_rain['year'], average_summer_rain['avg_summer_rain_mm'], label='Avg Summer Rain (mm)', color='skyblue', linewidth=3, linestyle='--')
ax2.set_ylabel('Average Summer Total Rainfall (mm)')
ax2.tick_params(axis='y')
ax2.set_ylim(10, 130)  # Set the y-axis limits for average summer rainfall

#create a third y-axis for wildfire frequency on the left
ax3 = ax1.twinx()
ax3.spines['right'].set_position(('outward', 60))  # Move the right spine outward

#bar plot for wildfire frequency
bar_width = 0.4  # Adjust the width of the bars
x_positions = df['year'].unique()  # x positions for the bars
wildfire_frequencies = df.groupby('year')['wildfire_quantity'].sum()  # Summing wildfire frequencies per year
bars = ax3.bar(x_positions, wildfire_frequencies, width=bar_width, color='dimgray', alpha=0.9, label='Annual Wildfire Frequency')

ax3.set_ylabel('Annual Wildfire Frequency')
ax3.tick_params(axis='y')
ax1.set_xlabel('Year')
plt.title('Mean Annual Summer Maximum Temperature and Mean Summer Total Rainfall \nagainst Annual Wildfire Frequency Over Time', pad=10, fontsize=13)
ax1.grid(color='grey', alpha=0.2)

#combine legends for temperature, rainfall, and wildfire frequency
lines = [line1, line2]
labels = [line.get_label() for line in lines]
bars_label = bars.get_label()

#add the bar label and combine with the lines
lines.append(bars)
labels.append(bars_label)

#add a single legend combining all elements
ax1.legend(lines, labels, loc='upper left', bbox_to_anchor=(0.05, 0.95))

#set the x-axis limits and ticks
plt.xticks(np.arange(1976, 2021, 2), rotation=45)
plt.xlim(1975.5, 2020.5)

plt.figtext(0.02, -0.05, 'Figure 4: Mean annual summer maximum temperature (mean monthly maximum temperatures averaged per year for the months April-September) against total annual wildfire frequency between 1976-2020',
            wrap=True, fontsize=13)

plt.tight_layout()
plt.show()

# %%
#spearman correlatrion between Mean annual summer maximum temperature, total rainfall, and wildfire quanity

# group wildfire frequencies per year
wildfire_frequencies = df.groupby('year')['wildfire_quantity'].sum().reset_index()
wildfire_frequencies.columns = ['year', 'wildfire_frequency']

# merge average summer temperature, rainfall, and wildfire frequency data
merged_df = average_summer_temp.merge(average_summer_rain, on='year').merge(wildfire_frequencies, on='year')

variables = merged_df[['avg_summer_temp_degC', 'avg_summer_rain_mm', 'wildfire_frequency']]

# compute Spearman correlation matrix and p-value matrix
corr_matrix, p_value_matrix = spearmanr(variables, axis=0)

# convert to df 
corr_df = pd.DataFrame(corr_matrix, index=variables.columns, columns=variables.columns)
p_value_df = pd.DataFrame(p_value_matrix, index=variables.columns, columns=variables.columns)

# extract upper triangular part of the matrices, excluding the diagonal
mask = np.triu(np.ones(corr_df.shape), k=1).astype(bool)
results = pd.DataFrame({
    'Variable 1': np.repeat(corr_df.columns, len(corr_df.index))[mask.ravel()],
    'Variable 2': np.tile(corr_df.columns, len(corr_df.columns))[mask.ravel()],
    'Spearman Correlation': corr_df.values[mask],
    'p-value': p_value_df.values[mask]
})

print(results)
# Out:
#              Variable 1          Variable 2  Spearman Correlation   p-value
# 0  avg_summer_temp_degC  avg_summer_rain_mm             -0.270892  0.071880
# 1  avg_summer_temp_degC  wildfire_frequency              0.640447  0.000002
# 2    avg_summer_rain_mm  wildfire_frequency             -0.182238  0.230858

# %%
#boxplot of wildfire quantity count against mean maximum temperature

# filter df to include rows where wildfire_quantity is between 0 and 7 or equal to 15
filtered_df = df[(df['wildfire_quantity'] >= 0) & (df['wildfire_quantity'] <= 7)]

plt.figure(figsize=(10, 6))
sns.boxplot(
    x='wildfire_quantity', 
    y='tmax_degC', 
    data=filtered_df, 
    boxprops=dict(facecolor='salmon', edgecolor='black', alpha=0.5),  # Set box color and outline
    medianprops=dict(color='black'),  
    width=0.5,  
    zorder=3,
    showfliers=False  # do not circle outliers in display
)

# create scatter plot underneath
sns.scatterplot(
    x='wildfire_quantity', 
    y='tmax_degC', 
    data=filtered_df, 
    color='dimgray', 
    alpha=0.6, 
    zorder=1,
    marker='X',
    edgecolor=None,
)

plt.yticks(np.arange(-2, 30, 2))
plt.grid(True, color='lightgray', zorder=0)
plt.grid(axis='y')
plt.xlabel('Wildfire Frequency (per month)')
plt.ylabel('Mean Monthly Max Temp (°C)')
plt.title('Wildfire Frequency and Mean Maximum Temperature')
plt.figtext(0.02, -0.02, 'Figure 3: Box plot showing distribution of mean monthly maximum temperature (C) by wildfire frequency 0-7')

plt.tight_layout()
plt.show()

# %% [markdown]
# #### Generating Features

# %%
#Generating 'year_month' feature 

df_features['year_month'] = df_features['year'].astype(str) + '_' + df_features['month'].astype(str).str.zfill(2)

# %%
#1, 6 & 12-month lag features for tmax & totalrain 

variables = ['tmax_degC', 'totalrain_mm']
lags = [1, 6, 12]

for var in variables:
    for lag in lags:
        df_features[f'{var}_lag_{lag}'] = df_features[var].shift(lag)

# %%
#creating 4-month rolling average lag feature for rain_mm & tmax_degc
#shifted by 1 month, therefore 4 previous months 
#(as we will never know average of current month untill it's over)
#min_periods=1 included to generate an initial average even if the previous 4 months aren't available
#this means month 2 1976 will be month 1, month 3 will be month 1+2/2 etc. 

df_features['totalrain_mm_avg4'] = df_features['totalrain_mm'].shift(1).rolling(window=4, min_periods=1).mean()
df_features['tmax_degC_avg4'] = df_features['tmax_degC'].shift(1).rolling(window=4, min_periods=1).mean()

#confirm rolling average is calculated correctly
print(df_features[['totalrain_mm', 'totalrain_mm_avg4']].head(10))
# Out:
#    totalrain_mm  totalrain_mm_avg4
# 0          16.2                NaN
# 1          79.9          16.200000
# 2          16.6          48.050000
# 3          16.9          37.566667
# 4          17.3          32.400000
# 5         134.9          32.675000
# 6         127.7          46.425000
# 7          32.4          74.200000
# 8          75.3          78.075000
# 9         113.8          92.575000

# %%
#generatig month_sin & month_cos to refelct seasonal variation

#convert 'year_month' to datetime and extract 'year' and 'month' features
df_features['year_month_dt'] = pd.to_datetime(df_features['year_month'], format='%Y_%m')
df_features['year'] = df_features['year_month_dt'].dt.year
df_features['month'] = df_features['year_month_dt'].dt.month

#feature 'month_sin' and 'month_cos'
df_features['month_sin'] = np.sin(2 * np.pi * df_features['month'] / 12)
df_features['month_cos'] = np.cos(2 * np.pi * df_features['month'] / 12)

#verify features
print("Final columns:")
print(df_features.columns.tolist())  

print(df_features['month_sin'])
# Out:
# Final columns:
# ['year', 'month', 'tmax_degC', 'tmin_degC', 'airfrost_days', 'totalrain_mm', 'totalsun_hours', 'wildfire_frequency', 'year_month', 'tmax_degC_lag_1', 'tmax_degC_lag_6', 'tmax_degC_lag_12', 'totalrain_mm_lag_1', 'totalrain_mm_lag_6', 'totalrain_mm_lag_12', 'totalrain_mm_avg4', 'tmax_degC_avg4', 'year_month_dt', 'month_sin', 'month_cos']
# 0      8.660254e-01
# 1      5.000000e-01
# 2      1.224647e-16
# 3     -5.000000e-01
# 4     -8.660254e-01
#            ...
# 532   -8.660254e-01
# 533   -1.000000e+00
# 534   -8.660254e-01
# 535   -5.000000e-01
# 536   -2.449294e-16
# Name: month_sin, Length: 537, dtype: float64

# %%
#optional plottig of month_sin & month_cos

#plt.plot(df_features.index, df_features['month_sin'], label='Month Sin', color='blue', alpha=0.7)
#plt.plot(df_features.index, df_features['month_cos'], label='Month Cos', color='orange', alpha=0.7)

#plt.title('Month Sin and Month Cos Transformations', fontsize=16)
#plt.xlabel('Year', fontsize=14)
#plt.ylabel('Transformed Values', fontsize=14)
#plt.legend()
#plt.grid()
#plt.show()

# %% [markdown]
# #### Feature Selection

# %%
#rename to wildfire_frequency 
df_features.rename(columns={'wildfire_quantity': 'wildfire_frequency'}, inplace=True)

# %%
#print current features in the df_features
print(df_features.columns.tolist())
# Out:
# ['year', 'month', 'tmax_degC', 'tmin_degC', 'airfrost_days', 'totalrain_mm', 'totalsun_hours', 'wildfire_frequency', 'year_month', 'tmax_degC_lag_1', 'tmax_degC_lag_6', 'tmax_degC_lag_12', 'totalrain_mm_lag_1', 'totalrain_mm_lag_6', 'totalrain_mm_lag_12', 'totalrain_mm_avg4', 'tmax_degC_avg4', 'year_month_dt', 'month_sin', 'month_cos']

# %%
#first correlation matrix 

#correlate all features except 'year' & 'month'
#columns_to_correlate = df_features.columns[~df_features.columns.isin(['year', 'month'])]  # Get column names

#spearman correlation coeffifient matrix
corr_matrix = df_features.corr(method='spearman')

#create mask for the upper triangle
mask = np.triu(np.ones_like(corr_matrix, dtype=bool))

plt.figure(figsize=(25, 20))
sns.heatmap(corr_matrix, mask=mask, annot=True, cmap='coolwarm', linewidths=0.5, annot_kws={"size": 15})
plt.title('Correlation Matrix Heatmap', size=25, pad=20)
plt.xticks(size=15, ha='right', rotation=30)  # Slight rotation for readability
plt.yticks(size=15, rotation=0)
plt.figtext(0.01, 0, 'Figure 5: Correlation matrix showing Spearmans correlation p-values between features', size=20)

plt.show()

# %%
#drop features >0.95 correlation score
df_features.drop(columns=['tmin_degC', 'year_month_dt'], inplace=True)

# %%
#confirm new df_features 
print(df_features.columns.tolist())
# Out:
# ['year', 'month', 'tmax_degC', 'airfrost_days', 'totalrain_mm', 'totalsun_hours', 'wildfire_frequency', 'year_month', 'tmax_degC_lag_1', 'tmax_degC_lag_6', 'tmax_degC_lag_12', 'totalrain_mm_lag_1', 'totalrain_mm_lag_6', 'totalrain_mm_lag_12', 'totalrain_mm_avg4', 'tmax_degC_avg4', 'month_sin', 'month_cos']

# %%
#updated cm

corr_matrix = df_features.corr(method='spearman')

#create mask for the upper triangle
mask = np.triu(np.ones_like(corr_matrix, dtype=bool))

plt.figure(figsize=(25, 20))
sns.heatmap(corr_matrix, mask=mask, annot=True, cmap='coolwarm', linewidths=0.5, annot_kws={"size": 15})
plt.title('Correlation Matrix Heatmap', size=25, pad=20)
plt.xticks(size=15, ha='right', rotation=30)  # Slight rotation for readability
plt.yticks(size=15, rotation=0)
plt.figtext(0.01, 0, 'Figure 5: Correlation matrix showing Spearmans correlation p-values between features', size=20)

plt.show()

# %% [markdown]
# #### Missing Data

# %%
#indicating missing values in response to lag features
missing_values = df_features.isnull().sum()
print(missing_values)
# Out:
# year                    0
# month                   0
# tmax_degC               0
# airfrost_days           0
# totalrain_mm            0
# totalsun_hours          0
# wildfire_frequency      0
# year_month              0
# tmax_degC_lag_1         1
# tmax_degC_lag_6         6
# tmax_degC_lag_12       12
# totalrain_mm_lag_1      1
# totalrain_mm_lag_6      6
# totalrain_mm_lag_12    12
# totalrain_mm_avg4       1
# tmax_degC_avg4          1
# month_sin               0
# month_cos               0
# dtype: int64

# %%
# filter df for date_month 12 months after the start (1977_03) to excluding missing values
df_no_missing_values = df_features[df_features['year_month'] > '1977_03']

# display df_no_missing_values
print(df_no_missing_values)
# Out:
#      year  month  tmax_degC  airfrost_days  totalrain_mm  totalsun_hours  \
# 12   1977      4       10.6              2          45.0           179.3
# 13   1977      5       14.6              0          43.5           207.6
# 14   1977      6       16.4              0          66.4           182.0
# 15   1977      7       19.6              0           9.5           178.3
# 16   1977      8       19.4              0          69.2           137.7
# ..    ...    ...        ...            ...           ...             ...
# 532  2020      8       21.2              0         115.2           131.0
# 533  2020      9       18.5              0          25.4           143.5
# 534  2020     10       13.0              0          96.2            52.9
# 535  2020     11       11.0              1          38.6            48.8
# 536  2020     12        7.0              3         126.6            38.9
#
#      wildfire_frequency year_month  tmax_degC_lag_1  tmax_degC_lag_6  \
# 12                    0    1977_04              9.5             13.0
# 13                    7    1977_05             10.6              8.6
# 14                    0    1977_06             14.6              3.7
# 15                    0    1977_07             16.4              4.6
# 16                    0    1977_08             19.6              6.3
# ..                  ...        ...              ...              ...
# 532                   0    2020_08             19.7              8.9
# 533                   0    2020_09             21.2             10.6
# 534                   0    2020_10             18.5             15.6
# 535                   0    2020_11             13.0             18.4
# 536                   0    2020_12             11.0             19.4
#
#      tmax_degC_lag_12  totalrain_mm_lag_1  totalrain_mm_lag_6  \
# 12               11.7                59.7               127.7
# 13               15.8                45.0                32.4
# 14               22.3                43.5                75.3
# 15               24.0                66.4               113.8
# 16               23.0                 9.5               201.4
# ..                ...                 ...                 ...
# 532              22.0                79.4               224.6
# 533              18.1               115.2                43.6
# 534              12.6                25.4                12.4
# 535               7.9                96.2                 5.4
# 536               8.2                38.6                91.0
#
#      totalrain_mm_lag_12  totalrain_mm_avg4  tmax_degC_avg4     month_sin  \
# 12                  16.2            112.550           6.025  8.660254e-01
# 13                  79.9            104.975           7.750  5.000000e-01
# 14                  16.6             87.400          10.250  1.224647e-16
# 15                  16.9             53.650          12.775 -5.000000e-01
# 16                  17.3             41.100          15.300 -8.660254e-01
# ..                   ...                ...             ...           ...
# 532                 64.8             47.050          18.275 -8.660254e-01
# 533                139.2             72.750          19.675 -1.000000e+00
# 534                135.6             77.750          19.700 -8.660254e-01
# 535                200.0             79.050          18.100 -5.000000e-01
# 536                 73.0             68.850          15.925 -2.449294e-16
#
#         month_cos
# 12  -5.000000e-01
# 13  -8.660254e-01
# 14  -1.000000e+00
# 15  -8.660254e-01
# 16  -5.000000e-01
# ..            ...
# 532 -5.000000e-01
# 533 -1.836970e-16
# 534  5.000000e-01
# 535  8.660254e-01
# 536  1.000000e+00
#
# [525 rows x 18 columns]

# %%
#define X & Y

Y = df_no_missing_values['wildfire_frequency']
X = df_no_missing_values.drop(columns=['wildfire_frequency'])

# %%
print(df_no_missing_values.shape)
print(df_no_missing_values['wildfire_frequency'].shape)
# Out:
# (525, 17)
# (525,)

# %%
#check columns ready for data pre-processing
print(X.columns)
# Out:
# Index(['month', 'tmax_degC', 'airfrost_days', 'totalrain_mm', 'totalsun_hours',
#        'year_month', 'tmax_degC_lag_1', 'tmax_degC_lag_6', 'tmax_degC_lag_12',
#        'totalrain_mm_lag_1', 'totalrain_mm_lag_6', 'totalrain_mm_lag_12',
#        'totalrain_mm_avg4', 'tmax_degC_avg4', 'month_sin', 'month_cos'],
#       dtype='object')

# %% [markdown]
# #### Multinomial Logistic Regression

# %%
#categorical y target variable 
Y.value_counts()
# Out:
# wildfire_frequency
# 0    426
# 1     57
# 2     18
# 3      8
# 4      8
# 7      3
# 5      3
# 6      2
# Name: count, dtype: int64

# %%
#logistic regression with GridScearchCV

from sklearn.metrics import f1_score
import random

#set to micro for multiclass problems
#fbeta_scorer = make_scorer(fbeta_score, beta=1, average='micro')

# dictionaries to store preprocessed folds
X_train_folds = {}
X_test_folds = {}
Y_train_folds = {}
Y_test_folds = {}

best_train_score_per_fold = []
best_test_score_per_fold = []

best_models = []
model_params = []

train_scores_per_fold = []
test_scores_per_fold = []

#initialise with small values
best_test_score = -np.inf
best_train_score = -np.inf 

#define parameter grid for GridSearch
param_grid = {
    'model__C': np.logspace(0, 0.02, 5), 
    'model__penalty': ['l2', None],
    'model__solver': ['saga', 'lbfgs', 'newton-cg']
}

# Time series data splitting & preprocessing
for fold_idx, (train_index, test_index) in enumerate(tscv.split(X), start=1):
    # Split the train data
    X_train = X.iloc[train_index]
    Y_train = Y.iloc[train_index]
    X_test = X.iloc[test_index]
    Y_test = Y.iloc[test_index]

    #confirming chronological order of train and test folds
    #print(f"Fold {fold_idx} - Train set (X):")
    #print(X_train.head()) 
    #print(f"Fold {fold_idx} - Test set (X):")
    #print(X_test.head())

    # Save to dictionaries
    X_train_folds[f'train_fold_{fold_idx}'] = X_train
    X_test_folds[f'test_fold_{fold_idx}'] = X_test
    Y_train_folds[f'train_fold_{fold_idx}'] = Y_train
    Y_test_folds[f'test_fold_{fold_idx}'] = Y_test
    
    # initialise StandardScaler and LogisticRegression in pipeline
    pipeline = Pipeline([
        ('scaler', StandardScaler()),  
        ('model', LogisticRegression(multi_class='multinomial', max_iter=1000, tol=1e-4, random_state=1))
    ])

    pipeline.fit(X_train, Y_train)
    
    # GridSearchCV with TimeSeriesSplit for hyperparameter tuning
    grid_search = GridSearchCV(
        estimator=pipeline,
        param_grid=param_grid,
        cv=TimeSeriesSplit(n_splits=5),  # Using time series CV here
        scoring=f1_score,  # Use a metric of your choice
        n_jobs=-1,  # Use all cores for parallel processing
        verbose=1
    )
    
        # handle warnings
    with warnings.catch_warnings():
         warnings.simplefilter("ignore")
         grid_search.fit(X_train, Y_train)
    
    # Best parameters and model
    #best_params = grid_search.best_params_
    best_model = grid_search.best_estimator_
    best_models.append(best_model)
    print(f"Fold {fold_idx} -> Best Params: {best_params}")

    X_train_transformed = best_model.named_steps['scaler'].transform(X_train)
    X_test_transformed = best_model.named_steps['scaler'].transform(X_test)

    print(f"Preprocessed training set shape (X_train_transformed): {X_train_transformed.shape}")
    print(f"Preprocessed test set shape (X_test_transformed): {X_test_transformed.shape}")

    # predict on train set
    y_train_pred = best_model.predict(X_train)
    train_score = f1_score(Y_train, y_train_pred, average='micro')
    print(f"Fold {fold_idx} -> Train F1 Score: {train_score:.4f}")
    
    # predict on test set
    y_test_pred = best_model.predict(X_test)
    test_score = f1_score(Y_test, y_test_pred, average='micro')
    print(f"Fold {fold_idx} -> Test F1 Score: {test_score:.4f}")

    train_scores_per_fold.append(train_score)
    test_scores_per_fold.append(test_score)
        
    if test_score > best_test_score:
        best_test_score = test_score
        best_train_score = train_score

    model_params.append(grid_search.best_params_)
    #print test & train size to check
    #print(f'Fold {fold_idx} -> Train size: {len(train_index)}, Test size: {test_size}')
    
    # Store results
    best_train_score_per_fold.append(best_train_score)
    best_test_score_per_fold.append(best_test_score)

# df for best models and test scores
results_df = pd.DataFrame({
        'Test Score': best_test_score_per_fold,
        'Model Parameters': model_params
    })

# sort for top 10 best models
sorted_results = results_df.sort_values(by='Test Score').head(10) 
print("\nTop 10 Models and Test Scores:")
print(sorted_results)
# Out:
# Fitting 5 folds for each of 30 candidates, totalling 150 fits
# C:\Users\miaox\.anaconda\envs\data1030\Lib\site-packages\sklearn\linear_model\_logistic.py:1247: FutureWarning: 'multi_class' was deprecated in version 1.5 and will be removed in 1.7. From then on, it will always use 'multinomial'. Leave it to its default value to avoid this warning.
#   warnings.warn(
# Fold 1 -> Best Params: {'model__C': 0.01, 'model__penalty': 'l2', 'model__solver': 'saga'}
# Preprocessed training set shape (X_train_transformed): (90, 16)
# Preprocessed test set shape (X_test_transformed): (87, 16)
# Fold 1 -> Train F1 Score: 0.9667
# Fold 1 -> Test F1 Score: 0.9310
# Fitting 5 folds for each of 30 candidates, totalling 150 fits
# C:\Users\miaox\.anaconda\envs\data1030\Lib\site-packages\sklearn\linear_model\_logistic.py:1247: FutureWarning: 'multi_class' was deprecated in version 1.5 and will be removed in 1.7. From then on, it will always use 'multinomial'. Leave it to its default value to avoid this warning.
#   warnings.warn(
# Fold 2 -> Best Params: {'model__C': 0.01, 'model__penalty': 'l2', 'model__solver': 'saga'}
# Preprocessed training set shape (X_train_transformed): (177, 16)
# Preprocessed test set shape (X_test_transformed): (87, 16)
# Fold 2 -> Train F1 Score: 0.9492
# Fold 2 -> Test F1 Score: 0.7931
# Fitting 5 folds for each of 30 candidates, totalling 150 fits
# C:\Users\miaox\.anaconda\envs\data1030\Lib\site-packages\sklearn\linear_model\_logistic.py:1247: FutureWarning: 'multi_class' was deprecated in version 1.5 and will be removed in 1.7. From then on, it will always use 'multinomial'. Leave it to its default value to avoid this warning.
#   warnings.warn(
# Fold 3 -> Best Params: {'model__C': 0.01, 'model__penalty': 'l2', 'model__solver': 'saga'}
# Preprocessed training set shape (X_train_transformed): (264, 16)
# Preprocessed test set shape (X_test_transformed): (87, 16)
# Fold 3 -> Train F1 Score: 0.9053
# Fold 3 -> Test F1 Score: 0.6552
# Fitting 5 folds for each of 30 candidates, totalling 150 fits
# C:\Users\miaox\.anaconda\envs\data1030\Lib\site-packages\sklearn\linear_model\_logistic.py:1247: FutureWarning: 'multi_class' was deprecated in version 1.5 and will be removed in 1.7. From then on, it will always use 'multinomial'. Leave it to its default value to avoid this warning.
#   warnings.warn(
# Fold 4 -> Best Params: {'model__C': 0.01, 'model__penalty': 'l2', 'model__solver': 'saga'}
# Preprocessed training set shape (X_train_transformed): (351, 16)
# Preprocessed test set shape (X_test_transformed): (87, 16)
# Fold 4 -> Train F1 Score: 0.8604
# Fold 4 -> Test F1 Score: 0.6092
# Fitting 5 folds for each of 30 candidates, totalling 150 fits
# C:\Users\miaox\.anaconda\envs\data1030\Lib\site-packages\sklearn\linear_model\_logistic.py:1247: FutureWarning: 'multi_class' was deprecated in version 1.5 and will be removed in 1.7. From then on, it will always use 'multinomial'. Leave it to its default value to avoid this warning.
#   warnings.warn(
# Fold 5 -> Best Params: {'model__C': 0.01, 'model__penalty': 'l2', 'model__solver': 'saga'}
# Preprocessed training set shape (X_train_transformed): (438, 16)
# Preprocessed test set shape (X_test_transformed): (87, 16)
# Fold 5 -> Train F1 Score: 0.8425
# Fold 5 -> Test F1 Score: 0.5632
#
# Top 10 Models and Test Scores:
#    Test Score                                   Model Parameters
# 0    0.931034  {'model__C': 1.0, 'model__penalty': 'l2', 'mod...
# 1    0.931034  {'model__C': 1.0, 'model__penalty': 'l2', 'mod...
# 2    0.931034  {'model__C': 1.0, 'model__penalty': 'l2', 'mod...
# 3    0.931034  {'model__C': 1.0, 'model__penalty': 'l2', 'mod...
# 4    0.931034  {'model__C': 1.0, 'model__penalty': 'l2', 'mod...

# %%
import matplotlib.pyplot as plt

# Create the plot for F1 scores across folds
plt.figure(figsize=(10, 6))
folds = list(range(1, len(train_scores_per_fold) + 1))  # Fold indices start from 1
plt.plot(folds, train_scores_per_fold, label='Training F1 Score', marker='o', linestyle='-', color='b')
plt.plot(folds, test_scores_per_fold, label='Test F1 Score', marker='o', linestyle='--', color='r')

# Adding labels and title
plt.xlabel('Fold')
plt.ylabel('F1 Score')
plt.title('Training vs Test F1 Score per Fold')
plt.legend()
plt.grid(True)
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import confusion_matrix

print(f"Classes in Y_train: {Y_train.unique()}")
print(f"Classes in Y_test: {Y_test.unique()}")

# actual labels (true classes)
print("True labels:", np.unique(Y_test))

# predicted labels (predicted classes)
print("Predicted labels:", np.unique(y_test_pred))

# define true and predicted labels
true_labels = [0, 1, 2, 3, 4, 5]
predicted_labels = [0, 1, 2]  # Example where 3, 4, and 5 are missing in predictions

# generate confusion matrix
cm = confusion_matrix(Y_test, y_test_pred, labels=true_labels)

sns.heatmap(cm, annot=True, fmt="d", cmap="Blues", xticklabels=true_labels, yticklabels=true_labels)
plt.xlabel("Predicted")
plt.ylabel("Actual")
plt.gca().xaxis.set_label_position('top')
plt.gca().tick_params(axis='x', labeltop=True, bottom=False, top=True) 
#plt.gca().set_xticks([])  # Remove x-ticks on the bottom axis


plt.show()
# Out:
# Classes in Y_train: [0 7 2 5 1 3 4 6]
# Classes in Y_test: [0 2 1 3 5 4]
# True labels: [0 1 2 3 4 5]
# Predicted labels: [0 1 2]

# %% [markdown]
# #### Binary: no wildfire[0], wildfire[1]

# %%
df_features_binary = df_features.copy()

# %%
print(df_features_binary['wildfire_frequency'])
# Out:
# 0       0
# 1       5
# 2       1
# 3      15
# 4       6
#        ..
# 532     0
# 533     0
# 534     0
# 535     0
# 536     0
# Name: wildfire_frequency, Length: 537, dtype: int64

# %%
df_features_binary['wildfire_frequency'] = df_features_binary['wildfire_frequency'].apply(lambda x: 1 if x > 0 else 0)

# %%
#confirm new feature

print(df_features_binary.columns.tolist())
print(df_features_binary['wildfire_frequency'])
# Out:
# ['month', 'tmax_degC', 'airfrost_days', 'totalrain_mm', 'totalsun_hours', 'wildfire_frequency', 'year_month', 'tmax_degC_lag_1', 'tmax_degC_lag_6', 'tmax_degC_lag_12', 'totalrain_mm_lag_1', 'totalrain_mm_lag_6', 'totalrain_mm_lag_12', 'totalrain_mm_avg4', 'tmax_degC_avg4', 'month_sin', 'month_cos']
# 0      0
# 1      1
# 2      1
# 3      1
# 4      1
#       ..
# 532    0
# 533    0
# 534    0
# 535    0
# 536    0
# Name: wildfire_frequency, Length: 537, dtype: int64

# %%
# filter df for date_month 12 months after the start (1977_03) to excluding missing values
df_binary_no_missing_values = df_features_binary[df_features_binary['year_month'] > '1977_03']

# %%
df_binary_no_missing_values = df_binary_no_missing_values.drop(columns=['year_month'])

# %%
# new df with no 12_month lag 
df_binary_no_lag_12 = df_features_binary.drop(columns=['tmax_degC_lag_12', 'totalrain_mm_lag_12'])
df_binary_no_lag_12 = df_binary_no_lag_12[df_binary_no_lag_12['year_month'] > '1976_09']

# alternate df with no lags
df_binary_no_lags = df_features_binary.drop(columns=['tmax_degC_lag_1', 'tmax_degC_lag_6', 'tmax_degC_lag_12', 'totalrain_mm_lag_1', 'totalrain_mm_lag_6', 'totalrain_mm_lag_12'])

# %% [markdown]
# #### Logistic Regression

# %%
#define X & Y

y = df_binary_no_missing_values['wildfire_frequency']
X = df_binary_no_missing_values.drop(columns=['wildfire_frequency'])

# %%
# new logistic regression with validation
# F1 scorer
f1_scorer = make_scorer(f1_score)

# param_grid
param_grid = {
    'model__C': np.logspace(-2, 2, 21), 
    'model__penalty': ['l2', None],
    'model__solver': ['saga', 'sag', 'lbfgs', 'newton-cg']
}

metrics = {
    "Accuracy": accuracy_score,
    "F-beta Score": lambda y_true, y_pred: fbeta_score(y_true, y_pred, beta=1.5),
    "F1 Score": f1_score,
    "Recall": recall_score,
    "Precision": precision_score,
    "ROC AUC": roc_auc_score,
    "PR AUC": lambda y_true, y_pred: compute_pr_auc(y_true, y_pred)
}

tscv = TimeSeriesSplit(n_splits=5)

best_models_logistic_regression = []

class_distributions = {}
logistic_regression_baseline_metrics = {}
logistic_regression_means = {}
logistic_regression_stds = {}

# Function to consistently format metric names
def format_metric_name(metric_name):
    return re.sub(r'[^a-zA-Z0-9]+', '_', metric_name.lower())
    
# initialise scores dictionaries
scores_per_fold = {f"train_{format_metric_name(name)}": [] for name in metrics}
scores_per_fold.update({f"test_{format_metric_name(name)}": [] for name in metrics})
scores_per_fold.update({f"val_{format_metric_name(name)}": [] for name in metrics})  # Add validation scores

# data splitting, model training, & evaluation
for fold_idx, (train_index, test_index) in enumerate(tscv.split(X), start=1):
    # Split data into train and test sets
    X_train = X.iloc[train_index]
    Y_train = Y.iloc[train_index]
    X_test_full = X.iloc[test_index]
    Y_test_full = Y.iloc[test_index]

    # Split the test set into 10% validation and 10% test (chronologically)
    split_point = len(X_test_full) // 2
    X_val = X_test_full.iloc[:split_point]
    Y_val = Y_test_full.iloc[:split_point]
    
    X_test = X_test_full.iloc[split_point:]
    Y_test = Y_test_full.iloc[split_point:]

    print(f"\nFold {fold_idx}:")
    print(f"  Training set: X shape = {X_train.shape}, Y shape = {Y_train.shape}, Size = {X_train.shape[0]}")
    print(f"  Validation set:  X shape = {X_val.shape}, Y shape = {Y_val.shape}, Size = {X_val.shape[0]}")
    print(f"  Testing set:  X shape = {X_test.shape}, Y shape = {Y_test.shape}, Size = {X_test.shape[0]}")
    
    # Count class occurrences in Y_test
    class_counts = Y_test.value_counts()
    total = len(Y_test)
    majority_class = class_counts.idxmax()
    majority_class_count = class_counts.max()
    num_class_1 = class_counts.get(1, 0)
    num_class_0 = class_counts.get(0, 0)
    baseline_probs = [1 if majority_class == 1 else 0] * len(Y_test)
    precision_baseline, recall_baseline, _ = precision_recall_curve(Y_test, baseline_probs)

    # Debugging prints for class distribution
    print(f"\nFold {fold_idx} - Class Distribution in Test Set:")
    print(f"  Total samples: {total}")
    print(f"  Class Counts:\n{class_counts}")
    print(f"  Majority Class: {majority_class}")
    print(f"  Majority Class Count: {majority_class_count}")
    
   # Store class distribution
    class_distributions[fold_idx] = {
        "Class 0": num_class_0,
        "Class 1": num_class_1
    }

    # baseline metrics: predicting all points as class 1
    accuracy = majority_class_count / total
    precision = num_class_1 / (num_class_1 + num_class_0)
    recall = (num_class_1 / total) / (num_class_1/ total + 0)
    f1 = 2 * (precision * recall) / (precision + recall)
    f1_5 = (1 + 1.5**2) * (precision * recall) / ((1.5**2 * precision) + recall)
    roc_auc = roc_auc_score(Y_test, baseline_probs)
    pr_auc = auc(recall_baseline, precision_baseline)

    print("\nBaseline Metric Calculations:")
    print(f"  Accuracy: {accuracy}")
    print(f"  Precision: {precision}")
    print(f"  Recall: {recall}")
    print(f"  F1 Score: {f1}")
    print(f"  F1.5 Score: {f1_5}")
    print(f"  ROC AUC: {roc_auc}")
    print(f"  PR AUC: {pr_auc}")
    
    logistic_regression_baseline_metrics[fold_idx] = {
        "Accuracy": accuracy,
        "Precision": precision,
        "Recall": recall,
        "F1": f1,
        "F1.5": f1_5,
        "ROC AUC": roc_auc,
        "PR AUC": pr_auc
    }
    
    # pipeline
    pipeline = Pipeline([
        ('scaler', StandardScaler()),  
        ('model', LogisticRegression(class_weight='balanced', max_iter=1000, tol=1e-4, random_state=1))
    ])
    
    # GridSearchCV with tscv
    grid_search = GridSearchCV(
        estimator=pipeline,
        param_grid=param_grid,
        cv=tscv,
        scoring=f1_scorer,
        refit=True,  # refit best model on the full training data
        n_jobs=-1,  
        verbose=1
    )
    
    with warnings.catch_warnings():
        warnings.simplefilter("ignore")
        grid_search.fit(X_train, Y_train)
    
    # Use the validation set to select the best model
    best_model_idx = np.argmax([grid_search.score(X_val, Y_val) for model in grid_search.cv_results_['params']])

    # find best parameters using X_train
    best_params = grid_search.best_params_
    best_model_logistic_regression = grid_search.best_estimator_
    print(f"Fold {fold_idx} -> Best Params: {best_params}")

    # Evaluate the best model on the validation set (X_val, Y_val)
    y_val_pred_probs = best_model_logistic_regression.predict_proba(X_val)[:, 1]
    y_val_pred = best_model_logistic_regression.predict(X_val)

    #evalualte on X_train 
    y_train_pred = best_model_logistic_regression.predict(X_train)

    # Evaluate on X_test
    y_test_pred_probs = best_model_logistic_regression.predict_proba(X_test)[:, 1]
    y_test_pred = best_model_logistic_regression.predict(X_test)

    # predict probabilities (needed for PR AUC calculation)
    y_pred_probs = best_model_logistic_regression.predict_proba(X_test)[:, 1]  # Get probabilities for class 1
    
    # calculate PR AUC for the test set
    pr_auc_value = compute_pr_auc(Y_test, y_pred_probs)

    #generate confusion matrix for each fold
    cm = confusion_matrix(Y_test, y_test_pred, labels=[0, 1])
        
    # Plot confusion matrix
    plt.figure(figsize=(6, 5))
    sns.heatmap(cm, annot=True, fmt="d", cmap="Blues", xticklabels=[0, 1], yticklabels=[0, 1])
    plt.xlabel("Predicted")
    plt.ylabel("Actual")
    plt.title(f"Confusion Matrix for Logistic Regression - Fold {fold_idx}")
    plt.show()
    
    #for loop for calculating train & test metrics
    #print(f"Fold {fold_idx} metrics:")
    for name, func in metrics.items():
        formatted_name = format_metric_name(name)
    
        # Train metrics
        train_score = func(Y_train, y_train_pred)
        print(f"  Train {name}: {train_score:.4f}")
        scores_per_fold[f"train_{formatted_name}"].append(train_score)

        # Validation metrics
        val_score = func(Y_val, y_val_pred)
        print(f"  Validation {name}: {val_score:.4f}")
        scores_per_fold[f"val_{formatted_name}"].append(val_score)
        
        # Test metrics
        test_score = func(Y_test, y_test_pred)
        print(f"  Test {name}: {test_score:.4f}")
        scores_per_fold[f"test_{formatted_name}"].append(test_score)

# Calculate and save mean and std metrics
print("\nOverall Metrics:")
for metric_name in metrics:
    formatted_name = format_metric_name(metric_name)
    train_key = f"train_{formatted_name}"
    val_key = f"val_{formatted_name}"
    test_key = f"test_{formatted_name}"
    
    avg_train = np.mean(scores_per_fold[train_key])
    std_train = np.std(scores_per_fold[train_key], ddof=1)
    avg_val = np.mean(scores_per_fold[val_key])
    std_val = np.std(scores_per_fold[val_key], ddof=1)
    avg_test = np.mean(scores_per_fold[test_key])
    std_test = np.std(scores_per_fold[test_key], ddof=1)

    # Save to dictionaries for model comparison
    logistic_regression_means[f"logistic_regression_{formatted_name}_mean"] = {
        "train": avg_train,
        "val": avg_val,
        "test": avg_test
    }
    logistic_regression_stds[f"logistic_regression_{formatted_name}_std"] = {
        "train": std_train,
        "val": std_val,
        "test": std_test
    }
        
    print(f"{metric_name} - Train: Mean = {avg_train:.4f}, Std Dev = {std_train:.4f}")
    print(f"{metric_name} - Validation: Mean = {avg_val:.4f}, Std Dev = {std_val:.4f}")
    print(f"{metric_name} - Test: Mean = {avg_test:.4f}, Std Dev = {std_test:.4f}")

#print baselines at the end for each fold:
print("\nBaseline Metrics per Fold:")
for fold, metrics in logistic_regression_baseline_metrics.items():
    print(f"Fold {fold}: {metrics}")
# Out:
# Fold 1:
#   Training set: X shape = (90, 15), Y shape = (90,), Size = 90
#   Validation set:  X shape = (43, 15), Y shape = (43,), Size = 43
#   Testing set:  X shape = (44, 15), Y shape = (44,), Size = 44
#
# Fold 1 - Class Distribution in Test Set:
#   Total samples: 44
#   Class Counts:
# wildfire_frequency
# 0    39
# 1     5
# Name: count, dtype: int64
#   Majority Class: 0
#   Majority Class Count: 39
#
# Baseline Metric Calculations:
#   Accuracy: 0.8863636363636364
#   Precision: 0.11363636363636363
#   Recall: 1.0
#   F1 Score: 0.20408163265306123
#   F1.5 Score: 0.29411764705882354
#   ROC AUC: 0.5
#   PR AUC: 0.5568181818181818
# Fitting 5 folds for each of 168 candidates, totalling 840 fits
# Fold 1 -> Best Params: {'model__C': 0.1, 'model__penalty': 'l2', 'model__solver': 'saga'}
#   Train Accuracy: 0.8222
#   Validation Accuracy: 0.7674
#   Test Accuracy: 0.6818
#   Train F-beta Score: 0.5871
#   Validation F-beta Score: 0.2453
#   Test F-beta Score: 0.1461
#   Train F1 Score: 0.4667
#   Validation F1 Score: 0.1667
#   Test F1 Score: 0.1250
#   Train Recall: 1.0000
#   Validation Recall: 1.0000
#   Test Recall: 0.2000
#   Train Precision: 0.3043
#   Validation Precision: 0.0909
#   Test Precision: 0.0909
#   Train ROC AUC: 0.9036
#   Validation ROC AUC: 0.8810
#   Test ROC AUC: 0.4718
#   Train PR AUC: 0.6522
#   Validation PR AUC: 0.5455
#   Test PR AUC: 0.1909
#
# Fold 2:
#   Training set: X shape = (177, 15), Y shape = (177,), Size = 177
#   Validation set:  X shape = (43, 15), Y shape = (43,), Size = 43
#   Testing set:  X shape = (44, 15), Y shape = (44,), Size = 44
#
# Fold 2 - Class Distribution in Test Set:
#   Total samples: 44
#   Class Counts:
# wildfire_frequency
# 0    33
# 1    11
# Name: count, dtype: int64
#   Majority Class: 0
#   Majority Class Count: 33
#
# Baseline Metric Calculations:
#   Accuracy: 0.75
#   Precision: 0.25
#   Recall: 1.0
#   F1 Score: 0.4
#   F1.5 Score: 0.52
#   ROC AUC: 0.5
#   PR AUC: 0.625
# Fitting 5 folds for each of 168 candidates, totalling 840 fits
# Fold 2 -> Best Params: {'model__C': 0.15848931924611143, 'model__penalty': 'l2', 'model__solver': 'sag'}
#   Train Accuracy: 0.7966
#   Validation Accuracy: 0.7907
#   Test Accuracy: 0.8182
#   Train F-beta Score: 0.4815
#   Validation F-beta Score: 0.6555
#   Test F-beta Score: 0.6887
#   Train F1 Score: 0.3793
#   Validation F1 Score: 0.5714
#   Test F1 Score: 0.6667
#   Train Recall: 0.8462
#   Validation Recall: 0.8571
#   Test Recall: 0.7273
#   Train Precision: 0.2444
#   Validation Precision: 0.4286
#   Test Precision: 0.6154
#   Train ROC AUC: 0.8194
#   Validation ROC AUC: 0.8175
#   Test ROC AUC: 0.7879
#   Train PR AUC: 0.5509
#   Validation PR AUC: 0.6545
#   Test PR AUC: 0.7054
#
# Fold 3:
#   Training set: X shape = (264, 15), Y shape = (264,), Size = 264
#   Validation set:  X shape = (43, 15), Y shape = (43,), Size = 43
#   Testing set:  X shape = (44, 15), Y shape = (44,), Size = 44
#
# Fold 3 - Class Distribution in Test Set:
#   Total samples: 44
#   Class Counts:
# wildfire_frequency
# 0    34
# 1    10
# Name: count, dtype: int64
#   Majority Class: 0
#   Majority Class Count: 34
#
# Baseline Metric Calculations:
#   Accuracy: 0.7727272727272727
#   Precision: 0.22727272727272727
#   Recall: 1.0
#   F1 Score: 0.37037037037037035
#   F1.5 Score: 0.4887218045112782
#   ROC AUC: 0.5
#   PR AUC: 0.6136363636363636
# Fitting 5 folds for each of 168 candidates, totalling 840 fits
# Fold 3 -> Best Params: {'model__C': 0.6309573444801934, 'model__penalty': 'l2', 'model__solver': 'lbfgs'}
#   Train Accuracy: 0.7652
#   Validation Accuracy: 0.8140
#   Test Accuracy: 0.6818
#   Train F-beta Score: 0.5670
#   Validation F-beta Score: 0.6783
#   Test F-beta Score: 0.5617
#   Train F1 Score: 0.4655
#   Validation F1 Score: 0.6000
#   Test F1 Score: 0.5000
#   Train Recall: 0.8710
#   Validation Recall: 0.8571
#   Test Recall: 0.7000
#   Train Precision: 0.3176
#   Validation Precision: 0.4615
#   Test Precision: 0.3889
#   Train ROC AUC: 0.8110
#   Validation ROC AUC: 0.8313
#   Test ROC AUC: 0.6882
#   Train PR AUC: 0.6019
#   Validation PR AUC: 0.6710
#   Test PR AUC: 0.5785
#
# Fold 4:
#   Training set: X shape = (351, 15), Y shape = (351,), Size = 351
#   Validation set:  X shape = (43, 15), Y shape = (43,), Size = 43
#   Testing set:  X shape = (44, 15), Y shape = (44,), Size = 44
#
# Fold 4 - Class Distribution in Test Set:
#   Total samples: 44
#   Class Counts:
# wildfire_frequency
# 0    32
# 1    12
# Name: count, dtype: int64
#   Majority Class: 0
#   Majority Class Count: 32
#
# Baseline Metric Calculations:
#   Accuracy: 0.7272727272727273
#   Precision: 0.2727272727272727
#   Recall: 1.0
#   F1 Score: 0.42857142857142855
#   F1.5 Score: 0.5492957746478873
#   ROC AUC: 0.5
#   PR AUC: 0.6363636363636364
# Fitting 5 folds for each of 168 candidates, totalling 840 fits
# Fold 4 -> Best Params: {'model__C': 39.810717055349734, 'model__penalty': 'l2', 'model__solver': 'saga'}
#   Train Accuracy: 0.7635
#   Validation Accuracy: 0.7907
#   Test Accuracy: 0.7273
#   Train F-beta Score: 0.5735
#   Validation F-beta Score: 0.6303
#   Test F-beta Score: 0.6047
#   Train F1 Score: 0.4845
#   Validation F1 Score: 0.6400
#   Test F1 Score: 0.5714
#   Train Recall: 0.8125
#   Validation Recall: 0.6154
#   Test Recall: 0.6667
#   Train Precision: 0.3451
#   Validation Precision: 0.6667
#   Test Precision: 0.5000
#   Train ROC AUC: 0.7841
#   Validation ROC AUC: 0.7410
#   Test ROC AUC: 0.7083
#   Train PR AUC: 0.5916
#   Validation PR AUC: 0.6992
#   Test PR AUC: 0.6288
#
# Fold 5:
#   Training set: X shape = (438, 15), Y shape = (438,), Size = 438
#   Validation set:  X shape = (43, 15), Y shape = (43,), Size = 43
#   Testing set:  X shape = (44, 15), Y shape = (44,), Size = 44
#
# Fold 5 - Class Distribution in Test Set:
#   Total samples: 44
#   Class Counts:
# wildfire_frequency
# 0    27
# 1    17
# Name: count, dtype: int64
#   Majority Class: 0
#   Majority Class Count: 27
#
# Baseline Metric Calculations:
#   Accuracy: 0.6136363636363636
#   Precision: 0.38636363636363635
#   Recall: 1.0
#   F1 Score: 0.5573770491803279
#   F1.5 Score: 0.6717325227963526
#   ROC AUC: 0.5
#   PR AUC: 0.6931818181818181
# Fitting 5 folds for each of 168 candidates, totalling 840 fits
# Fold 5 -> Best Params: {'model__C': 1.584893192461114, 'model__penalty': 'l2', 'model__solver': 'saga'}
#   Train Accuracy: 0.7580
#   Validation Accuracy: 0.7442
#   Test Accuracy: 0.6364
#   Train F-beta Score: 0.6018
#   Validation F-beta Score: 0.6797
#   Test F-beta Score: 0.6367
#   Train F1 Score: 0.5225
#   Validation F1 Score: 0.5926
#   Test F1 Score: 0.6000
#   Train Recall: 0.7945
#   Validation Recall: 0.8889
#   Test Recall: 0.7059
#   Train Precision: 0.3893
#   Validation Precision: 0.4444
#   Test Precision: 0.5217
#   Train ROC AUC: 0.7726
#   Validation ROC AUC: 0.7974
#   Test ROC AUC: 0.6492
#   Train PR AUC: 0.6090
#   Validation PR AUC: 0.6783
#   Test PR AUC: 0.6706
#
# Overall Metrics:
# Accuracy - Train: Mean = 0.7811, Std Dev = 0.0275
# Accuracy - Validation: Mean = 0.7814, Std Dev = 0.0265
# Accuracy - Test: Mean = 0.7091, Std Dev = 0.0689
# F-beta Score - Train: Mean = 0.5622, Std Dev = 0.0470
# F-beta Score - Validation: Mean = 0.5778, Std Dev = 0.1870
# F-beta Score - Test: Mean = 0.5276, Std Dev = 0.2183
# F1 Score - Train: Mean = 0.4637, Std Dev = 0.0525
# F1 Score - Validation: Mean = 0.5141, Std Dev = 0.1958
# F1 Score - Test: Mean = 0.4926, Std Dev = 0.2140
# Recall - Train: Mean = 0.8648, Std Dev = 0.0811
# Recall - Validation: Mean = 0.8437, Std Dev = 0.1405
# Recall - Test: Mean = 0.6000, Std Dev = 0.2246
# Precision - Train: Mean = 0.3202, Std Dev = 0.0534
# Precision - Validation: Mean = 0.4184, Std Dev = 0.2071
# Precision - Test: Mean = 0.4234, Std Dev = 0.2026
# ROC AUC - Train: Mean = 0.8182, Std Dev = 0.0514
# ROC AUC - Validation: Mean = 0.8136, Std Dev = 0.0510
# ROC AUC - Test: Mean = 0.6611, Std Dev = 0.1173
# PR AUC - Train: Mean = 0.6011, Std Dev = 0.0363
# PR AUC - Validation: Mean = 0.6497, Std Dev = 0.0604
# PR AUC - Test: Mean = 0.5549, Std Dev = 0.2089
#
# Baseline Metrics per Fold:
# Fold 1: {'Accuracy': 0.8863636363636364, 'Precision': 0.11363636363636363, 'Recall': 1.0, 'F1': 0.20408163265306123, 'F1.5': 0.29411764705882354, 'ROC AUC': 0.5, 'PR AUC': 0.5568181818181818}
# Fold 2: {'Accuracy': 0.75, 'Precision': 0.25, 'Recall': 1.0, 'F1': 0.4, 'F1.5': 0.52, 'ROC AUC': 0.5, 'PR AUC': 0.625}
# Fold 3: {'Accuracy': 0.7727272727272727, 'Precision': 0.22727272727272727, 'Recall': 1.0, 'F1': 0.37037037037037035, 'F1.5': 0.4887218045112782, 'ROC AUC': 0.5, 'PR AUC': 0.6136363636363636}
# Fold 4: {'Accuracy': 0.7272727272727273, 'Precision': 0.2727272727272727, 'Recall': 1.0, 'F1': 0.42857142857142855, 'F1.5': 0.5492957746478873, 'ROC AUC': 0.5, 'PR AUC': 0.6363636363636364}
# Fold 5: {'Accuracy': 0.6136363636363636, 'Precision': 0.38636363636363635, 'Recall': 1.0, 'F1': 0.5573770491803279, 'F1.5': 0.6717325227963526, 'ROC AUC': 0.5, 'PR AUC': 0.6931818181818181}

# %%
print(logistic_regression_baseline_metrics)
# Out:
# {1: {'Accuracy': 0.8863636363636364, 'Precision': 0.11363636363636363, 'Recall': 1.0, 'F1': 0.20408163265306123, 'F1.5': 0.29411764705882354, 'ROC AUC': 0.5, 'PR AUC': 0.5568181818181818}, 2: {'Accuracy': 0.75, 'Precision': 0.25, 'Recall': 1.0, 'F1': 0.4, 'F1.5': 0.52, 'ROC AUC': 0.5, 'PR AUC': 0.625}, 3: {'Accuracy': 0.7727272727272727, 'Precision': 0.22727272727272727, 'Recall': 1.0, 'F1': 0.37037037037037035, 'F1.5': 0.4887218045112782, 'ROC AUC': 0.5, 'PR AUC': 0.6136363636363636}, 4: {'Accuracy': 0.7272727272727273, 'Precision': 0.2727272727272727, 'Recall': 1.0, 'F1': 0.42857142857142855, 'F1.5': 0.5492957746478873, 'ROC AUC': 0.5, 'PR AUC': 0.6363636363636364}, 5: {'Accuracy': 0.6136363636363636, 'Precision': 0.38636363636363635, 'Recall': 1.0, 'F1': 0.5573770491803279, 'F1.5': 0.6717325227963526, 'ROC AUC': 0.5, 'PR AUC': 0.6931818181818181}}

# %%
print(logistic_regression_means)
print(logistic_regression_stds)
# Out:
# {'logistic_regression_accuracy_mean': {'train': 0.781101507595587, 'val': 0.7813953488372094, 'test': 0.7090909090909091}, 'logistic_regression_f_beta_score_mean': {'train': 0.5621814144585933, 'val': 0.577809533140325, 'test': 0.5275846778629238}, 'logistic_regression_f1_score_mean': {'train': 0.4636977650171053, 'val': 0.5141375661375661, 'test': 0.49261904761904757}, 'logistic_regression_recall_mean': {'train': 0.8648284272069071, 'val': 0.8437118437118437, 'test': 0.5999643493761141}, 'logistic_regression_precision_mean': {'train': 0.3201667635368411, 'val': 0.4184260184260184, 'test': 0.42338434512347556}, 'logistic_regression_roc_auc_mean': {'train': 0.818158744896445, 'val': 0.8136346333405158, 'test': 0.661095951978305}, 'logistic_regression_pr_auc_mean': {'train': 0.6011314504881996, 'val': 0.6496735822317217, 'test': 0.554856165431613}}
# {'logistic_regression_accuracy_std': {'train': 0.02751634275322994, 'val': 0.02651570756044506, 'test': 0.06893523130955959}, 'logistic_regression_f_beta_score_std': {'train': 0.047042011272989695, 'val': 0.18697552125362865, 'test': 0.21825774708613024}, 'logistic_regression_f1_score_std': {'train': 0.052500677511576534, 'val': 0.19582338104078967, 'test': 0.2140282845232464}, 'logistic_regression_recall_std': {'train': 0.08114685365808842, 'val': 0.1405000539555433, 'test': 0.22464074533653028}, 'logistic_regression_precision_std': {'train': 0.053356990896332376, 'val': 0.20708049632913536, 'test': 0.2025694061993905}, 'logistic_regression_roc_auc_std': {'train': 0.05144899729458998, 'val': 0.05098092111070707, 'test': 0.1172788600471412}, 'logistic_regression_pr_auc_std': {'train': 0.03631968601149124, 'val': 0.060429324811301616, 'test': 0.2088999453611551}}

# %% [markdown]
# #### XGBoostClassifier

# %%
# XGBoost with validation

# define scorer inside gridsearch
f1_scorer = make_scorer(f1_score)

# param_grid
param_grid = {
    'model__n_estimators': [50, 100, 200, 500],
    'model__max_depth': [3, 4, 5],
    'model__learning_rate': [0.01, 0.05, 0.1],
    'model__reg_alpha': [0, 0.1, 1],
    'model__reg_lambda': [0.1, 1, 10], 
    'model__subsample': [0.8, 0.9],
    'model__colsample_bytree': [0.8, 0.9],
}
metrics = {
    "Accuracy": accuracy_score,
    "F-beta Score": lambda y_true, y_pred: fbeta_score(y_true, y_pred, beta=1.5),
    "F1 Score": f1_score,
    "Recall": recall_score,
    "Precision": precision_score,
    "ROC AUC": roc_auc_score,
    "PR AUC": lambda y_true, y_pred: compute_pr_auc(y_true, y_pred)
}

tscv = TimeSeriesSplit(n_splits=5)

best_models_xgb = []

class_distributions = {}
xgb_baseline_metrics = {}
xgb_means = {}
xgb_stds = {}

# Function to consistently format metric names
def format_metric_name(metric_name):
    return re.sub(r'[^a-zA-Z0-9]+', '_', metric_name.lower())
    
# initialise scores dictionaries
scores_per_fold = {f"train_{format_metric_name(name)}": [] for name in metrics}
scores_per_fold.update({f"test_{format_metric_name(name)}": [] for name in metrics})
scores_per_fold.update({f"val_{format_metric_name(name)}": [] for name in metrics})  # Add validation scores

# data splitting, model training, & evaluation
for fold_idx, (train_index, test_index) in enumerate(tscv.split(X), start=1):
    # Split data into train and test sets
    X_train = X.iloc[train_index]
    Y_train = Y.iloc[train_index]
    X_test_full = X.iloc[test_index]
    Y_test_full = Y.iloc[test_index]

    # Split the test set into 10% validation and 10% test (chronologically)
    split_point = len(X_test_full) // 2
    X_val = X_test_full.iloc[:split_point]
    Y_val = Y_test_full.iloc[:split_point]
    
    X_test = X_test_full.iloc[split_point:]
    Y_test = Y_test_full.iloc[split_point:]

    print(f"\nFold {fold_idx}:")
    print(f"  Training set: X shape = {X_train.shape}, Y shape = {Y_train.shape}, Size = {X_train.shape[0]}")
    print(f"  Validation set:  X shape = {X_val.shape}, Y shape = {Y_val.shape}, Size = {X_val.shape[0]}")
    print(f"  Testing set:  X shape = {X_test.shape}, Y shape = {Y_test.shape}, Size = {X_test.shape[0]}")

    #defining class imbalance
    scale_pos_weight = len(Y_train[Y_train == 0]) / len(Y_train[Y_train == 1])
    
    # Count class occurrences in Y_test
    class_counts = Y_test.value_counts()
    total = len(Y_test)
    majority_class = class_counts.idxmax()
    majority_class_count = class_counts.max()
    num_class_1 = class_counts.get(1, 0)
    num_class_0 = class_counts.get(0, 0)
    baseline_probs = [1 if majority_class == 1 else 0] * len(Y_test)
    precision_baseline, recall_baseline, _ = precision_recall_curve(Y_test, baseline_probs)

    # Debugging prints for class distribution
    print(f"\nFold {fold_idx} - Class Distribution in Test Set:")
    print(f"  Total samples: {total}")
    print(f"  Class Counts:\n{class_counts}")
    print(f"  Majority Class: {majority_class}")
    print(f"  Majority Class Count: {majority_class_count}")
    
   # Store class distribution
    class_distributions[fold_idx] = {
        "Class 0": num_class_0,
        "Class 1": num_class_1
    }

    # baseline metrics: predicting all points as class 1
    accuracy = majority_class_count / total
    precision = num_class_1 / (num_class_1 + num_class_0)
    recall = (num_class_1 / total) / (num_class_1/ total + 0)
    f1 = 2 * (precision * recall) / (precision + recall)
    f1_5 = (1 + 1.5**2) * (precision * recall) / ((1.5**2 * precision) + recall)
    roc_auc = roc_auc_score(Y_test, baseline_probs)
    pr_auc = auc(recall_baseline, precision_baseline)

    print("\nBaseline Metric Calculations:")
    print(f"  Accuracy: {accuracy}")
    print(f"  Precision: {precision}")
    print(f"  Recall: {recall}")
    print(f"  F1 Score: {f1}")
    print(f"  F1.5 Score: {f1_5}")
    print(f"  ROC AUC: {roc_auc}")
    print(f"  PR AUC: {pr_auc}")
    
    xgb_baseline_metrics[fold_idx] = {
        "Accuracy": accuracy,
        "Precision": precision,
        "Recall": recall,
        "F1": f1,
        "F1.5": f1_5,
        "ROC AUC": roc_auc,
        "PR AUC": pr_auc
    }
    
    # pipeline
    pipeline = Pipeline([
        ('scaler', StandardScaler()),  
        ('model', XGBClassifier(use_label_encoder=False, eval_metric='logloss', 
                                scale_pos_weight=scale_pos_weight, random_state=1))
    ])
    
    # GridSearchCV with tscv
    grid_search = GridSearchCV(
        estimator=pipeline,
        param_grid=param_grid,
        cv=tscv,
        scoring=f1_scorer,
        refit=True,  # refit best model on the full training data
        n_jobs=-1,  
        verbose=1
    )
    
    with warnings.catch_warnings():
        warnings.simplefilter("ignore")
        grid_search.fit(X_train, Y_train)
    
    # Use the validation set to select the best model
    best_model_idx = np.argmax([grid_search.score(X_val, Y_val) for model in grid_search.cv_results_['params']])

    # find best parameters using X_train
    best_params = grid_search.best_params_
    best_model_xgb = grid_search.best_estimator_
    print(f"Fold {fold_idx} -> Best Params: {best_params}")

    # Evaluate the best model on the validation set (X_val, Y_val)
    y_val_pred_probs = best_model_xgb.predict_proba(X_val)[:, 1]
    y_val_pred = best_model_xgb.predict(X_val)

    #evalualte on X_train 
    y_train_pred = best_model_xgb.predict(X_train)

    # Evaluate on X_test
    y_test_pred_probs = best_model_xgb.predict_proba(X_test)[:, 1]
    y_test_pred = best_model_xgb.predict(X_test)

    # predict probabilities (needed for PR AUC calculation)
    y_pred_probs = best_model_xgb.predict_proba(X_test)[:, 1]  # Get probabilities for class 1
    
    # calculate PR AUC for the test set
    pr_auc_value = compute_pr_auc(Y_test, y_pred_probs)

    # generate confusion matrix for each fold
    cm = confusion_matrix(Y_test, y_test_pred, labels=[0, 1])
        
    # Plot confusion matrix
    plt.figure(figsize=(6, 5))
    sns.heatmap(cm, annot=True, fmt="d", cmap="Blues", xticklabels=[0, 1], yticklabels=[0, 1])
    plt.xlabel("Predicted")
    plt.ylabel("Actual")
    plt.title(f"Confusion Matrix for XGBoost - Fold {fold_idx}")
    plt.show()
    
    #for loop for calculating train & test metrics
    #print(f"Fold {fold_idx} metrics:")
    for name, func in metrics.items():
        formatted_name = format_metric_name(name)
    
        # Train metrics
        train_score = func(Y_train, y_train_pred)
        print(f"  Train {name}: {train_score:.4f}")
        scores_per_fold[f"train_{formatted_name}"].append(train_score)

        # Validation metrics
        val_score = func(Y_val, y_val_pred)
        print(f"  Validation {name}: {val_score:.4f}")
        scores_per_fold[f"val_{formatted_name}"].append(val_score)
        
        # Test metrics
        test_score = func(Y_test, y_test_pred)
        print(f"  Test {name}: {test_score:.4f}")
        scores_per_fold[f"test_{formatted_name}"].append(test_score)

# Calculate and save mean and std metrics
print("\nOverall Metrics:")
for metric_name in metrics:
    formatted_name = format_metric_name(metric_name)
    train_key = f"train_{formatted_name}"
    val_key = f"val_{formatted_name}"
    test_key = f"test_{formatted_name}"
    
    avg_train = np.mean(scores_per_fold[train_key])
    std_train = np.std(scores_per_fold[train_key], ddof=1)
    avg_val = np.mean(scores_per_fold[val_key])
    std_val = np.std(scores_per_fold[val_key], ddof=1)
    avg_test = np.mean(scores_per_fold[test_key])
    std_test = np.std(scores_per_fold[test_key], ddof=1)

    # Save to dictionaries for model comparison
    xgb_means[f"xgb_{formatted_name}_mean"] = {
        "train": avg_train,
        "val": avg_val,
        "test": avg_test
    }
    xgb_stds[f"xgb_{formatted_name}_std"] = {
        "train": std_train,
        "val": std_val,
        "test": std_test
    }
        
    print(f"{metric_name} - Train: Mean = {avg_train:.4f}, Std Dev = {std_train:.4f}")
    print(f"{metric_name} - Validation: Mean = {avg_val:.4f}, Std Dev = {std_val:.4f}")
    print(f"{metric_name} - Test: Mean = {avg_test:.4f}, Std Dev = {std_test:.4f}")

#print baselines at the end for each fold:
print("\nBaseline Metrics per Fold:")
for fold, metrics in xgb_baseline_metrics.items():
    print(f"Fold {fold}: {metrics}")
# Out:
# Fold 1:
#   Training set: X shape = (90, 15), Y shape = (90,), Size = 90
#   Validation set:  X shape = (43, 15), Y shape = (43,), Size = 43
#   Testing set:  X shape = (44, 15), Y shape = (44,), Size = 44
#
# Fold 1 - Class Distribution in Test Set:
#   Total samples: 44
#   Class Counts:
# wildfire_frequency
# 0    39
# 1     5
# Name: count, dtype: int64
#   Majority Class: 0
#   Majority Class Count: 39
#
# Baseline Metric Calculations:
#   Accuracy: 0.8863636363636364
#   Precision: 0.11363636363636363
#   Recall: 1.0
#   F1 Score: 0.20408163265306123
#   F1.5 Score: 0.29411764705882354
#   ROC AUC: 0.5
#   PR AUC: 0.5568181818181818
# Fitting 5 folds for each of 1296 candidates, totalling 6480 fits
# Fold 1 -> Best Params: {'model__colsample_bytree': 0.8, 'model__learning_rate': 0.01, 'model__max_depth': 3, 'model__n_estimators': 50, 'model__reg_alpha': 0, 'model__reg_lambda': 10, 'model__subsample': 0.9}
#   Train Accuracy: 0.9000
#   Validation Accuracy: 0.9070
#   Test Accuracy: 0.8182
#   Train F-beta Score: 0.7165
#   Validation F-beta Score: 0.0000
#   Test F-beta Score: 0.3562
#   Train F1 Score: 0.6087
#   Validation F1 Score: 0.0000
#   Test F1 Score: 0.3333
#   Train Recall: 1.0000
#   Validation Recall: 0.0000
#   Test Recall: 0.4000
#   Train Precision: 0.4375
#   Validation Precision: 0.0000
#   Test Precision: 0.2857
#   Train ROC AUC: 0.9458
#   Validation ROC AUC: 0.4643
#   Test ROC AUC: 0.6359
#   Train PR AUC: 0.7188
#   Validation PR AUC: 0.0116
#   Test PR AUC: 0.3769
#
# Fold 2:
#   Training set: X shape = (177, 15), Y shape = (177,), Size = 177
#   Validation set:  X shape = (43, 15), Y shape = (43,), Size = 43
#   Testing set:  X shape = (44, 15), Y shape = (44,), Size = 44
#
# Fold 2 - Class Distribution in Test Set:
#   Total samples: 44
#   Class Counts:
# wildfire_frequency
# 0    33
# 1    11
# Name: count, dtype: int64
#   Majority Class: 0
#   Majority Class Count: 33
#
# Baseline Metric Calculations:
#   Accuracy: 0.75
#   Precision: 0.25
#   Recall: 1.0
#   F1 Score: 0.4
#   F1.5 Score: 0.52
#   ROC AUC: 0.5
#   PR AUC: 0.625
# Fitting 5 folds for each of 1296 candidates, totalling 6480 fits
# Fold 2 -> Best Params: {'model__colsample_bytree': 0.8, 'model__learning_rate': 0.01, 'model__max_depth': 4, 'model__n_estimators': 50, 'model__reg_alpha': 0, 'model__reg_lambda': 10, 'model__subsample': 0.8}
#   Train Accuracy: 0.9266
#   Validation Accuracy: 0.9070
#   Test Accuracy: 0.7273
#   Train F-beta Score: 0.7647
#   Validation F-beta Score: 0.6265
#   Test F-beta Score: 0.3071
#   Train F1 Score: 0.6667
#   Validation F1 Score: 0.6667
#   Test F1 Score: 0.3333
#   Train Recall: 1.0000
#   Validation Recall: 0.5714
#   Test Recall: 0.2727
#   Train Precision: 0.5000
#   Validation Precision: 0.8000
#   Test Precision: 0.4286
#   Train ROC AUC: 0.9604
#   Validation ROC AUC: 0.7718
#   Test ROC AUC: 0.5758
#   Train PR AUC: 0.7500
#   Validation PR AUC: 0.7206
#   Test PR AUC: 0.4416
#
# Fold 3:
#   Training set: X shape = (264, 15), Y shape = (264,), Size = 264
#   Validation set:  X shape = (43, 15), Y shape = (43,), Size = 43
#   Testing set:  X shape = (44, 15), Y shape = (44,), Size = 44
#
# Fold 3 - Class Distribution in Test Set:
#   Total samples: 44
#   Class Counts:
# wildfire_frequency
# 0    34
# 1    10
# Name: count, dtype: int64
#   Majority Class: 0
#   Majority Class Count: 34
#
# Baseline Metric Calculations:
#   Accuracy: 0.7727272727272727
#   Precision: 0.22727272727272727
#   Recall: 1.0
#   F1 Score: 0.37037037037037035
#   F1.5 Score: 0.4887218045112782
#   ROC AUC: 0.5
#   PR AUC: 0.6136363636363636
# Fitting 5 folds for each of 1296 candidates, totalling 6480 fits
# Fold 3 -> Best Params: {'model__colsample_bytree': 0.8, 'model__learning_rate': 0.01, 'model__max_depth': 3, 'model__n_estimators': 200, 'model__reg_alpha': 0, 'model__reg_lambda': 10, 'model__subsample': 0.8}
#   Train Accuracy: 0.8561
#   Validation Accuracy: 0.7674
#   Test Accuracy: 0.6818
#   Train F-beta Score: 0.7261
#   Validation F-beta Score: 0.4860
#   Test F-beta Score: 0.4452
#   Train F1 Score: 0.6200
#   Validation F1 Score: 0.4444
#   Test F1 Score: 0.4167
#   Train Recall: 1.0000
#   Validation Recall: 0.5714
#   Test Recall: 0.5000
#   Train Precision: 0.4493
#   Validation Precision: 0.3636
#   Test Precision: 0.3571
#   Train ROC AUC: 0.9185
#   Validation ROC AUC: 0.6885
#   Test ROC AUC: 0.6176
#   Train PR AUC: 0.7246
#   Validation PR AUC: 0.5024
#   Test PR AUC: 0.4854
#
# Fold 4:
#   Training set: X shape = (351, 15), Y shape = (351,), Size = 351
#   Validation set:  X shape = (43, 15), Y shape = (43,), Size = 43
#   Testing set:  X shape = (44, 15), Y shape = (44,), Size = 44
#
# Fold 4 - Class Distribution in Test Set:
#   Total samples: 44
#   Class Counts:
# wildfire_frequency
# 0    32
# 1    12
# Name: count, dtype: int64
#   Majority Class: 0
#   Majority Class Count: 32
#
# Baseline Metric Calculations:
#   Accuracy: 0.7272727272727273
#   Precision: 0.2727272727272727
#   Recall: 1.0
#   F1 Score: 0.42857142857142855
#   F1.5 Score: 0.5492957746478873
#   ROC AUC: 0.5
#   PR AUC: 0.6363636363636364
# Fitting 5 folds for each of 1296 candidates, totalling 6480 fits
# Fold 4 -> Best Params: {'model__colsample_bytree': 0.9, 'model__learning_rate': 0.05, 'model__max_depth': 3, 'model__n_estimators': 50, 'model__reg_alpha': 0, 'model__reg_lambda': 0.1, 'model__subsample': 0.8}
#   Train Accuracy: 0.8803
#   Validation Accuracy: 0.8140
#   Test Accuracy: 0.6364
#   Train F-beta Score: 0.7879
#   Validation F-beta Score: 0.5948
#   Test F-beta Score: 0.3963
#   Train F1 Score: 0.6957
#   Validation F1 Score: 0.6364
#   Test F1 Score: 0.3846
#   Train Recall: 1.0000
#   Validation Recall: 0.5385
#   Test Recall: 0.4167
#   Train Precision: 0.5333
#   Validation Precision: 0.7778
#   Test Precision: 0.3571
#   Train ROC AUC: 0.9307
#   Validation ROC AUC: 0.7359
#   Test ROC AUC: 0.5677
#   Train PR AUC: 0.7667
#   Validation PR AUC: 0.7279
#   Test PR AUC: 0.4665
#
# Fold 5:
#   Training set: X shape = (438, 15), Y shape = (438,), Size = 438
#   Validation set:  X shape = (43, 15), Y shape = (43,), Size = 43
#   Testing set:  X shape = (44, 15), Y shape = (44,), Size = 44
#
# Fold 5 - Class Distribution in Test Set:
#   Total samples: 44
#   Class Counts:
# wildfire_frequency
# 0    27
# 1    17
# Name: count, dtype: int64
#   Majority Class: 0
#   Majority Class Count: 27
#
# Baseline Metric Calculations:
#   Accuracy: 0.6136363636363636
#   Precision: 0.38636363636363635
#   Recall: 1.0
#   F1 Score: 0.5573770491803279
#   F1.5 Score: 0.6717325227963526
#   ROC AUC: 0.5
#   PR AUC: 0.6931818181818181
# Fitting 5 folds for each of 1296 candidates, totalling 6480 fits
# Fold 5 -> Best Params: {'model__colsample_bytree': 0.8, 'model__learning_rate': 0.05, 'model__max_depth': 3, 'model__n_estimators': 50, 'model__reg_alpha': 1, 'model__reg_lambda': 10, 'model__subsample': 0.8}
#   Train Accuracy: 0.8059
#   Validation Accuracy: 0.7209
#   Test Accuracy: 0.6591
#   Train F-beta Score: 0.7019
#   Validation F-beta Score: 0.4887
#   Test F-beta Score: 0.5778
#   Train F1 Score: 0.6119
#   Validation F1 Score: 0.4545
#   Test F1 Score: 0.5714
#   Train Recall: 0.9178
#   Validation Recall: 0.5556
#   Test Recall: 0.5882
#   Train Precision: 0.4589
#   Validation Precision: 0.3846
#   Test Precision: 0.5556
#   Train ROC AUC: 0.8507
#   Validation ROC AUC: 0.6601
#   Test ROC AUC: 0.6460
#   Train PR AUC: 0.6952
#   Validation PR AUC: 0.5166
#   Test PR AUC: 0.6514
#
# Overall Metrics:
# Accuracy - Train: Mean = 0.8738, Std Dev = 0.0459
# Accuracy - Validation: Mean = 0.8233, Std Dev = 0.0832
# Accuracy - Test: Mean = 0.7045, Std Dev = 0.0719
# F-beta Score - Train: Mean = 0.7394, Std Dev = 0.0357
# F-beta Score - Validation: Mean = 0.4392, Std Dev = 0.2534
# F-beta Score - Test: Mean = 0.4165, Std Dev = 0.1035
# F1 Score - Train: Mean = 0.6406, Std Dev = 0.0387
# F1 Score - Validation: Mean = 0.4404, Std Dev = 0.2663
# F1 Score - Test: Mean = 0.4079, Std Dev = 0.0981
# Recall - Train: Mean = 0.9836, Std Dev = 0.0368
# Recall - Validation: Mean = 0.4474, Std Dev = 0.2505
# Recall - Test: Mean = 0.4355, Std Dev = 0.1179
# Precision - Train: Mean = 0.4758, Std Dev = 0.0398
# Precision - Validation: Mean = 0.4652, Std Dev = 0.3328
# Precision - Test: Mean = 0.3968, Std Dev = 0.1021
# ROC AUC - Train: Mean = 0.9212, Std Dev = 0.0425
# ROC AUC - Validation: Mean = 0.6641, Std Dev = 0.1197
# ROC AUC - Test: Mean = 0.6086, Std Dev = 0.0353
# PR AUC - Train: Mean = 0.7311, Std Dev = 0.0279
# PR AUC - Validation: Mean = 0.4958, Std Dev = 0.2912
# PR AUC - Test: Mean = 0.4844, Std Dev = 0.1020
#
# Baseline Metrics per Fold:
# Fold 1: {'Accuracy': 0.8863636363636364, 'Precision': 0.11363636363636363, 'Recall': 1.0, 'F1': 0.20408163265306123, 'F1.5': 0.29411764705882354, 'ROC AUC': 0.5, 'PR AUC': 0.5568181818181818}
# Fold 2: {'Accuracy': 0.75, 'Precision': 0.25, 'Recall': 1.0, 'F1': 0.4, 'F1.5': 0.52, 'ROC AUC': 0.5, 'PR AUC': 0.625}
# Fold 3: {'Accuracy': 0.7727272727272727, 'Precision': 0.22727272727272727, 'Recall': 1.0, 'F1': 0.37037037037037035, 'F1.5': 0.4887218045112782, 'ROC AUC': 0.5, 'PR AUC': 0.6136363636363636}
# Fold 4: {'Accuracy': 0.7272727272727273, 'Precision': 0.2727272727272727, 'Recall': 1.0, 'F1': 0.42857142857142855, 'F1.5': 0.5492957746478873, 'ROC AUC': 0.5, 'PR AUC': 0.6363636363636364}
# Fold 5: {'Accuracy': 0.6136363636363636, 'Precision': 0.38636363636363635, 'Recall': 1.0, 'F1': 0.5573770491803279, 'F1.5': 0.6717325227963526, 'ROC AUC': 0.5, 'PR AUC': 0.6931818181818181}

# %%
print(xgb_baseline_metrics)
# Out:
# {1: {'Accuracy': 0.8863636363636364, 'Precision': 0.11363636363636363, 'Recall': 1.0, 'F1': 0.20408163265306123, 'F1.5': 0.29411764705882354, 'ROC AUC': 0.5, 'PR AUC': 0.5568181818181818}, 2: {'Accuracy': 0.75, 'Precision': 0.25, 'Recall': 1.0, 'F1': 0.4, 'F1.5': 0.52, 'ROC AUC': 0.5, 'PR AUC': 0.625}, 3: {'Accuracy': 0.7727272727272727, 'Precision': 0.22727272727272727, 'Recall': 1.0, 'F1': 0.37037037037037035, 'F1.5': 0.4887218045112782, 'ROC AUC': 0.5, 'PR AUC': 0.6136363636363636}, 4: {'Accuracy': 0.7272727272727273, 'Precision': 0.2727272727272727, 'Recall': 1.0, 'F1': 0.42857142857142855, 'F1.5': 0.5492957746478873, 'ROC AUC': 0.5, 'PR AUC': 0.6363636363636364}, 5: {'Accuracy': 0.6136363636363636, 'Precision': 0.38636363636363635, 'Recall': 1.0, 'F1': 0.5573770491803279, 'F1.5': 0.6717325227963526, 'ROC AUC': 0.5, 'PR AUC': 0.6931818181818181}}

# %%
print(xgb_means)
print(xgb_stds)
# Out:
# {'xgb_accuracy_mean': {'train': 0.8737784463556462, 'val': 0.8232558139534885, 'test': 0.7045454545454545}, 'xgb_f_beta_score_mean': {'train': 0.7394199147012157, 'val': 0.43919607576978875, 'test': 0.4165151436758677}, 'xgb_f1_score_mean': {'train': 0.640577327774469, 'val': 0.4404040404040404, 'test': 0.40787545787545787}, 'xgb_recall_mean': {'train': 0.9835616438356164, 'val': 0.4473748473748474, 'test': 0.4355258467023173}, 'xgb_precision_mean': {'train': 0.475802561048243, 'val': 0.46520590520590516, 'test': 0.39682539682539686}, 'xgb_roc_auc_mean': {'train': 0.921196384524951, 'val': 0.6641262658909718, 'test': 0.60859598054451}, 'xgb_pr_auc_mean': {'train': 0.7310519654556284, 'val': 0.4958252600113065, 'test': 0.48435743994567526}}
# {'xgb_accuracy_std': {'train': 0.045914002481855745, 'val': 0.083202529395341, 'test': 0.07186994682200865}, 'xgb_f_beta_score_std': {'train': 0.035704740904852116, 'val': 0.25338878122810854, 'test': 0.10350430814124836}, 'xgb_f1_score_std': {'train': 0.038657946765012205, 'val': 0.2663489077107513, 'test': 0.0980828654448618}, 'xgb_recall_std': {'train': 0.03675728182191435, 'val': 0.2504609539840815, 'test': 0.11789637602274948}, 'xgb_precision_std': {'train': 0.03984859448131615, 'val': 0.33279723536044736, 'test': 0.10210063754181435}, 'xgb_roc_auc_std': {'train': 0.04245092184021038, 'val': 0.11968302532322796, 'test': 0.03526411731804384}, 'xgb_pr_auc_std': {'train': 0.027860756052890418, 'val': 0.29124623236850355, 'test': 0.10198914238291096}}

# %% [markdown]
# #### Random Forest Classifier

# %%
#define X & Y

y = df_binary_no_missing_values['wildfire_frequency']
X = df_binary_no_missing_values.drop(columns=['wildfire_frequency'])

# %%
# random forest classifier with validation
# F1 scorer
f1_scorer = make_scorer(f1_score)

# param_grid
param_grid = {
    'model__n_estimators': [1, 3, 10, 30],
    'model__max_depth': [1, 2, 3, 10, 30, 100],
    'model__max_features': [0.25, 0.5, 0.75, 1.0]
}

metrics = {
    "Accuracy": accuracy_score,
    "F-beta Score": lambda y_true, y_pred: fbeta_score(y_true, y_pred, beta=1.5),
    "F1 Score": f1_score,
    "Recall": recall_score,
    "Precision": precision_score,
    "ROC AUC": roc_auc_score,
    "PR AUC": lambda y_true, y_pred: compute_pr_auc(y_true, y_pred)
}

tscv = TimeSeriesSplit(n_splits=5)

best_models_forest = []

class_distributions = {}
forest_baseline_metrics = {}
forest_means = {}
forest_stds = {}

# Function to consistently format metric names
def format_metric_name(metric_name):
    return re.sub(r'[^a-zA-Z0-9]+', '_', metric_name.lower())
    
# initialise scores dictionaries
scores_per_fold = {f"train_{format_metric_name(name)}": [] for name in metrics}
scores_per_fold.update({f"test_{format_metric_name(name)}": [] for name in metrics})
scores_per_fold.update({f"val_{format_metric_name(name)}": [] for name in metrics})  # Add validation scores

# data splitting, model training, & evaluation
for fold_idx, (train_index, test_index) in enumerate(tscv.split(X), start=1):
    # Split data into train and test sets
    X_train = X.iloc[train_index]
    Y_train = Y.iloc[train_index]
    X_test_full = X.iloc[test_index]
    Y_test_full = Y.iloc[test_index]

    # Split the test set into 10% validation and 10% test (chronologically)
    split_point = len(X_test_full) // 2
    X_val = X_test_full.iloc[:split_point]
    Y_val = Y_test_full.iloc[:split_point]
    
    X_test = X_test_full.iloc[split_point:]
    Y_test = Y_test_full.iloc[split_point:]

    print(f"\nFold {fold_idx}:")
    print(f"  Training set: X shape = {X_train.shape}, Y shape = {Y_train.shape}, Size = {X_train.shape[0]}")
    print(f"  Validation set:  X shape = {X_val.shape}, Y shape = {Y_val.shape}, Size = {X_val.shape[0]}")
    print(f"  Testing set:  X shape = {X_test.shape}, Y shape = {Y_test.shape}, Size = {X_test.shape[0]}")

    # Count class occurrences in Y_test
    class_counts = Y_test.value_counts()
    total = len(Y_test)
    majority_class = class_counts.idxmax()
    majority_class_count = class_counts.max()
    num_class_1 = class_counts.get(1, 0)
    num_class_0 = class_counts.get(0, 0)
    baseline_probs = [1 if majority_class == 1 else 0] * len(Y_test)
    precision_baseline, recall_baseline, _ = precision_recall_curve(Y_test, baseline_probs)

    # Debugging prints for class distribution
    print(f"\nFold {fold_idx} - Class Distribution in Test Set:")
    print(f"  Total samples: {total}")
    print(f"  Class Counts:\n{class_counts}")
    print(f"  Majority Class: {majority_class}")
    print(f"  Majority Class Count: {majority_class_count}")
    
    # Store class distribution
    class_distributions[fold_idx] = {
        "Class 0": num_class_0,
        "Class 1": num_class_1
    }

    # baseline metrics: predicting all points as class 1
    accuracy = majority_class_count / total
    precision = num_class_1 / (num_class_1 + num_class_0)
    recall = (num_class_1 / total) / (num_class_1/ total + 0)
    f1 = 2 * (precision * recall) / (precision + recall)
    f1_5 = (1 + 1.5**2) * (precision * recall) / ((1.5**2 * precision) + recall)
    roc_auc = roc_auc_score(Y_test, baseline_probs)
    pr_auc = auc(recall_baseline, precision_baseline)

    print("\nBaseline Metric Calculations:")
    print(f"  Accuracy: {accuracy}")
    print(f"  Precision: {precision}")
    print(f"  Recall: {recall}")
    print(f"  F1 Score: {f1}")
    print(f"  F1.5 Score: {f1_5}")
    print(f"  ROC AUC: {roc_auc}")
    print(f"  PR AUC: {pr_auc}")
    
    forest_baseline_metrics[fold_idx] = {
        "Accuracy": accuracy,
        "Precision": precision,
        "Recall": recall,
        "F1": f1,
        "F1.5": f1_5,
        "ROC AUC": roc_auc,
        "PR AUC": pr_auc
    }
    
    # pipeline
    pipeline = Pipeline([
        ('scaler', StandardScaler()),  
        ('model', RandomForestClassifier(class_weight='balanced', random_state=1))
    ])
    
    # GridSearchCV with tscv
    grid_search = GridSearchCV(
        estimator=pipeline,
        param_grid=param_grid,
        cv=tscv,
        scoring=f1_scorer,
        refit=True,  # refit best model on the full training data
        n_jobs=-1,  
        verbose=1
    )
    
    with warnings.catch_warnings():
        warnings.simplefilter("ignore")
        grid_search.fit(X_train, Y_train)
    
    # Use the validation set to select the best model
    best_model_idx = np.argmax([grid_search.score(X_val, Y_val) for model in grid_search.cv_results_['params']])

    # find best parameters using X_train
    best_params = grid_search.best_params_
    best_model_forest = grid_search.best_estimator_
    print(f"Fold {fold_idx} -> Best Params: {best_params}")

    # Evaluate the best model on the validation set (X_val, Y_val)
    y_val_pred_probs = best_model_forest.predict_proba(X_val)[:, 1]
    y_val_pred = best_model_forest.predict(X_val)

    #evalualte on X_train 
    y_train_pred = best_model_forest.predict(X_train)

    # Evaluate on X_test
    y_test_pred_probs = best_model_forest.predict_proba(X_test)[:, 1]
    y_test_pred = best_model_forest.predict(X_test)

    # predict probabilities (needed for PR AUC calculation)
    y_pred_probs = best_model_forest.predict_proba(X_test)[:, 1]  # Get probabilities for class 1
    
    # calculate PR AUC for the test set
    pr_auc_value = compute_pr_auc(Y_test, y_pred_probs)

    #calculate confusion matrix for each fold
    cm = confusion_matrix(Y_test, y_test_pred, labels=[0, 1])
        
    # Plot confusion matrix
    plt.figure(figsize=(6, 5))
    sns.heatmap(cm, annot=True, fmt="d", cmap="Blues", xticklabels=[0, 1], yticklabels=[0, 1])
    plt.xlabel("Predicted")
    plt.ylabel("Actual")
    plt.title(f"Confusion Matrix for Random Forest - Fold {fold_idx}")
    plt.show()
    
    #for loop for calculating train & test metrics
    #print(f"Fold {fold_idx} metrics:")
    for name, func in metrics.items():
        formatted_name = format_metric_name(name)
    
        # Train metrics
        train_score = func(Y_train, y_train_pred)
        print(f"  Train {name}: {train_score:.4f}")
        scores_per_fold[f"train_{formatted_name}"].append(train_score)

        # Validation metrics
        val_score = func(Y_val, y_val_pred)
        print(f"  Validation {name}: {val_score:.4f}")
        scores_per_fold[f"val_{formatted_name}"].append(val_score)
        
        # Test metrics
        test_score = func(Y_test, y_test_pred)
        print(f"  Test {name}: {test_score:.4f}")
        scores_per_fold[f"test_{formatted_name}"].append(test_score)
        
# Calculate and save mean and std metrics
print("\nOverall Metrics:")
for metric_name in metrics:
    formatted_name = format_metric_name(metric_name)
    train_key = f"train_{formatted_name}"
    val_key = f"val_{formatted_name}"
    test_key = f"test_{formatted_name}"
    
    avg_train = np.mean(scores_per_fold[train_key])
    std_train = np.std(scores_per_fold[train_key], ddof=1)
    avg_val = np.mean(scores_per_fold[val_key])
    std_val = np.std(scores_per_fold[val_key], ddof=1)
    avg_test = np.mean(scores_per_fold[test_key])
    std_test = np.std(scores_per_fold[test_key], ddof=1)

    # Save to dictionaries for model comparison
    forest_means[f"forest_{formatted_name}_mean"] = {
        "train": avg_train,
        "val": avg_val,
        "test": avg_test
    }
    forest_stds[f"forest_{formatted_name}_std"] = {
        "train": std_train,
        "val": std_val,
        "test": std_test
    }
        
    print(f"{metric_name} - Train: Mean = {avg_train:.4f}, Std Dev = {std_train:.4f}")
    print(f"{metric_name} - Validation: Mean = {avg_val:.4f}, Std Dev = {std_val:.4f}")
    print(f"{metric_name} - Test: Mean = {avg_test:.4f}, Std Dev = {std_test:.4f}")

#print baselines at the end for each fold:
print("\nBaseline Metrics per Fold:")
for fold, metrics in forest_baseline_metrics.items():
    print(f"Fold {fold}: {metrics}")
# Out:
# Fold 1:
#   Training set: X shape = (90, 15), Y shape = (90,), Size = 90
#   Validation set:  X shape = (43, 15), Y shape = (43,), Size = 43
#   Testing set:  X shape = (44, 15), Y shape = (44,), Size = 44
#
# Fold 1 - Class Distribution in Test Set:
#   Total samples: 44
#   Class Counts:
# wildfire_frequency
# 0    39
# 1     5
# Name: count, dtype: int64
#   Majority Class: 0
#   Majority Class Count: 39
#
# Baseline Metric Calculations:
#   Accuracy: 0.8863636363636364
#   Precision: 0.11363636363636363
#   Recall: 1.0
#   F1 Score: 0.20408163265306123
#   F1.5 Score: 0.29411764705882354
#   ROC AUC: 0.5
#   PR AUC: 0.5568181818181818
# Fitting 5 folds for each of 96 candidates, totalling 480 fits
# Fold 1 -> Best Params: {'model__max_depth': 1, 'model__max_features': 0.25, 'model__n_estimators': 1}
#   Train Accuracy: 0.6111
#   Validation Accuracy: 0.6279
#   Test Accuracy: 0.5682
#   Train F-beta Score: 0.3498
#   Validation F-beta Score: 0.1688
#   Test F-beta Score: 0.3910
#   Train F1 Score: 0.2553
#   Validation F1 Score: 0.1111
#   Test F1 Score: 0.2963
#   Train Recall: 0.8571
#   Validation Recall: 1.0000
#   Test Recall: 0.8000
#   Train Precision: 0.1500
#   Validation Precision: 0.0588
#   Test Precision: 0.1818
#   Train ROC AUC: 0.7238
#   Validation ROC AUC: 0.8095
#   Test ROC AUC: 0.6692
#   Train PR AUC: 0.5091
#   Validation PR AUC: 0.5294
#   Test PR AUC: 0.5023
#
# Fold 2:
#   Training set: X shape = (177, 15), Y shape = (177,), Size = 177
#   Validation set:  X shape = (43, 15), Y shape = (43,), Size = 43
#   Testing set:  X shape = (44, 15), Y shape = (44,), Size = 44
#
# Fold 2 - Class Distribution in Test Set:
#   Total samples: 44
#   Class Counts:
# wildfire_frequency
# 0    33
# 1    11
# Name: count, dtype: int64
#   Majority Class: 0
#   Majority Class Count: 33
#
# Baseline Metric Calculations:
#   Accuracy: 0.75
#   Precision: 0.25
#   Recall: 1.0
#   F1 Score: 0.4
#   F1.5 Score: 0.52
#   ROC AUC: 0.5
#   PR AUC: 0.625
# Fitting 5 folds for each of 96 candidates, totalling 480 fits
# Fold 2 -> Best Params: {'model__max_depth': 1, 'model__max_features': 0.75, 'model__n_estimators': 3}
#   Train Accuracy: 0.8701
#   Validation Accuracy: 0.8605
#   Test Accuracy: 0.8409
#   Train F-beta Score: 0.2751
#   Validation F-beta Score: 0.5714
#   Test F-beta Score: 0.5285
#   Train F1 Score: 0.2581
#   Validation F1 Score: 0.5714
#   Test F1 Score: 0.5882
#   Train Recall: 0.3077
#   Validation Recall: 0.5714
#   Test Recall: 0.4545
#   Train Precision: 0.2222
#   Validation Precision: 0.5714
#   Test Precision: 0.8333
#   Train ROC AUC: 0.6112
#   Validation ROC AUC: 0.7440
#   Test ROC AUC: 0.7121
#   Train PR AUC: 0.2904
#   Validation PR AUC: 0.6063
#   Test PR AUC: 0.7121
#
# Fold 3:
#   Training set: X shape = (264, 15), Y shape = (264,), Size = 264
#   Validation set:  X shape = (43, 15), Y shape = (43,), Size = 43
#   Testing set:  X shape = (44, 15), Y shape = (44,), Size = 44
#
# Fold 3 - Class Distribution in Test Set:
#   Total samples: 44
#   Class Counts:
# wildfire_frequency
# 0    34
# 1    10
# Name: count, dtype: int64
#   Majority Class: 0
#   Majority Class Count: 34
#
# Baseline Metric Calculations:
#   Accuracy: 0.7727272727272727
#   Precision: 0.22727272727272727
#   Recall: 1.0
#   F1 Score: 0.37037037037037035
#   F1.5 Score: 0.4887218045112782
#   ROC AUC: 0.5
#   PR AUC: 0.6136363636363636
# Fitting 5 folds for each of 96 candidates, totalling 480 fits
# Fold 3 -> Best Params: {'model__max_depth': 1, 'model__max_features': 0.5, 'model__n_estimators': 3}
#   Train Accuracy: 0.7652
#   Validation Accuracy: 0.7907
#   Test Accuracy: 0.6818
#   Train F-beta Score: 0.5532
#   Validation F-beta Score: 0.5049
#   Test F-beta Score: 0.5065
#   Train F1 Score: 0.4561
#   Validation F1 Score: 0.4706
#   Test F1 Score: 0.4615
#   Train Recall: 0.8387
#   Validation Recall: 0.5714
#   Test Recall: 0.6000
#   Train Precision: 0.3133
#   Validation Precision: 0.4000
#   Test Precision: 0.3750
#   Train ROC AUC: 0.7970
#   Validation ROC AUC: 0.7024
#   Test ROC AUC: 0.6529
#   Train PR AUC: 0.5855
#   Validation PR AUC: 0.5206
#   Test PR AUC: 0.5330
#
# Fold 4:
#   Training set: X shape = (351, 15), Y shape = (351,), Size = 351
#   Validation set:  X shape = (43, 15), Y shape = (43,), Size = 43
#   Testing set:  X shape = (44, 15), Y shape = (44,), Size = 44
#
# Fold 4 - Class Distribution in Test Set:
#   Total samples: 44
#   Class Counts:
# wildfire_frequency
# 0    32
# 1    12
# Name: count, dtype: int64
#   Majority Class: 0
#   Majority Class Count: 32
#
# Baseline Metric Calculations:
#   Accuracy: 0.7272727272727273
#   Precision: 0.2727272727272727
#   Recall: 1.0
#   F1 Score: 0.42857142857142855
#   F1.5 Score: 0.5492957746478873
#   ROC AUC: 0.5
#   PR AUC: 0.6363636363636364
# Fitting 5 folds for each of 96 candidates, totalling 480 fits
# Fold 4 -> Best Params: {'model__max_depth': 1, 'model__max_features': 0.25, 'model__n_estimators': 30}
#   Train Accuracy: 0.6182
#   Validation Accuracy: 0.7442
#   Test Accuracy: 0.6136
#   Train F-beta Score: 0.5071
#   Validation F-beta Score: 0.7610
#   Test F-beta Score: 0.6250
#   Train F1 Score: 0.3964
#   Validation F1 Score: 0.6857
#   Test F1 Score: 0.5405
#   Train Recall: 0.9167
#   Validation Recall: 0.9231
#   Test Recall: 0.8333
#   Train Precision: 0.2529
#   Validation Precision: 0.5455
#   Test Precision: 0.4000
#   Train ROC AUC: 0.7438
#   Validation ROC AUC: 0.7949
#   Test ROC AUC: 0.6823
#   Train PR AUC: 0.5905
#   Validation PR AUC: 0.7459
#   Test PR AUC: 0.6394
#
# Fold 5:
#   Training set: X shape = (438, 15), Y shape = (438,), Size = 438
#   Validation set:  X shape = (43, 15), Y shape = (43,), Size = 43
#   Testing set:  X shape = (44, 15), Y shape = (44,), Size = 44
#
# Fold 5 - Class Distribution in Test Set:
#   Total samples: 44
#   Class Counts:
# wildfire_frequency
# 0    27
# 1    17
# Name: count, dtype: int64
#   Majority Class: 0
#   Majority Class Count: 27
#
# Baseline Metric Calculations:
#   Accuracy: 0.6136363636363636
#   Precision: 0.38636363636363635
#   Recall: 1.0
#   F1 Score: 0.5573770491803279
#   F1.5 Score: 0.6717325227963526
#   ROC AUC: 0.5
#   PR AUC: 0.6931818181818181
# Fitting 5 folds for each of 96 candidates, totalling 480 fits
# Fold 5 -> Best Params: {'model__max_depth': 1, 'model__max_features': 0.75, 'model__n_estimators': 3}
#   Train Accuracy: 0.6963
#   Validation Accuracy: 0.6977
#   Test Accuracy: 0.5227
#   Train F-beta Score: 0.5664
#   Validation F-beta Score: 0.4745
#   Test F-beta Score: 0.4464
#   Train F1 Score: 0.4743
#   Validation F1 Score: 0.4348
#   Test F1 Score: 0.4324
#   Train Recall: 0.8219
#   Validation Recall: 0.5556
#   Test Recall: 0.4706
#   Train Precision: 0.3333
#   Validation Precision: 0.3571
#   Test Precision: 0.4000
#   Train ROC AUC: 0.7466
#   Validation ROC AUC: 0.6454
#   Test ROC AUC: 0.5131
#   Train PR AUC: 0.5925
#   Validation PR AUC: 0.5029
#   Test PR AUC: 0.5376
#
# Overall Metrics:
# Accuracy - Train: Mean = 0.7122, Std Dev = 0.1084
# Accuracy - Validation: Mean = 0.7442, Std Dev = 0.0886
# Accuracy - Test: Mean = 0.6455, Std Dev = 0.1241
# F-beta Score - Train: Mean = 0.4503, Std Dev = 0.1305
# F-beta Score - Validation: Mean = 0.4961, Std Dev = 0.2142
# F-beta Score - Test: Mean = 0.4995, Std Dev = 0.0884
# F1 Score - Train: Mean = 0.3680, Std Dev = 0.1057
# F1 Score - Validation: Mean = 0.4547, Std Dev = 0.2155
# F1 Score - Test: Mean = 0.4638, Std Dev = 0.1123
# Recall - Train: Mean = 0.7484, Std Dev = 0.2490
# Recall - Validation: Mean = 0.7243, Std Dev = 0.2184
# Recall - Test: Mean = 0.6317, Std Dev = 0.1784
# Precision - Train: Mean = 0.2543, Std Dev = 0.0735
# Precision - Validation: Mean = 0.3866, Std Dev = 0.2049
# Precision - Test: Mean = 0.4380, Std Dev = 0.2392
# ROC AUC - Train: Mean = 0.7245, Std Dev = 0.0689
# ROC AUC - Validation: Mean = 0.7392, Std Dev = 0.0675
# ROC AUC - Test: Mean = 0.6459, Std Dev = 0.0774
# PR AUC - Train: Mean = 0.5136, Std Dev = 0.1296
# PR AUC - Validation: Mean = 0.5810, Std Dev = 0.1003
# PR AUC - Test: Mean = 0.5849, Std Dev = 0.0879
#
# Baseline Metrics per Fold:
# Fold 1: {'Accuracy': 0.8863636363636364, 'Precision': 0.11363636363636363, 'Recall': 1.0, 'F1': 0.20408163265306123, 'F1.5': 0.29411764705882354, 'ROC AUC': 0.5, 'PR AUC': 0.5568181818181818}
# Fold 2: {'Accuracy': 0.75, 'Precision': 0.25, 'Recall': 1.0, 'F1': 0.4, 'F1.5': 0.52, 'ROC AUC': 0.5, 'PR AUC': 0.625}
# Fold 3: {'Accuracy': 0.7727272727272727, 'Precision': 0.22727272727272727, 'Recall': 1.0, 'F1': 0.37037037037037035, 'F1.5': 0.4887218045112782, 'ROC AUC': 0.5, 'PR AUC': 0.6136363636363636}
# Fold 4: {'Accuracy': 0.7272727272727273, 'Precision': 0.2727272727272727, 'Recall': 1.0, 'F1': 0.42857142857142855, 'F1.5': 0.5492957746478873, 'ROC AUC': 0.5, 'PR AUC': 0.6363636363636364}
# Fold 5: {'Accuracy': 0.6136363636363636, 'Precision': 0.38636363636363635, 'Recall': 1.0, 'F1': 0.5573770491803279, 'F1.5': 0.6717325227963526, 'ROC AUC': 0.5, 'PR AUC': 0.6931818181818181}

# %%
print(forest_baseline_metrics)
# Out:
# {1: {'Accuracy': 0.8863636363636364, 'Precision': 0.11363636363636363, 'Recall': 1.0, 'F1': 0.20408163265306123, 'F1.5': 0.29411764705882354, 'ROC AUC': 0.5, 'PR AUC': 0.5568181818181818}, 2: {'Accuracy': 0.75, 'Precision': 0.25, 'Recall': 1.0, 'F1': 0.4, 'F1.5': 0.52, 'ROC AUC': 0.5, 'PR AUC': 0.625}, 3: {'Accuracy': 0.7727272727272727, 'Precision': 0.22727272727272727, 'Recall': 1.0, 'F1': 0.37037037037037035, 'F1.5': 0.4887218045112782, 'ROC AUC': 0.5, 'PR AUC': 0.6136363636363636}, 4: {'Accuracy': 0.7272727272727273, 'Precision': 0.2727272727272727, 'Recall': 1.0, 'F1': 0.42857142857142855, 'F1.5': 0.5492957746478873, 'ROC AUC': 0.5, 'PR AUC': 0.6363636363636364}, 5: {'Accuracy': 0.6136363636363636, 'Precision': 0.38636363636363635, 'Recall': 1.0, 'F1': 0.5573770491803279, 'F1.5': 0.6717325227963526, 'ROC AUC': 0.5, 'PR AUC': 0.6931818181818181}}

# %%
print(forest_means)
print(forest_stds)
# Out:
# {'forest_accuracy_mean': {'train': 0.7121799547269712, 'val': 0.7441860465116279, 'test': 0.6454545454545455}, 'forest_f_beta_score_mean': {'train': 0.450328109914364, 'val': 0.49610845473848036, 'test': 0.4994556331971694}, 'forest_f1_score_mean': {'train': 0.3680457425468097, 'val': 0.4547249624487476, 'test': 0.4638086049850756}, 'forest_recall_mean': {'train': 0.7484258634280728, 'val': 0.7242979242979242, 'test': 0.6316934046345811}, 'forest_precision_mean': {'train': 0.2543364261644278, 'val': 0.3865699006875477, 'test': 0.438030303030303}, 'forest_roc_auc_mean': {'train': 0.7244679688553812, 'val': 0.7392498024850966, 'test': 0.6459313439828145}, 'forest_pr_auc_mean': {'train': 0.5135785787332943, 'val': 0.5810153078415732, 'test': 0.584861853832442}}
# {'forest_accuracy_std': {'train': 0.10842335495962621, 'val': 0.08855550123097565, 'test': 0.12406676421778345}, 'forest_f_beta_score_std': {'train': 0.13047164661772623, 'val': 0.21417494057184935, 'test': 0.08837338434658755}, 'forest_f1_score_std': {'train': 0.10566374243619947, 'val': 0.2154620729625347, 'test': 0.11227174869501672}, 'forest_recall_std': {'train': 0.24895915968599636, 'val': 0.21836711634549585, 'test': 0.17841420528889168}, 'forest_precision_std': {'train': 0.07353779185231442, 'val': 0.20486645701202533, 'test': 0.2391519202410982}, 'forest_roc_auc_std': {'train': 0.06886163528305876, 'val': 0.06748647545472855, 'test': 0.0773737774529814}, 'forest_pr_auc_std': {'train': 0.12955483158349232, 'val': 0.10030715320981262, 'test': 0.08792161705851818}}

# %% [markdown]
# #### SVC

# %%
y = df_binary_no_missing_values['wildfire_frequency']
X = df_binary_no_missing_values.drop(columns=['wildfire_frequency'])

# %%
# svc with validation
# F1 scorer
scorer = make_scorer(f1_score)

# param_grid
param_grid = {
    'model__gamma': [0.00001, 0.0005, 0.001, 0.01, 0.1, 1, 10, 100, 1000],
    'model__C': [100, 10, 1, 0.1, 0.01, 0.001, 0.0001]
}

metrics = {
    "Accuracy": accuracy_score,
    "F-beta Score": lambda y_true, y_pred: fbeta_score(y_true, y_pred, beta=1.5),
    "F1 Score": f1_score,
    "Recall": recall_score,
    "Precision": precision_score,
    "ROC AUC": roc_auc_score,
    "PR AUC": lambda y_true, y_pred: compute_pr_auc(y_true, y_pred)
}

tscv = TimeSeriesSplit(n_splits=5)

best_models_svc = []

class_distributions = {}
svc_baseline_metrics = {}
svc_means = {}
svc_stds = {}

# Function to consistently format metric names
def format_metric_name(metric_name):
    return re.sub(r'[^a-zA-Z0-9]+', '_', metric_name.lower())
    
# initialise scores dictionaries
scores_per_fold = {f"train_{format_metric_name(name)}": [] for name in metrics}
scores_per_fold.update({f"test_{format_metric_name(name)}": [] for name in metrics})
scores_per_fold.update({f"val_{format_metric_name(name)}": [] for name in metrics})  # Add validation scores

# data splitting, model training, & evaluation
for fold_idx, (train_index, test_index) in enumerate(tscv.split(X), start=1):
    # Split data into train and test sets
    X_train = X.iloc[train_index]
    Y_train = Y.iloc[train_index]
    X_test_full = X.iloc[test_index]
    Y_test_full = Y.iloc[test_index]

    # Split the test set into 10% validation and 10% test (chronologically)
    split_point = len(X_test_full) // 2
    X_val = X_test_full.iloc[:split_point]
    Y_val = Y_test_full.iloc[:split_point]
    
    X_test = X_test_full.iloc[split_point:]
    Y_test = Y_test_full.iloc[split_point:]

    print(f"\nFold {fold_idx}:")
    print(f"  Training set: X shape = {X_train.shape}, Y shape = {Y_train.shape}, Size = {X_train.shape[0]}")
    print(f"  Validation set:  X shape = {X_val.shape}, Y shape = {Y_val.shape}, Size = {X_val.shape[0]}")
    print(f"  Testing set:  X shape = {X_test.shape}, Y shape = {Y_test.shape}, Size = {X_test.shape[0]}")
    
    # Count class occurrences in Y_test
    class_counts = Y_test.value_counts()
    total = len(Y_test)
    majority_class = class_counts.idxmax()
    majority_class_count = class_counts.max()
    num_class_1 = class_counts.get(1, 0)
    num_class_0 = class_counts.get(0, 0)
    baseline_probs = [1 if majority_class == 1 else 0] * len(Y_test)
    precision_baseline, recall_baseline, _ = precision_recall_curve(Y_test, baseline_probs)

    # Debugging prints for class distribution
    print(f"\nFold {fold_idx} - Class Distribution in Test Set:")
    print(f"  Total samples: {total}")
    print(f"  Class Counts:\n{class_counts}")
    print(f"  Majority Class: {majority_class}")
    print(f"  Majority Class Count: {majority_class_count}")
    
    # Store class distribution
    class_distributions[fold_idx] = {
        "Class 0": num_class_0,
        "Class 1": num_class_1
    }

    # baseline metrics: predicting all points as class 1
    accuracy = majority_class_count / total
    precision = num_class_1 / (num_class_1 + num_class_0)
    recall = (num_class_1 / total) / (num_class_1/ total + 0)
    f1 = 2 * (precision * recall) / (precision + recall)
    f1_5 = (1 + 1.5**2) * (precision * recall) / ((1.5**2 * precision) + recall)
    roc_auc = roc_auc_score(Y_test, baseline_probs)
    pr_auc = auc(recall_baseline, precision_baseline)

    print("\nBaseline Metric Calculations:")
    print(f"  Accuracy: {accuracy}")
    print(f"  Precision: {precision}")
    print(f"  Recall: {recall}")
    print(f"  F1 Score: {f1}")
    print(f"  F1.5 Score: {f1_5}")
    print(f"  ROC AUC: {roc_auc}")
    print(f"  PR AUC: {pr_auc}")
    
    svc_baseline_metrics[fold_idx] = {
        "Accuracy": accuracy,
        "Precision": precision,
        "Recall": recall,
        "F1": f1,
        "F1.5": f1_5,
        "ROC AUC": roc_auc,
        "PR AUC": pr_auc
    }
    
    # pipeline
    pipeline = Pipeline([
        ('scaler', StandardScaler()),  
        ('model', SVC(class_weight='balanced', probability=True, random_state=1))
    ])
    
    # GridSearchCV with tscv
    grid_search = GridSearchCV(
        estimator=pipeline,
        param_grid=param_grid,
        cv=tscv,
        scoring=scorer,
        refit=True,  # refit best model on the full training data
        n_jobs=-1,  
        verbose=1
    )
    
    with warnings.catch_warnings():
        warnings.simplefilter("ignore")
        grid_search.fit(X_train, Y_train)
    
    # Use the validation set to select the best model
    best_model_idx = np.argmax([grid_search.score(X_val, Y_val) for model in grid_search.cv_results_['params']])

    # find best parameters using X_train
    best_params = grid_search.best_params_
    best_model_svc = grid_search.best_estimator_
    print(f"Fold {fold_idx} -> Best Params: {best_params}")

    # Evaluate the best model on the validation set (X_val, Y_val)
    y_val_pred_probs = best_model_svc.predict_proba(X_val)[:, 1]
    y_val_pred = best_model_svc.predict(X_val)

    #evalualte on X_train 
    y_train_pred = best_model_svc.predict(X_train)

    # Evaluate on X_test
    y_test_pred_probs = best_model_svc.predict_proba(X_test)[:, 1]
    y_test_pred = best_model_svc.predict(X_test)

    # predict probabilities (needed for PR AUC calculation)
    y_pred_probs = best_model_svc.predict_proba(X_test)[:, 1]  # Get probabilities for class 1
    
    # calculate PR AUC for the test set
    pr_auc_value = compute_pr_auc(Y_test, y_pred_probs)

    #calculate confusion matrix for each fold
    cm = confusion_matrix(Y_test, y_test_pred, labels=[0, 1])
        
    # Plot confusion matrix
    plt.figure(figsize=(6, 5))
    sns.heatmap(cm, annot=True, fmt="d", cmap="Blues", xticklabels=[0, 1], yticklabels=[0, 1])
    plt.xlabel("Predicted")
    plt.ylabel("Actual")
    plt.title(f"Confusion Matrix for SVC - Fold {fold_idx}")
    plt.show()
    
    #for loop for calculating train & test metrics
    #print(f"Fold {fold_idx} metrics:")
    for name, func in metrics.items():
        formatted_name = format_metric_name(name)
    
        # Train metrics
        train_score = func(Y_train, y_train_pred)
        print(f"  Train {name}: {train_score:.4f}")
        scores_per_fold[f"train_{formatted_name}"].append(train_score)

        # Validation metrics
        val_score = func(Y_val, y_val_pred)
        print(f"  Validation {name}: {val_score:.4f}")
        scores_per_fold[f"val_{formatted_name}"].append(val_score)
        
        # Test metrics
        test_score = func(Y_test, y_test_pred)
        print(f"  Test {name}: {test_score:.4f}")
        scores_per_fold[f"test_{formatted_name}"].append(test_score)

# Calculate and save mean and std metrics
print("\nOverall Metrics:")
for metric_name in metrics:
    formatted_name = format_metric_name(metric_name)
    train_key = f"train_{formatted_name}"
    val_key = f"val_{formatted_name}"
    test_key = f"test_{formatted_name}"
    
    avg_train = np.mean(scores_per_fold[train_key])
    std_train = np.std(scores_per_fold[train_key], ddof=1)
    avg_val = np.mean(scores_per_fold[val_key])
    std_val = np.std(scores_per_fold[val_key], ddof=1)
    avg_test = np.mean(scores_per_fold[test_key])
    std_test = np.std(scores_per_fold[test_key], ddof=1)

    # Save to dictionaries for model comparison
    svc_means[f"svc_{formatted_name}_mean"] = {
        "train": avg_train,
        "val": avg_val,
        "test": avg_test
    }
    svc_stds[f"svc_{formatted_name}_std"] = {
        "train": std_train,
        "val": std_val,
        "test": std_test
    }
        
    print(f"{metric_name} - Train: Mean = {avg_train:.4f}, Std Dev = {std_train:.4f}")
    print(f"{metric_name} - Validation: Mean = {avg_val:.4f}, Std Dev = {std_val:.4f}")
    print(f"{metric_name} - Test: Mean = {avg_test:.4f}, Std Dev = {std_test:.4f}")

#print baselines at the end for each fold:
print("\nBaseline Metrics per Fold:")
for fold, metrics in svc_baseline_metrics.items():
    print(f"Fold {fold}: {metrics}")
# Out:
# Fold 1:
#   Training set: X shape = (90, 15), Y shape = (90,), Size = 90
#   Validation set:  X shape = (43, 15), Y shape = (43,), Size = 43
#   Testing set:  X shape = (44, 15), Y shape = (44,), Size = 44
#
# Fold 1 - Class Distribution in Test Set:
#   Total samples: 44
#   Class Counts:
# wildfire_frequency
# 0    39
# 1     5
# Name: count, dtype: int64
#   Majority Class: 0
#   Majority Class Count: 39
#
# Baseline Metric Calculations:
#   Accuracy: 0.8863636363636364
#   Precision: 0.11363636363636363
#   Recall: 1.0
#   F1 Score: 0.20408163265306123
#   F1.5 Score: 0.29411764705882354
#   ROC AUC: 0.5
#   PR AUC: 0.5568181818181818
# Fitting 5 folds for each of 63 candidates, totalling 315 fits
# Fold 1 -> Best Params: {'model__C': 100, 'model__gamma': 1e-05}
#   Train Accuracy: 0.4556
#   Validation Accuracy: 0.4651
#   Test Accuracy: 0.4545
#   Train F-beta Score: 0.3171
#   Validation F-beta Score: 0.1238
#   Test F-beta Score: 0.3399
#   Train F1 Score: 0.2222
#   Validation F1 Score: 0.0800
#   Test F1 Score: 0.2500
#   Train Recall: 1.0000
#   Validation Recall: 1.0000
#   Test Recall: 0.8000
#   Train Precision: 0.1250
#   Validation Precision: 0.0417
#   Test Precision: 0.1481
#   Train ROC AUC: 0.7048
#   Validation ROC AUC: 0.7262
#   Test ROC AUC: 0.6051
#   Train PR AUC: 0.5625
#   Validation PR AUC: 0.5208
#   Test PR AUC: 0.4854
#
# Fold 2:
#   Training set: X shape = (177, 15), Y shape = (177,), Size = 177
#   Validation set:  X shape = (43, 15), Y shape = (43,), Size = 43
#   Testing set:  X shape = (44, 15), Y shape = (44,), Size = 44
#
# Fold 2 - Class Distribution in Test Set:
#   Total samples: 44
#   Class Counts:
# wildfire_frequency
# 0    33
# 1    11
# Name: count, dtype: int64
#   Majority Class: 0
#   Majority Class Count: 33
#
# Baseline Metric Calculations:
#   Accuracy: 0.75
#   Precision: 0.25
#   Recall: 1.0
#   F1 Score: 0.4
#   F1.5 Score: 0.52
#   ROC AUC: 0.5
#   PR AUC: 0.625
# Fitting 5 folds for each of 63 candidates, totalling 315 fits
# Fold 2 -> Best Params: {'model__C': 10, 'model__gamma': 0.0005}
#   Train Accuracy: 0.6667
#   Validation Accuracy: 0.6744
#   Test Accuracy: 0.7727
#   Train F-beta Score: 0.3929
#   Validation F-beta Score: 0.5612
#   Test F-beta Score: 0.6541
#   Train F1 Score: 0.2892
#   Validation F1 Score: 0.4615
#   Test F1 Score: 0.6154
#   Train Recall: 0.9231
#   Validation Recall: 0.8571
#   Test Recall: 0.7273
#   Train Precision: 0.1714
#   Validation Precision: 0.3158
#   Test Precision: 0.5333
#   Train ROC AUC: 0.7847
#   Validation ROC AUC: 0.7480
#   Test ROC AUC: 0.7576
#   Train PR AUC: 0.5501
#   Validation PR AUC: 0.5981
#   Test PR AUC: 0.6644
#
# Fold 3:
#   Training set: X shape = (264, 15), Y shape = (264,), Size = 264
#   Validation set:  X shape = (43, 15), Y shape = (43,), Size = 43
#   Testing set:  X shape = (44, 15), Y shape = (44,), Size = 44
#
# Fold 3 - Class Distribution in Test Set:
#   Total samples: 44
#   Class Counts:
# wildfire_frequency
# 0    34
# 1    10
# Name: count, dtype: int64
#   Majority Class: 0
#   Majority Class Count: 34
#
# Baseline Metric Calculations:
#   Accuracy: 0.7727272727272727
#   Precision: 0.22727272727272727
#   Recall: 1.0
#   F1 Score: 0.37037037037037035
#   F1.5 Score: 0.4887218045112782
#   ROC AUC: 0.5
#   PR AUC: 0.6136363636363636
# Fitting 5 folds for each of 63 candidates, totalling 315 fits
# Fold 3 -> Best Params: {'model__C': 0.1, 'model__gamma': 0.01}
#   Train Accuracy: 0.6326
#   Validation Accuracy: 0.6512
#   Test Accuracy: 0.6136
#   Train F-beta Score: 0.4625
#   Validation F-beta Score: 0.5455
#   Test F-beta Score: 0.5230
#   Train F1 Score: 0.3576
#   Validation F1 Score: 0.4444
#   Test F1 Score: 0.4516
#   Train Recall: 0.8710
#   Validation Recall: 0.8571
#   Test Recall: 0.7000
#   Train Precision: 0.2250
#   Validation Precision: 0.3000
#   Test Precision: 0.3333
#   Train ROC AUC: 0.7359
#   Validation ROC AUC: 0.7341
#   Test ROC AUC: 0.6441
#   Train PR AUC: 0.5556
#   Validation PR AUC: 0.5902
#   Test PR AUC: 0.5508
#
# Fold 4:
#   Training set: X shape = (351, 15), Y shape = (351,), Size = 351
#   Validation set:  X shape = (43, 15), Y shape = (43,), Size = 43
#   Testing set:  X shape = (44, 15), Y shape = (44,), Size = 44
#
# Fold 4 - Class Distribution in Test Set:
#   Total samples: 44
#   Class Counts:
# wildfire_frequency
# 0    32
# 1    12
# Name: count, dtype: int64
#   Majority Class: 0
#   Majority Class Count: 32
#
# Baseline Metric Calculations:
#   Accuracy: 0.7272727272727273
#   Precision: 0.2727272727272727
#   Recall: 1.0
#   F1 Score: 0.42857142857142855
#   F1.5 Score: 0.5492957746478873
#   ROC AUC: 0.5
#   PR AUC: 0.6363636363636364
# Fitting 5 folds for each of 63 candidates, totalling 315 fits
# Fold 4 -> Best Params: {'model__C': 10, 'model__gamma': 0.01}
#   Train Accuracy: 0.7550
#   Validation Accuracy: 0.7674
#   Test Accuracy: 0.7273
#   Train F-beta Score: 0.6197
#   Validation F-beta Score: 0.6610
#   Test F-beta Score: 0.6500
#   Train F1 Score: 0.5114
#   Validation F1 Score: 0.6429
#   Test F1 Score: 0.6000
#   Train Recall: 0.9375
#   Validation Recall: 0.6923
#   Test Recall: 0.7500
#   Train Precision: 0.3516
#   Validation Precision: 0.6000
#   Test Precision: 0.5000
#   Train ROC AUC: 0.8318
#   Validation ROC AUC: 0.7462
#   Test ROC AUC: 0.7344
#   Train PR AUC: 0.6488
#   Validation PR AUC: 0.6927
#   Test PR AUC: 0.6591
#
# Fold 5:
#   Training set: X shape = (438, 15), Y shape = (438,), Size = 438
#   Validation set:  X shape = (43, 15), Y shape = (43,), Size = 43
#   Testing set:  X shape = (44, 15), Y shape = (44,), Size = 44
#
# Fold 5 - Class Distribution in Test Set:
#   Total samples: 44
#   Class Counts:
# wildfire_frequency
# 0    27
# 1    17
# Name: count, dtype: int64
#   Majority Class: 0
#   Majority Class Count: 27
#
# Baseline Metric Calculations:
#   Accuracy: 0.6136363636363636
#   Precision: 0.38636363636363635
#   Recall: 1.0
#   F1 Score: 0.5573770491803279
#   F1.5 Score: 0.6717325227963526
#   ROC AUC: 0.5
#   PR AUC: 0.6931818181818181
# Fitting 5 folds for each of 63 candidates, totalling 315 fits
# Fold 5 -> Best Params: {'model__C': 10, 'model__gamma': 0.01}
#   Train Accuracy: 0.7557
#   Validation Accuracy: 0.6977
#   Test Accuracy: 0.6136
#   Train F-beta Score: 0.6495
#   Validation F-beta Score: 0.6460
#   Test F-beta Score: 0.6265
#   Train F1 Score: 0.5523
#   Validation F1 Score: 0.5517
#   Test F1 Score: 0.5854
#   Train Recall: 0.9041
#   Validation Recall: 0.8889
#   Test Recall: 0.7059
#   Train Precision: 0.3976
#   Validation Precision: 0.4000
#   Test Precision: 0.5000
#   Train ROC AUC: 0.8151
#   Validation ROC AUC: 0.7680
#   Test ROC AUC: 0.6307
#   Train PR AUC: 0.6588
#   Validation PR AUC: 0.6561
#   Test PR AUC: 0.6598
#
# Overall Metrics:
# Accuracy - Train: Mean = 0.6531, Std Dev = 0.1230
# Accuracy - Validation: Mean = 0.6512, Std Dev = 0.1127
# Accuracy - Test: Mean = 0.6364, Std Dev = 0.1234
# F-beta Score - Train: Mean = 0.4883, Std Dev = 0.1435
# F-beta Score - Validation: Mean = 0.5075, Std Dev = 0.2204
# F-beta Score - Test: Mean = 0.5587, Std Dev = 0.1334
# F1 Score - Train: Mean = 0.3865, Std Dev = 0.1418
# F1 Score - Validation: Mean = 0.4361, Std Dev = 0.2143
# F1 Score - Test: Mean = 0.5005, Std Dev = 0.1545
# Recall - Train: Mean = 0.9271, Std Dev = 0.0477
# Recall - Validation: Mean = 0.8591, Std Dev = 0.1102
# Recall - Test: Mean = 0.7366, Std Dev = 0.0405
# Precision - Train: Mean = 0.2541, Std Dev = 0.1167
# Precision - Validation: Mean = 0.3315, Std Dev = 0.2013
# Precision - Test: Mean = 0.4030, Std Dev = 0.1625
# ROC AUC - Train: Mean = 0.7745, Std Dev = 0.0533
# ROC AUC - Validation: Mean = 0.7445, Std Dev = 0.0159
# ROC AUC - Test: Mean = 0.6744, Std Dev = 0.0673
# PR AUC - Train: Mean = 0.5952, Std Dev = 0.0539
# PR AUC - Validation: Mean = 0.6116, Std Dev = 0.0660
# PR AUC - Test: Mean = 0.6039, Std Dev = 0.0817
#
# Baseline Metrics per Fold:
# Fold 1: {'Accuracy': 0.8863636363636364, 'Precision': 0.11363636363636363, 'Recall': 1.0, 'F1': 0.20408163265306123, 'F1.5': 0.29411764705882354, 'ROC AUC': 0.5, 'PR AUC': 0.5568181818181818}
# Fold 2: {'Accuracy': 0.75, 'Precision': 0.25, 'Recall': 1.0, 'F1': 0.4, 'F1.5': 0.52, 'ROC AUC': 0.5, 'PR AUC': 0.625}
# Fold 3: {'Accuracy': 0.7727272727272727, 'Precision': 0.22727272727272727, 'Recall': 1.0, 'F1': 0.37037037037037035, 'F1.5': 0.4887218045112782, 'ROC AUC': 0.5, 'PR AUC': 0.6136363636363636}
# Fold 4: {'Accuracy': 0.7272727272727273, 'Precision': 0.2727272727272727, 'Recall': 1.0, 'F1': 0.42857142857142855, 'F1.5': 0.5492957746478873, 'ROC AUC': 0.5, 'PR AUC': 0.6363636363636364}
# Fold 5: {'Accuracy': 0.6136363636363636, 'Precision': 0.38636363636363635, 'Recall': 1.0, 'F1': 0.5573770491803279, 'F1.5': 0.6717325227963526, 'ROC AUC': 0.5, 'PR AUC': 0.6931818181818181}

# %%
print("Keys in svc_means:", svc_means.keys())
print("Keys in svc_stds:", svc_stds.keys())
# Out:
# Keys in svc_means: dict_keys(['svc_accuracy_mean', 'svc_f_beta_score_mean', 'svc_f1_score_mean', 'svc_recall_mean', 'svc_precision_mean', 'svc_roc_auc_mean', 'svc_pr_auc_mean'])
# Keys in svc_stds: dict_keys(['svc_accuracy_std', 'svc_f_beta_score_std', 'svc_f1_score_std', 'svc_recall_std', 'svc_precision_std', 'svc_roc_auc_std', 'svc_pr_auc_std'])

# %%
print(svc_baseline_metrics)
# Out:
# {1: {'Accuracy': 0.8863636363636364, 'Precision': 0.11363636363636363, 'Recall': 1.0, 'F1': 0.20408163265306123, 'F1.5': 0.29411764705882354, 'ROC AUC': 0.5, 'PR AUC': 0.5568181818181818}, 2: {'Accuracy': 0.75, 'Precision': 0.25, 'Recall': 1.0, 'F1': 0.4, 'F1.5': 0.52, 'ROC AUC': 0.5, 'PR AUC': 0.625}, 3: {'Accuracy': 0.7727272727272727, 'Precision': 0.22727272727272727, 'Recall': 1.0, 'F1': 0.37037037037037035, 'F1.5': 0.4887218045112782, 'ROC AUC': 0.5, 'PR AUC': 0.6136363636363636}, 4: {'Accuracy': 0.7272727272727273, 'Precision': 0.2727272727272727, 'Recall': 1.0, 'F1': 0.42857142857142855, 'F1.5': 0.5492957746478873, 'ROC AUC': 0.5, 'PR AUC': 0.6363636363636364}, 5: {'Accuracy': 0.6136363636363636, 'Precision': 0.38636363636363635, 'Recall': 1.0, 'F1': 0.5573770491803279, 'F1.5': 0.6717325227963526, 'ROC AUC': 0.5, 'PR AUC': 0.6931818181818181}}

# %%
print(svc_means)
print(svc_stds)
# Out:
# {'svc_accuracy_mean': {'train': 0.6530982994681624, 'val': 0.6511627906976745, 'test': 0.6363636363636365}, 'svc_f_beta_score_mean': {'train': 0.48833644104919915, 'val': 0.5074789660945114, 'test': 0.5586903722407458}, 'svc_f1_score_mean': {'train': 0.38653192687234866, 'val': 0.4361128373542167, 'test': 0.5004726744537917}, 'svc_recall_mean': {'train': 0.9271308508107005, 'val': 0.8590964590964593, 'test': 0.7366310160427808}, 'svc_precision_mean': {'train': 0.2541162865748709, 'val': 0.3314912280701754, 'test': 0.402962962962963}, 'svc_roc_auc_mean': {'train': 0.7744592645304718, 'val': 0.744492207139266, 'test': 0.6743831128022305}, 'svc_pr_auc_mean': {'train': 0.5951565663300322, 'val': 0.6115729133507591, 'test': 0.6038878985937809}}
# {'svc_accuracy_std': {'train': 0.1230225248622438, 'val': 0.11273674087014718, 'test': 0.12344068740000246}, 'svc_f_beta_score_std': {'train': 0.1434693701716923, 'val': 0.22038418001578186, 'test': 0.13341141345748134}, 'svc_f1_score_std': {'train': 0.14175523891299943, 'val': 0.21426701312222896, 'test': 0.1544677413465714}, 'svc_recall_std': {'train': 0.0477444755457297, 'val': 0.11019020210549184, 'test': 0.04052544585622974}, 'svc_precision_std': {'train': 0.11665826857735985, 'val': 0.201262845157456, 'test': 0.16248667772761397}, 'svc_roc_auc_std': {'train': 0.05332939615540943, 'val': 0.0158820363326162, 'test': 0.06734025926179726}, 'svc_pr_auc_std': {'train': 0.05385233656069568, 'val': 0.06600830204330234, 'test': 0.0816750445800202}}

# %% [markdown]
# #### Evaluation Plots

# %%
# initialise lists to store means and standard deviations for plotting
svc_means_list = []
svc_stds_list = []

# List of metrics to iterate over
metrics = [
    'accuracy', 'f_beta_score', 'f1_score', 'recall', 'precision', 'roc_auc', 'pr_auc'
]

# Extract means and standard deviations for the "test" set from the dictionary
for metric_name in metrics:
    # Construct the keys for means and standard deviations
    mean_key = f"svc_{metric_name}_mean"
    std_key = f"svc_{metric_name}_std"
    
    # Access the test mean and standard deviation if they exist
    if mean_key in svc_means and std_key in svc_stds:
        svc_means_list.append(svc_means[mean_key]["test"])
        svc_stds_list.append(svc_stds[std_key]["test"])
    else:
        print(f"Warning: Key '{mean_key}' or '{std_key}' not found in dictionaries.")

# Debugging: Check the lengths of both lists
print("Length of svc_means_list:", len(svc_means_list))
print("Length of svc_stds_list:", len(svc_stds_list))

# Ensure that both lists have the same length before plotting
if len(svc_means_list) == len(svc_stds_list):
    # Now you have svc_means_list and svc_stds_list with the correct order for plotting
    print("Means:", svc_means_list)
    print("Standard Deviations:", svc_stds_list)

    # Plot the means with error bars
    plt.figure(figsize=(10, 6))
    metrics_labels = metrics  # Use the metric names as labels

    # Plot the means with error bars (standard deviation)
    plt.bar(metrics_labels, svc_means_list, yerr=svc_stds_list, capsize=5, color='skyblue', alpha=0.7)
    plt.xlabel('Metrics')
    plt.ylabel('Scores')
    plt.title('Metrics for Best Model (SVC)')
    plt.xticks(rotation=45, ha='right')
    plt.tight_layout()
    plt.show()
else:
    print("Error: Length mismatch between means and standard deviations.")
# Out:
# Length of svc_means_list: 7
# Length of svc_stds_list: 7
# Means: [0.6363636363636365, 0.5586903722407458, 0.5004726744537917, 0.7366310160427808, 0.402962962962963, 0.6743831128022305, 0.6038878985937809]
# Standard Deviations: [0.12344068740000246, 0.13341141345748134, 0.1544677413465714, 0.04052544585622974, 0.16248667772761397, 0.06734025926179726, 0.0816750445800202]

# %%
# Define the metrics and models
metrics = ['accuracy', 'f_beta_score', 'f1_score', 'recall', 'precision', 'roc_auc', 'pr_auc']
models = ['logistic_regression', 'forest', 'xgb', 'svc']

# Prepare empty lists to store means and stds for each model and metric
means = []
stds = []

# Iterate over each model and metric to collect the data from the pre-defined dictionaries
for model in models:
    model_means = []
    model_stds = []
    for metric in metrics:
        # Construct the keys dynamically to fetch the means and stds from the pre-defined dictionaries
        mean_key = f"{model}_{metric}_mean"
        std_key = f"{model}_{metric}_std"
        
        # Check if the key exists before trying to access it
        try:
            # Ensure you're selecting the 'test' key
            model_means.append(eval(f"{model}_means")[mean_key]['test'])
            model_stds.append(eval(f"{model}_stds")[std_key]['test'])
        except KeyError as e:
            print(f"KeyError: {e}. Could not find the key {mean_key} or {std_key}.")
            model_means.append(np.nan)  # Append NaN if the key doesn't exist
            model_stds.append(np.nan)  # Append NaN if the key doesn't exist
    
    # Append the model's means and stds to the lists
    means.append(model_means)
    stds.append(model_stds)

# Convert lists to numpy arrays for easier plotting
means = np.array(means)
stds = np.array(stds)

# Define the positions of the bars
x = np.arange(len(metrics))  # the label locations
width = 0.2  # width of the bars

# Create the plot
fig, ax = plt.subplots(figsize=(10, 6))

# Plot bars for each model
bars_logistic = ax.bar(x - 1.5 * width, means[0], width, yerr=stds[0], label='Logistic Regression', color='b', capsize=5)
bars_forest = ax.bar(x - 0.5 * width, means[1], width, yerr=stds[1], label='Random Forest', color='g', capsize=5)
bars_xgb = ax.bar(x + 0.5 * width, means[2], width, yerr=stds[2], label='XGBoost', color='r', capsize=5)
bars_svc = ax.bar(x + 1.5 * width, means[3], width, yerr=stds[3], label='SVC', color='c', capsize=5)

# Add labels, title, and custom x-axis tick labels
ax.set_xlabel('Metrics')
ax.set_ylabel('Scores')
ax.set_title('Comparison of Model Performance Across Metrics')
ax.set_xticks(x)
ax.set_xticklabels(metrics)
ax.legend()

# Show the plot
plt.tight_layout()
plt.show()

# %%
# Define the metrics and models
metrics = ['accuracy', 'f_beta_score', 'f1_score', 'recall', 'precision', 'roc_auc', 'pr_auc']
models = ['logistic_regression', 'forest', 'xgb', 'svc']

# Prepare empty lists to store means and stds for each model and metric
means = []
stds = []

baselines = [0.750, 0.505, 0.392, 1.0, 0.250, 0.5, 0.625]

# Iterate over each model and metric to collect the data from the pre-defined dictionaries
for model in models:
    model_means = []
    model_stds = []
    for metric in metrics:
        # Construct the keys dynamically to fetch the means and stds from the pre-defined dictionaries
        mean_key = f"{model}_{metric}_mean"
        std_key = f"{model}_{metric}_std"
        
        # Check if the key exists before trying to access it
        try:
            # Ensure you're selecting the 'test' key
            model_means.append(eval(f"{model}_means")[mean_key]['test'])
            model_stds.append(eval(f"{model}_stds")[std_key]['test'])
        except KeyError as e:
            print(f"KeyError: {e}. Could not find the key {mean_key} or {std_key}.")
            model_means.append(np.nan)  # Append NaN if the key doesn't exist
            model_stds.append(np.nan)  # Append NaN if the key doesn't exist
    
    # Append the model's means and stds to the lists
    means.append(model_means)
    stds.append(model_stds)

# Convert lists to numpy arrays for easier plotting
means = np.array(means)
stds = np.array(stds)

# Define the positions of the bars
x = np.arange(len(metrics))  # the label locations
width = 0.2  # width of the bars

# Create the plot
fig, ax = plt.subplots(figsize=(10, 6))

# Plot bars for each model
bars_logistic = ax.bar(x - 1.5 * width, means[0], width, yerr=stds[0], label='Logistic Regression', color='lightblue', capsize=5)
bars_forest = ax.bar(x - 0.5 * width, means[1], width, yerr=stds[1], label='Random Forest', color='darkseagreen', capsize=5)
bars_xgb = ax.bar(x + 0.5 * width, means[2], width, yerr=stds[2], label='XGBoost', color='rosybrown', capsize=5)
bars_svc = ax.bar(x + 1.5 * width, means[3], width, yerr=stds[3], label='SVC', color='lightpink', capsize=5)

for i, baseline in enumerate(baselines):
    ax.hlines(y=baseline, xmin=x[i] - 2 * width, xmax=x[i] + 2 * width, colors='red', linestyles='dashed', label=None if i > 0 else 'Baseline')

# Add labels, title, and custom x-axis tick labels
ax.set_xlabel('Metrics')
ax.set_ylabel('Scores')
ax.set_title('Comparison of Model Performance Across Metrics')
ax.set_xticks(x)
ax.set_ylim(0, 1)
ax.set_xticklabels(metrics)
ax.legend()

plt.savefig('ML_mean_std_metrics.png')

# Show the plot
plt.tight_layout()
plt.show()

# %% [markdown]
# #### Best Model Logistic Regression

# %%
# new logistic regression with validation
# F1 scorer
f1_scorer = make_scorer(f1_score)

# param_grid
param_grid = {
    'model__C': np.logspace(-2, 2, 21), 
    'model__penalty': ['l2', None],
    'model__solver': ['saga', 'sag', 'lbfgs', 'newton-cg']
}

metrics = {
    "Accuracy": accuracy_score,
    "F-beta Score": lambda y_true, y_pred: fbeta_score(y_true, y_pred, beta=1.5),
    "F1 Score": f1_score,
    "Recall": recall_score,
    "Precision": precision_score,
    "ROC AUC": roc_auc_score,
    "PR AUC": lambda y_true, y_pred: compute_pr_auc(y_true, y_pred)
}

tscv = TimeSeriesSplit(n_splits=5)

best_models_logistic_regression = []

class_distributions = {}
logistic_regression_baseline_metrics = {}
logistic_regression_means = {}
logistic_regression_stds = {}

# Function to consistently format metric names
def format_metric_name(metric_name):
    return re.sub(r'[^a-zA-Z0-9]+', '_', metric_name.lower())
    
# initialise scores dictionaries
scores_per_fold = {f"train_{format_metric_name(name)}": [] for name in metrics}
scores_per_fold.update({f"test_{format_metric_name(name)}": [] for name in metrics})
scores_per_fold.update({f"val_{format_metric_name(name)}": [] for name in metrics})  # Add validation scores

# data splitting, model training, & evaluation
for fold_idx, (train_index, test_index) in enumerate(tscv.split(X), start=1):
    # Split data into train and test sets
    X_train = X.iloc[train_index]
    Y_train = Y.iloc[train_index]
    X_test_full = X.iloc[test_index]
    Y_test_full = Y.iloc[test_index]

    # Split the test set into 10% validation and 10% test (chronologically)
    split_point = len(X_test_full) // 2
    X_val = X_test_full.iloc[:split_point]
    Y_val = Y_test_full.iloc[:split_point]
    
    X_test = X_test_full.iloc[split_point:]
    Y_test = Y_test_full.iloc[split_point:]

    print(f"\nFold {fold_idx}:")
    print(f"  Training set: X shape = {X_train.shape}, Y shape = {Y_train.shape}, Size = {X_train.shape[0]}")
    print(f"  Validation set:  X shape = {X_val.shape}, Y shape = {Y_val.shape}, Size = {X_val.shape[0]}")
    print(f"  Testing set:  X shape = {X_test.shape}, Y shape = {Y_test.shape}, Size = {X_test.shape[0]}")
    
    # Count class occurrences in Y_test
    class_counts = Y_test.value_counts()
    total = len(Y_test)
    majority_class = class_counts.idxmax()
    majority_class_count = class_counts.max()
    num_class_1 = class_counts.get(1, 0)
    num_class_0 = class_counts.get(0, 0)
    baseline_probs = [1 if majority_class == 1 else 0] * len(Y_test)
    precision_baseline, recall_baseline, _ = precision_recall_curve(Y_test, baseline_probs)

    # Debugging prints for class distribution
    print(f"\nFold {fold_idx} - Class Distribution in Test Set:")
    print(f"  Total samples: {total}")
    print(f"  Class Counts:\n{class_counts}")
    print(f"  Majority Class: {majority_class}")
    print(f"  Majority Class Count: {majority_class_count}")
    
   # Store class distribution
    class_distributions[fold_idx] = {
        "Class 0": num_class_0,
        "Class 1": num_class_1
    }

    # baseline metrics: predicting all points as class 1
    accuracy = majority_class_count / total
    precision = num_class_1 / (num_class_1 + num_class_0)
    recall = (num_class_1 / total) / (num_class_1/ total + 0)
    f1 = 2 * (precision * recall) / (precision + recall)
    f1_5 = (1 + 1.5**2) * (precision * recall) / ((1.5**2 * precision) + recall)
    roc_auc = roc_auc_score(Y_test, baseline_probs)
    pr_auc = auc(recall_baseline, precision_baseline)

    print("\nBaseline Metric Calculations:")
    print(f"  Accuracy: {accuracy}")
    print(f"  Precision: {precision}")
    print(f"  Recall: {recall}")
    print(f"  F1 Score: {f1}")
    print(f"  F1.5 Score: {f1_5}")
    print(f"  ROC AUC: {roc_auc}")
    print(f"  PR AUC: {pr_auc}")
    
    logistic_regression_baseline_metrics[fold_idx] = {
        "Accuracy": accuracy,
        "Precision": precision,
        "Recall": recall,
        "F1": f1,
        "F1.5": f1_5,
        "ROC AUC": roc_auc,
        "PR AUC": pr_auc
    }
    
    # pipeline
    pipeline = Pipeline([
        ('scaler', StandardScaler()),  
        ('model', LogisticRegression(class_weight='balanced', max_iter=1000, tol=1e-4, random_state=1))
    ])
    
    # GridSearchCV with tscv
    grid_search = GridSearchCV(
        estimator=pipeline,
        param_grid=param_grid,
        cv=tscv,
        scoring=f1_scorer,
        refit=True,  # refit best model on the full training data
        n_jobs=-1,  
        verbose=1
    )
    
    with warnings.catch_warnings():
        warnings.simplefilter("ignore")
        grid_search.fit(X_train, Y_train)
    
    # Use the validation set to select the best model
    best_model_idx = np.argmax([grid_search.score(X_val, Y_val) for model in grid_search.cv_results_['params']])

    # find best parameters using X_train
    best_params = grid_search.best_params_
    best_model_logistic_regression = grid_search.best_estimator_
    print(f"Fold {fold_idx} -> Best Params: {best_params}")

    # Evaluate the best model on the validation set (X_val, Y_val)
    y_val_pred_probs = best_model_logistic_regression.predict_proba(X_val)[:, 1]
    y_val_pred = best_model_logistic_regression.predict(X_val)

    #evalualte on X_train 
    y_train_pred = best_model_logistic_regression.predict(X_train)

    # Evaluate on X_test
    y_test_pred_probs = best_model_logistic_regression.predict_proba(X_test)[:, 1]
    y_test_pred = best_model_logistic_regression.predict(X_test)

    # predict probabilities (needed for PR AUC calculation)
    y_pred_probs = best_model_logistic_regression.predict_proba(X_test)[:, 1]  # Get probabilities for class 1
    
    # calculate PR AUC for the test set
    pr_auc_value = compute_pr_auc(Y_test, y_pred_probs)

    #generate confusion matrix for each fold
    cm = confusion_matrix(Y_test, y_test_pred, labels=[0, 1])
        
    # Plot confusion matrix
    plt.figure(figsize=(6, 5))
    sns.heatmap(cm, annot=True, fmt="d", cmap="Blues", xticklabels=[0, 1], yticklabels=[0, 1])
    plt.xlabel("Predicted")
    plt.ylabel("Actual")
    plt.title(f"Confusion Matrix for Logistic Regression - Fold {fold_idx}")

    #save as high-quality image
    plt.savefig(f"logistic_regression_{fold_idx}.png")
    
    plt.show()
    
    #for loop for calculating train & test metrics
    #print(f"Fold {fold_idx} metrics:")
    for name, func in metrics.items():
        formatted_name = format_metric_name(name)
    
        # Train metrics
        train_score = func(Y_train, y_train_pred)
        print(f"  Train {name}: {train_score:.4f}")
        scores_per_fold[f"train_{formatted_name}"].append(train_score)

        # Validation metrics
        val_score = func(Y_val, y_val_pred)
        print(f"  Validation {name}: {val_score:.4f}")
        scores_per_fold[f"val_{formatted_name}"].append(val_score)
        
        # Test metrics
        test_score = func(Y_test, y_test_pred)
        print(f"  Test {name}: {test_score:.4f}")
        scores_per_fold[f"test_{formatted_name}"].append(test_score)

# Calculate and save mean and std metrics
print("\nOverall Metrics:")
for metric_name in metrics:
    formatted_name = format_metric_name(metric_name)
    train_key = f"train_{formatted_name}"
    val_key = f"val_{formatted_name}"
    test_key = f"test_{formatted_name}"
    
    avg_train = np.mean(scores_per_fold[train_key])
    std_train = np.std(scores_per_fold[train_key], ddof=1)
    avg_val = np.mean(scores_per_fold[val_key])
    std_val = np.std(scores_per_fold[val_key], ddof=1)
    avg_test = np.mean(scores_per_fold[test_key])
    std_test = np.std(scores_per_fold[test_key], ddof=1)

    # Save to dictionaries for model comparison
    logistic_regression_means[f"logistic_regression_{formatted_name}_mean"] = {
        "train": avg_train,
        "val": avg_val,
        "test": avg_test
    }
    logistic_regression_stds[f"logistic_regression_{formatted_name}_std"] = {
        "train": std_train,
        "val": std_val,
        "test": std_test
    }
        
    print(f"{metric_name} - Train: Mean = {avg_train:.4f}, Std Dev = {std_train:.4f}")
    print(f"{metric_name} - Validation: Mean = {avg_val:.4f}, Std Dev = {std_val:.4f}")
    print(f"{metric_name} - Test: Mean = {avg_test:.4f}, Std Dev = {std_test:.4f}")

#print baselines at the end for each fold:
print("\nBaseline Metrics per Fold:")
for fold, metrics in logistic_regression_baseline_metrics.items():
    print(f"Fold {fold}: {metrics}")
# Out:
# Fold 1:
#   Training set: X shape = (90, 15), Y shape = (90,), Size = 90
#   Validation set:  X shape = (43, 15), Y shape = (43,), Size = 43
#   Testing set:  X shape = (44, 15), Y shape = (44,), Size = 44
#
# Fold 1 - Class Distribution in Test Set:
#   Total samples: 44
#   Class Counts:
# wildfire_frequency
# 0    39
# 1     5
# Name: count, dtype: int64
#   Majority Class: 0
#   Majority Class Count: 39
#
# Baseline Metric Calculations:
#   Accuracy: 0.8863636363636364
#   Precision: 0.11363636363636363
#   Recall: 1.0
#   F1 Score: 0.20408163265306123
#   F1.5 Score: 0.29411764705882354
#   ROC AUC: 0.5
#   PR AUC: 0.5568181818181818
# Fitting 5 folds for each of 168 candidates, totalling 840 fits
# Fold 1 -> Best Params: {'model__C': 0.1, 'model__penalty': 'l2', 'model__solver': 'saga'}
#   Train Accuracy: 0.8222
#   Validation Accuracy: 0.7674
#   Test Accuracy: 0.6818
#   Train F-beta Score: 0.5871
#   Validation F-beta Score: 0.2453
#   Test F-beta Score: 0.1461
#   Train F1 Score: 0.4667
#   Validation F1 Score: 0.1667
#   Test F1 Score: 0.1250
#   Train Recall: 1.0000
#   Validation Recall: 1.0000
#   Test Recall: 0.2000
#   Train Precision: 0.3043
#   Validation Precision: 0.0909
#   Test Precision: 0.0909
#   Train ROC AUC: 0.9036
#   Validation ROC AUC: 0.8810
#   Test ROC AUC: 0.4718
#   Train PR AUC: 0.6522
#   Validation PR AUC: 0.5455
#   Test PR AUC: 0.1909
#
# Fold 2:
#   Training set: X shape = (177, 15), Y shape = (177,), Size = 177
#   Validation set:  X shape = (43, 15), Y shape = (43,), Size = 43
#   Testing set:  X shape = (44, 15), Y shape = (44,), Size = 44
#
# Fold 2 - Class Distribution in Test Set:
#   Total samples: 44
#   Class Counts:
# wildfire_frequency
# 0    33
# 1    11
# Name: count, dtype: int64
#   Majority Class: 0
#   Majority Class Count: 33
#
# Baseline Metric Calculations:
#   Accuracy: 0.75
#   Precision: 0.25
#   Recall: 1.0
#   F1 Score: 0.4
#   F1.5 Score: 0.52
#   ROC AUC: 0.5
#   PR AUC: 0.625
# Fitting 5 folds for each of 168 candidates, totalling 840 fits
# Fold 2 -> Best Params: {'model__C': 0.15848931924611143, 'model__penalty': 'l2', 'model__solver': 'sag'}
#   Train Accuracy: 0.7966
#   Validation Accuracy: 0.7907
#   Test Accuracy: 0.8182
#   Train F-beta Score: 0.4815
#   Validation F-beta Score: 0.6555
#   Test F-beta Score: 0.6887
#   Train F1 Score: 0.3793
#   Validation F1 Score: 0.5714
#   Test F1 Score: 0.6667
#   Train Recall: 0.8462
#   Validation Recall: 0.8571
#   Test Recall: 0.7273
#   Train Precision: 0.2444
#   Validation Precision: 0.4286
#   Test Precision: 0.6154
#   Train ROC AUC: 0.8194
#   Validation ROC AUC: 0.8175
#   Test ROC AUC: 0.7879
#   Train PR AUC: 0.5509
#   Validation PR AUC: 0.6545
#   Test PR AUC: 0.7054
#
# Fold 3:
#   Training set: X shape = (264, 15), Y shape = (264,), Size = 264
#   Validation set:  X shape = (43, 15), Y shape = (43,), Size = 43
#   Testing set:  X shape = (44, 15), Y shape = (44,), Size = 44
#
# Fold 3 - Class Distribution in Test Set:
#   Total samples: 44
#   Class Counts:
# wildfire_frequency
# 0    34
# 1    10
# Name: count, dtype: int64
#   Majority Class: 0
#   Majority Class Count: 34
#
# Baseline Metric Calculations:
#   Accuracy: 0.7727272727272727
#   Precision: 0.22727272727272727
#   Recall: 1.0
#   F1 Score: 0.37037037037037035
#   F1.5 Score: 0.4887218045112782
#   ROC AUC: 0.5
#   PR AUC: 0.6136363636363636
# Fitting 5 folds for each of 168 candidates, totalling 840 fits
# Fold 3 -> Best Params: {'model__C': 0.6309573444801934, 'model__penalty': 'l2', 'model__solver': 'lbfgs'}
#   Train Accuracy: 0.7652
#   Validation Accuracy: 0.8140
#   Test Accuracy: 0.6818
#   Train F-beta Score: 0.5670
#   Validation F-beta Score: 0.6783
#   Test F-beta Score: 0.5617
#   Train F1 Score: 0.4655
#   Validation F1 Score: 0.6000
#   Test F1 Score: 0.5000
#   Train Recall: 0.8710
#   Validation Recall: 0.8571
#   Test Recall: 0.7000
#   Train Precision: 0.3176
#   Validation Precision: 0.4615
#   Test Precision: 0.3889
#   Train ROC AUC: 0.8110
#   Validation ROC AUC: 0.8313
#   Test ROC AUC: 0.6882
#   Train PR AUC: 0.6019
#   Validation PR AUC: 0.6710
#   Test PR AUC: 0.5785
#
# Fold 4:
#   Training set: X shape = (351, 15), Y shape = (351,), Size = 351
#   Validation set:  X shape = (43, 15), Y shape = (43,), Size = 43
#   Testing set:  X shape = (44, 15), Y shape = (44,), Size = 44
#
# Fold 4 - Class Distribution in Test Set:
#   Total samples: 44
#   Class Counts:
# wildfire_frequency
# 0    32
# 1    12
# Name: count, dtype: int64
#   Majority Class: 0
#   Majority Class Count: 32
#
# Baseline Metric Calculations:
#   Accuracy: 0.7272727272727273
#   Precision: 0.2727272727272727
#   Recall: 1.0
#   F1 Score: 0.42857142857142855
#   F1.5 Score: 0.5492957746478873
#   ROC AUC: 0.5
#   PR AUC: 0.6363636363636364
# Fitting 5 folds for each of 168 candidates, totalling 840 fits
# Fold 4 -> Best Params: {'model__C': 39.810717055349734, 'model__penalty': 'l2', 'model__solver': 'saga'}
#   Train Accuracy: 0.7635
#   Validation Accuracy: 0.7907
#   Test Accuracy: 0.7273
#   Train F-beta Score: 0.5735
#   Validation F-beta Score: 0.6303
#   Test F-beta Score: 0.6047
#   Train F1 Score: 0.4845
#   Validation F1 Score: 0.6400
#   Test F1 Score: 0.5714
#   Train Recall: 0.8125
#   Validation Recall: 0.6154
#   Test Recall: 0.6667
#   Train Precision: 0.3451
#   Validation Precision: 0.6667
#   Test Precision: 0.5000
#   Train ROC AUC: 0.7841
#   Validation ROC AUC: 0.7410
#   Test ROC AUC: 0.7083
#   Train PR AUC: 0.5916
#   Validation PR AUC: 0.6992
#   Test PR AUC: 0.6288
#
# Fold 5:
#   Training set: X shape = (438, 15), Y shape = (438,), Size = 438
#   Validation set:  X shape = (43, 15), Y shape = (43,), Size = 43
#   Testing set:  X shape = (44, 15), Y shape = (44,), Size = 44
#
# Fold 5 - Class Distribution in Test Set:
#   Total samples: 44
#   Class Counts:
# wildfire_frequency
# 0    27
# 1    17
# Name: count, dtype: int64
#   Majority Class: 0
#   Majority Class Count: 27
#
# Baseline Metric Calculations:
#   Accuracy: 0.6136363636363636
#   Precision: 0.38636363636363635
#   Recall: 1.0
#   F1 Score: 0.5573770491803279
#   F1.5 Score: 0.6717325227963526
#   ROC AUC: 0.5
#   PR AUC: 0.6931818181818181
# Fitting 5 folds for each of 168 candidates, totalling 840 fits
# Fold 5 -> Best Params: {'model__C': 1.584893192461114, 'model__penalty': 'l2', 'model__solver': 'saga'}
#   Train Accuracy: 0.7580
#   Validation Accuracy: 0.7442
#   Test Accuracy: 0.6364
#   Train F-beta Score: 0.6018
#   Validation F-beta Score: 0.6797
#   Test F-beta Score: 0.6367
#   Train F1 Score: 0.5225
#   Validation F1 Score: 0.5926
#   Test F1 Score: 0.6000
#   Train Recall: 0.7945
#   Validation Recall: 0.8889
#   Test Recall: 0.7059
#   Train Precision: 0.3893
#   Validation Precision: 0.4444
#   Test Precision: 0.5217
#   Train ROC AUC: 0.7726
#   Validation ROC AUC: 0.7974
#   Test ROC AUC: 0.6492
#   Train PR AUC: 0.6090
#   Validation PR AUC: 0.6783
#   Test PR AUC: 0.6706
#
# Overall Metrics:
# Accuracy - Train: Mean = 0.7811, Std Dev = 0.0275
# Accuracy - Validation: Mean = 0.7814, Std Dev = 0.0265
# Accuracy - Test: Mean = 0.7091, Std Dev = 0.0689
# F-beta Score - Train: Mean = 0.5622, Std Dev = 0.0470
# F-beta Score - Validation: Mean = 0.5778, Std Dev = 0.1870
# F-beta Score - Test: Mean = 0.5276, Std Dev = 0.2183
# F1 Score - Train: Mean = 0.4637, Std Dev = 0.0525
# F1 Score - Validation: Mean = 0.5141, Std Dev = 0.1958
# F1 Score - Test: Mean = 0.4926, Std Dev = 0.2140
# Recall - Train: Mean = 0.8648, Std Dev = 0.0811
# Recall - Validation: Mean = 0.8437, Std Dev = 0.1405
# Recall - Test: Mean = 0.6000, Std Dev = 0.2246
# Precision - Train: Mean = 0.3202, Std Dev = 0.0534
# Precision - Validation: Mean = 0.4184, Std Dev = 0.2071
# Precision - Test: Mean = 0.4234, Std Dev = 0.2026
# ROC AUC - Train: Mean = 0.8182, Std Dev = 0.0514
# ROC AUC - Validation: Mean = 0.8136, Std Dev = 0.0510
# ROC AUC - Test: Mean = 0.6611, Std Dev = 0.1173
# PR AUC - Train: Mean = 0.6011, Std Dev = 0.0363
# PR AUC - Validation: Mean = 0.6497, Std Dev = 0.0604
# PR AUC - Test: Mean = 0.5549, Std Dev = 0.2089
#
# Baseline Metrics per Fold:
# Fold 1: {'Accuracy': 0.8863636363636364, 'Precision': 0.11363636363636363, 'Recall': 1.0, 'F1': 0.20408163265306123, 'F1.5': 0.29411764705882354, 'ROC AUC': 0.5, 'PR AUC': 0.5568181818181818}
# Fold 2: {'Accuracy': 0.75, 'Precision': 0.25, 'Recall': 1.0, 'F1': 0.4, 'F1.5': 0.52, 'ROC AUC': 0.5, 'PR AUC': 0.625}
# Fold 3: {'Accuracy': 0.7727272727272727, 'Precision': 0.22727272727272727, 'Recall': 1.0, 'F1': 0.37037037037037035, 'F1.5': 0.4887218045112782, 'ROC AUC': 0.5, 'PR AUC': 0.6136363636363636}
# Fold 4: {'Accuracy': 0.7272727272727273, 'Precision': 0.2727272727272727, 'Recall': 1.0, 'F1': 0.42857142857142855, 'F1.5': 0.5492957746478873, 'ROC AUC': 0.5, 'PR AUC': 0.6363636363636364}
# Fold 5: {'Accuracy': 0.6136363636363636, 'Precision': 0.38636363636363635, 'Recall': 1.0, 'F1': 0.5573770491803279, 'F1.5': 0.6717325227963526, 'ROC AUC': 0.5, 'PR AUC': 0.6931818181818181}

# %%
# new logistic regression with validation
# F1 scorer
f1_scorer = make_scorer(f1_score)

# param_grid
param_grid = {
    'model__C': np.logspace(-2, 2, 21), 
    'model__penalty': ['l2', None],
    'model__solver': ['saga', 'sag', 'lbfgs', 'newton-cg']
}

metrics = {
    "Accuracy": accuracy_score,
    "F-beta Score": lambda y_true, y_pred: fbeta_score(y_true, y_pred, beta=1.5),
    "F1 Score": f1_score,
    "Recall": recall_score,
    "Precision": precision_score,
    "ROC AUC": roc_auc_score,
    "PR AUC": lambda y_true, y_pred: compute_pr_auc(y_true, y_pred)
}

tscv = TimeSeriesSplit(n_splits=5)

best_models_logistic_regression = []

class_distributions = {}
logistic_regression_baseline_metrics = {}
logistic_regression_means = {}
logistic_regression_stds = {}

# Function to consistently format metric names
def format_metric_name(metric_name):
    return re.sub(r'[^a-zA-Z0-9]+', '_', metric_name.lower())
    
# initialise scores dictionaries
scores_per_fold = {f"train_{format_metric_name(name)}": [] for name in metrics}
scores_per_fold.update({f"test_{format_metric_name(name)}": [] for name in metrics})
scores_per_fold.update({f"val_{format_metric_name(name)}": [] for name in metrics})  # Add validation scores

# data splitting, model training, & evaluation
for fold_idx, (train_index, test_index) in enumerate(tscv.split(X), start=1):
    # Split data into train and test sets
    X_train = X.iloc[train_index]
    Y_train = Y.iloc[train_index]
    X_test_full = X.iloc[test_index]
    Y_test_full = Y.iloc[test_index]

    # Split the test set into 10% validation and 10% test (chronologically)
    split_point = len(X_test_full) // 2
    X_val = X_test_full.iloc[:split_point]
    Y_val = Y_test_full.iloc[:split_point]
    
    X_test = X_test_full.iloc[split_point:]
    Y_test = Y_test_full.iloc[split_point:]

    print(f"\nFold {fold_idx}:")
    print(f"  Training set: X shape = {X_train.shape}, Y shape = {Y_train.shape}, Size = {X_train.shape[0]}")
    print(f"  Validation set:  X shape = {X_val.shape}, Y shape = {Y_val.shape}, Size = {X_val.shape[0]}")
    print(f"  Testing set:  X shape = {X_test.shape}, Y shape = {Y_test.shape}, Size = {X_test.shape[0]}")
    
    # Count class occurrences in Y_test
    class_counts = Y_test.value_counts()
    total = len(Y_test)
    majority_class = class_counts.idxmax()
    majority_class_count = class_counts.max()
    num_class_1 = class_counts.get(1, 0)
    num_class_0 = class_counts.get(0, 0)
    baseline_probs = [1 if majority_class == 1 else 0] * len(Y_test)
    precision_baseline, recall_baseline, _ = precision_recall_curve(Y_test, baseline_probs)

    # Debugging prints for class distribution
    print(f"\nFold {fold_idx} - Class Distribution in Test Set:")
    print(f"  Total samples: {total}")
    print(f"  Class Counts:\n{class_counts}")
    print(f"  Majority Class: {majority_class}")
    print(f"  Majority Class Count: {majority_class_count}")
    
   # Store class distribution
    class_distributions[fold_idx] = {
        "Class 0": num_class_0,
        "Class 1": num_class_1
    }

    # baseline metrics: predicting all points as class 1
    accuracy = majority_class_count / total
    precision = num_class_1 / (num_class_1 + num_class_0)
    recall = (num_class_1 / total) / (num_class_1/ total + 0)
    f1 = 2 * (precision * recall) / (precision + recall)
    f1_5 = (1 + 1.5**2) * (precision * recall) / ((1.5**2 * precision) + recall)
    roc_auc = roc_auc_score(Y_test, baseline_probs)
    pr_auc = auc(recall_baseline, precision_baseline)

    print("\nBaseline Metric Calculations:")
    print(f"  Accuracy: {accuracy}")
    print(f"  Precision: {precision}")
    print(f"  Recall: {recall}")
    print(f"  F1 Score: {f1}")
    print(f"  F1.5 Score: {f1_5}")
    print(f"  ROC AUC: {roc_auc}")
    print(f"  PR AUC: {pr_auc}")
    
    logistic_regression_baseline_metrics[fold_idx] = {
        "Accuracy": accuracy,
        "Precision": precision,
        "Recall": recall,
        "F1": f1,
        "F1.5": f1_5,
        "ROC AUC": roc_auc,
        "PR AUC": pr_auc
    }
    
    # pipeline
    pipeline = Pipeline([
        ('scaler', StandardScaler()),  
        ('model', LogisticRegression(class_weight='balanced', max_iter=1000, tol=1e-4, random_state=1))
    ])
    
    # GridSearchCV with tscv
    grid_search = GridSearchCV(
        estimator=pipeline,
        param_grid=param_grid,
        cv=tscv,
        scoring=f1_scorer,
        refit=True,  # refit best model on the full training data
        n_jobs=-1,  
        verbose=1
    )
    
    with warnings.catch_warnings():
        warnings.simplefilter("ignore")
        grid_search.fit(X_train, Y_train)
    
    # Use the validation set to select the best model
    best_model_idx = np.argmax([grid_search.score(X_val, Y_val) for model in grid_search.cv_results_['params']])

    # find best parameters using X_train
    best_params = grid_search.best_params_
    best_model_logistic_regression = grid_search.best_estimator_
    print(f"Fold {fold_idx} -> Best Params: {best_params}")

    # Evaluate the best model on the validation set (X_val, Y_val)
    y_val_pred_probs = best_model_logistic_regression.predict_proba(X_val)[:, 1]
    y_val_pred = best_model_logistic_regression.predict(X_val)

    #evalualte on X_train 
    y_train_pred = best_model_logistic_regression.predict(X_train)

    # Evaluate on X_test
    y_test_pred_probs = best_model_logistic_regression.predict_proba(X_test)[:, 1]
    y_test_pred = best_model_logistic_regression.predict(X_test)

    # predict probabilities (needed for PR AUC calculation)
    y_pred_probs = best_model_logistic_regression.predict_proba(X_test)[:, 1]  # Get probabilities for class 1
    
    # calculate PR AUC for the test set
    pr_auc_value = compute_pr_auc(Y_test, y_pred_probs)

    #generate confusion matrix for each fold
    cm = confusion_matrix(Y_test, y_test_pred, labels=[0, 1])
        
    # Plot confusion matrix
    plt.figure(figsize=(6, 5))
    sns.heatmap(cm, annot=True, fmt="d", cmap="Blues", xticklabels=[0, 1], yticklabels=[0, 1])
    plt.xlabel("Predicted")
    plt.ylabel("Actual")
    plt.title(f"Confusion Matrix for Logistic Regression - Fold {fold_idx}")
    plt.show()
    
    #for loop for calculating train & test metrics
    #print(f"Fold {fold_idx} metrics:")
    for name, func in metrics.items():
        formatted_name = format_metric_name(name)
    
        # Train metrics
        train_score = func(Y_train, y_train_pred)
        print(f"  Train {name}: {train_score:.4f}")
        scores_per_fold[f"train_{formatted_name}"].append(train_score)

        # Validation metrics
        val_score = func(Y_val, y_val_pred)
        print(f"  Validation {name}: {val_score:.4f}")
        scores_per_fold[f"val_{formatted_name}"].append(val_score)
        
        # Test metrics
        test_score = func(Y_test, y_test_pred)
        print(f"  Test {name}: {test_score:.4f}")
        scores_per_fold[f"test_{formatted_name}"].append(test_score)

# Calculate and save mean and std metrics
print("\nOverall Metrics:")
for metric_name in metrics:
    formatted_name = format_metric_name(metric_name)
    train_key = f"train_{formatted_name}"
    val_key = f"val_{formatted_name}"
    test_key = f"test_{formatted_name}"
    
    avg_train = np.mean(scores_per_fold[train_key])
    std_train = np.std(scores_per_fold[train_key], ddof=1)
    avg_val = np.mean(scores_per_fold[val_key])
    std_val = np.std(scores_per_fold[val_key], ddof=1)
    avg_test = np.mean(scores_per_fold[test_key])
    std_test = np.std(scores_per_fold[test_key], ddof=1)

    # Save to dictionaries for model comparison
    logistic_regression_means[f"logistic_regression_{formatted_name}_mean"] = {
        "train": avg_train,
        "val": avg_val,
        "test": avg_test
    }
    logistic_regression_stds[f"logistic_regression_{formatted_name}_std"] = {
        "train": std_train,
        "val": std_val,
        "test": std_test
    }
        
    print(f"{metric_name} - Train: Mean = {avg_train:.4f}, Std Dev = {std_train:.4f}")
    print(f"{metric_name} - Validation: Mean = {avg_val:.4f}, Std Dev = {std_val:.4f}")
    print(f"{metric_name} - Test: Mean = {avg_test:.4f}, Std Dev = {std_test:.4f}")

#print baselines at the end for each fold:
print("\nBaseline Metrics per Fold:")
for fold, metrics in logistic_regression_baseline_metrics.items():
    print(f"Fold {fold}: {metrics}")
# Out:
# Fold 1:
#   Training set: X shape = (90, 15), Y shape = (90,), Size = 90
#   Validation set:  X shape = (43, 15), Y shape = (43,), Size = 43
#   Testing set:  X shape = (44, 15), Y shape = (44,), Size = 44
#
# Fold 1 - Class Distribution in Test Set:
#   Total samples: 44
#   Class Counts:
# wildfire_frequency
# 0    39
# 1     5
# Name: count, dtype: int64
#   Majority Class: 0
#   Majority Class Count: 39
#
# Baseline Metric Calculations:
#   Accuracy: 0.8863636363636364
#   Precision: 0.11363636363636363
#   Recall: 1.0
#   F1 Score: 0.20408163265306123
#   F1.5 Score: 0.29411764705882354
#   ROC AUC: 0.5
#   PR AUC: 0.5568181818181818
# Fitting 5 folds for each of 168 candidates, totalling 840 fits
# Fold 1 -> Best Params: {'model__C': 0.1, 'model__penalty': 'l2', 'model__solver': 'saga'}
#   Train Accuracy: 0.8222
#   Validation Accuracy: 0.7674
#   Test Accuracy: 0.6818
#   Train F-beta Score: 0.5871
#   Validation F-beta Score: 0.2453
#   Test F-beta Score: 0.1461
#   Train F1 Score: 0.4667
#   Validation F1 Score: 0.1667
#   Test F1 Score: 0.1250
#   Train Recall: 1.0000
#   Validation Recall: 1.0000
#   Test Recall: 0.2000
#   Train Precision: 0.3043
#   Validation Precision: 0.0909
#   Test Precision: 0.0909
#   Train ROC AUC: 0.9036
#   Validation ROC AUC: 0.8810
#   Test ROC AUC: 0.4718
#   Train PR AUC: 0.6522
#   Validation PR AUC: 0.5455
#   Test PR AUC: 0.1909
#
# Fold 2:
#   Training set: X shape = (177, 15), Y shape = (177,), Size = 177
#   Validation set:  X shape = (43, 15), Y shape = (43,), Size = 43
#   Testing set:  X shape = (44, 15), Y shape = (44,), Size = 44
#
# Fold 2 - Class Distribution in Test Set:
#   Total samples: 44
#   Class Counts:
# wildfire_frequency
# 0    33
# 1    11
# Name: count, dtype: int64
#   Majority Class: 0
#   Majority Class Count: 33
#
# Baseline Metric Calculations:
#   Accuracy: 0.75
#   Precision: 0.25
#   Recall: 1.0
#   F1 Score: 0.4
#   F1.5 Score: 0.52
#   ROC AUC: 0.5
#   PR AUC: 0.625
# Fitting 5 folds for each of 168 candidates, totalling 840 fits
# Fold 2 -> Best Params: {'model__C': 0.15848931924611143, 'model__penalty': 'l2', 'model__solver': 'sag'}
#   Train Accuracy: 0.7966
#   Validation Accuracy: 0.7907
#   Test Accuracy: 0.8182
#   Train F-beta Score: 0.4815
#   Validation F-beta Score: 0.6555
#   Test F-beta Score: 0.6887
#   Train F1 Score: 0.3793
#   Validation F1 Score: 0.5714
#   Test F1 Score: 0.6667
#   Train Recall: 0.8462
#   Validation Recall: 0.8571
#   Test Recall: 0.7273
#   Train Precision: 0.2444
#   Validation Precision: 0.4286
#   Test Precision: 0.6154
#   Train ROC AUC: 0.8194
#   Validation ROC AUC: 0.8175
#   Test ROC AUC: 0.7879
#   Train PR AUC: 0.5509
#   Validation PR AUC: 0.6545
#   Test PR AUC: 0.7054
#
# Fold 3:
#   Training set: X shape = (264, 15), Y shape = (264,), Size = 264
#   Validation set:  X shape = (43, 15), Y shape = (43,), Size = 43
#   Testing set:  X shape = (44, 15), Y shape = (44,), Size = 44
#
# Fold 3 - Class Distribution in Test Set:
#   Total samples: 44
#   Class Counts:
# wildfire_frequency
# 0    34
# 1    10
# Name: count, dtype: int64
#   Majority Class: 0
#   Majority Class Count: 34
#
# Baseline Metric Calculations:
#   Accuracy: 0.7727272727272727
#   Precision: 0.22727272727272727
#   Recall: 1.0
#   F1 Score: 0.37037037037037035
#   F1.5 Score: 0.4887218045112782
#   ROC AUC: 0.5
#   PR AUC: 0.6136363636363636
# Fitting 5 folds for each of 168 candidates, totalling 840 fits
# Fold 3 -> Best Params: {'model__C': 0.6309573444801934, 'model__penalty': 'l2', 'model__solver': 'lbfgs'}
#   Train Accuracy: 0.7652
#   Validation Accuracy: 0.8140
#   Test Accuracy: 0.6818
#   Train F-beta Score: 0.5670
#   Validation F-beta Score: 0.6783
#   Test F-beta Score: 0.5617
#   Train F1 Score: 0.4655
#   Validation F1 Score: 0.6000
#   Test F1 Score: 0.5000
#   Train Recall: 0.8710
#   Validation Recall: 0.8571
#   Test Recall: 0.7000
#   Train Precision: 0.3176
#   Validation Precision: 0.4615
#   Test Precision: 0.3889
#   Train ROC AUC: 0.8110
#   Validation ROC AUC: 0.8313
#   Test ROC AUC: 0.6882
#   Train PR AUC: 0.6019
#   Validation PR AUC: 0.6710
#   Test PR AUC: 0.5785
#
# Fold 4:
#   Training set: X shape = (351, 15), Y shape = (351,), Size = 351
#   Validation set:  X shape = (43, 15), Y shape = (43,), Size = 43
#   Testing set:  X shape = (44, 15), Y shape = (44,), Size = 44
#
# Fold 4 - Class Distribution in Test Set:
#   Total samples: 44
#   Class Counts:
# wildfire_frequency
# 0    32
# 1    12
# Name: count, dtype: int64
#   Majority Class: 0
#   Majority Class Count: 32
#
# Baseline Metric Calculations:
#   Accuracy: 0.7272727272727273
#   Precision: 0.2727272727272727
#   Recall: 1.0
#   F1 Score: 0.42857142857142855
#   F1.5 Score: 0.5492957746478873
#   ROC AUC: 0.5
#   PR AUC: 0.6363636363636364
# Fitting 5 folds for each of 168 candidates, totalling 840 fits
# Fold 4 -> Best Params: {'model__C': 39.810717055349734, 'model__penalty': 'l2', 'model__solver': 'saga'}
#   Train Accuracy: 0.7635
#   Validation Accuracy: 0.7907
#   Test Accuracy: 0.7273
#   Train F-beta Score: 0.5735
#   Validation F-beta Score: 0.6303
#   Test F-beta Score: 0.6047
#   Train F1 Score: 0.4845
#   Validation F1 Score: 0.6400
#   Test F1 Score: 0.5714
#   Train Recall: 0.8125
#   Validation Recall: 0.6154
#   Test Recall: 0.6667
#   Train Precision: 0.3451
#   Validation Precision: 0.6667
#   Test Precision: 0.5000
#   Train ROC AUC: 0.7841
#   Validation ROC AUC: 0.7410
#   Test ROC AUC: 0.7083
#   Train PR AUC: 0.5916
#   Validation PR AUC: 0.6992
#   Test PR AUC: 0.6288
#
# Fold 5:
#   Training set: X shape = (438, 15), Y shape = (438,), Size = 438
#   Validation set:  X shape = (43, 15), Y shape = (43,), Size = 43
#   Testing set:  X shape = (44, 15), Y shape = (44,), Size = 44
#
# Fold 5 - Class Distribution in Test Set:
#   Total samples: 44
#   Class Counts:
# wildfire_frequency
# 0    27
# 1    17
# Name: count, dtype: int64
#   Majority Class: 0
#   Majority Class Count: 27
#
# Baseline Metric Calculations:
#   Accuracy: 0.6136363636363636
#   Precision: 0.38636363636363635
#   Recall: 1.0
#   F1 Score: 0.5573770491803279
#   F1.5 Score: 0.6717325227963526
#   ROC AUC: 0.5
#   PR AUC: 0.6931818181818181
# Fitting 5 folds for each of 168 candidates, totalling 840 fits
# Fold 5 -> Best Params: {'model__C': 1.584893192461114, 'model__penalty': 'l2', 'model__solver': 'saga'}
#   Train Accuracy: 0.7580
#   Validation Accuracy: 0.7442
#   Test Accuracy: 0.6364
#   Train F-beta Score: 0.6018
#   Validation F-beta Score: 0.6797
#   Test F-beta Score: 0.6367
#   Train F1 Score: 0.5225
#   Validation F1 Score: 0.5926
#   Test F1 Score: 0.6000
#   Train Recall: 0.7945
#   Validation Recall: 0.8889
#   Test Recall: 0.7059
#   Train Precision: 0.3893
#   Validation Precision: 0.4444
#   Test Precision: 0.5217
#   Train ROC AUC: 0.7726
#   Validation ROC AUC: 0.7974
#   Test ROC AUC: 0.6492
#   Train PR AUC: 0.6090
#   Validation PR AUC: 0.6783
#   Test PR AUC: 0.6706
#
# Overall Metrics:
# Accuracy - Train: Mean = 0.7811, Std Dev = 0.0275
# Accuracy - Validation: Mean = 0.7814, Std Dev = 0.0265
# Accuracy - Test: Mean = 0.7091, Std Dev = 0.0689
# F-beta Score - Train: Mean = 0.5622, Std Dev = 0.0470
# F-beta Score - Validation: Mean = 0.5778, Std Dev = 0.1870
# F-beta Score - Test: Mean = 0.5276, Std Dev = 0.2183
# F1 Score - Train: Mean = 0.4637, Std Dev = 0.0525
# F1 Score - Validation: Mean = 0.5141, Std Dev = 0.1958
# F1 Score - Test: Mean = 0.4926, Std Dev = 0.2140
# Recall - Train: Mean = 0.8648, Std Dev = 0.0811
# Recall - Validation: Mean = 0.8437, Std Dev = 0.1405
# Recall - Test: Mean = 0.6000, Std Dev = 0.2246
# Precision - Train: Mean = 0.3202, Std Dev = 0.0534
# Precision - Validation: Mean = 0.4184, Std Dev = 0.2071
# Precision - Test: Mean = 0.4234, Std Dev = 0.2026
# ROC AUC - Train: Mean = 0.8182, Std Dev = 0.0514
# ROC AUC - Validation: Mean = 0.8136, Std Dev = 0.0510
# ROC AUC - Test: Mean = 0.6611, Std Dev = 0.1173
# PR AUC - Train: Mean = 0.6011, Std Dev = 0.0363
# PR AUC - Validation: Mean = 0.6497, Std Dev = 0.0604
# PR AUC - Test: Mean = 0.5549, Std Dev = 0.2089
#
# Baseline Metrics per Fold:
# Fold 1: {'Accuracy': 0.8863636363636364, 'Precision': 0.11363636363636363, 'Recall': 1.0, 'F1': 0.20408163265306123, 'F1.5': 0.29411764705882354, 'ROC AUC': 0.5, 'PR AUC': 0.5568181818181818}
# Fold 2: {'Accuracy': 0.75, 'Precision': 0.25, 'Recall': 1.0, 'F1': 0.4, 'F1.5': 0.52, 'ROC AUC': 0.5, 'PR AUC': 0.625}
# Fold 3: {'Accuracy': 0.7727272727272727, 'Precision': 0.22727272727272727, 'Recall': 1.0, 'F1': 0.37037037037037035, 'F1.5': 0.4887218045112782, 'ROC AUC': 0.5, 'PR AUC': 0.6136363636363636}
# Fold 4: {'Accuracy': 0.7272727272727273, 'Precision': 0.2727272727272727, 'Recall': 1.0, 'F1': 0.42857142857142855, 'F1.5': 0.5492957746478873, 'ROC AUC': 0.5, 'PR AUC': 0.6363636363636364}
# Fold 5: {'Accuracy': 0.6136363636363636, 'Precision': 0.38636363636363635, 'Recall': 1.0, 'F1': 0.5573770491803279, 'F1.5': 0.6717325227963526, 'ROC AUC': 0.5, 'PR AUC': 0.6931818181818181}

# %%
# Store coefficient magnitudes for fold 5
if fold_idx == 5:
    # Get the best model
    best_model = grid_search.best_estimator_
    
    # Access the logistic regression model from the pipeline
    model = best_model_logistic_regression.named_steps['model']
    
    # Get the coefficients (absolute values for magnitude)
    coef_magnitudes = np.abs(model.coef_).flatten()  # For binary classification, coef_ is 2D
    
    # Assuming df_binary_no_missing_values is your dataframe, and it contains the feature names in the correct order
    feature_names = X.columns.tolist()
    
    # Create a dictionary to store the feature names and their coefficient magnitudes
    coef_dict = {feature_names[i]: coef_magnitudes[i] for i in range(len(coef_magnitudes))}
    
    print("\nCoefficient Magnitudes for Fold 5:")
    for feature, coef_mag in coef_dict.items():
        print(f"{feature}: {coef_mag:.4f}")

    # Sort the dictionary by coefficient magnitude, from highest to lowest
    sorted_coef_dict = dict(sorted(coef_dict.items(), key=lambda item: item[1], reverse=True))
    
    print("\nCoefficient Magnitudes for Fold 5 (Sorted from Highest to Lowest):")
    for feature, coef_mag in sorted_coef_dict.items():
        print(f"{feature}: {coef_mag:.4f}")
    
    # Optionally, store these coefficients for later use
    logistic_regression_coefficients_fold5 = sorted_coef_dict
# Out:
# Coefficient Magnitudes for Fold 5:
# month: 0.0850
# tmax_degC: 1.0138
# airfrost_days: 1.0189
# totalrain_mm: 0.0558
# totalsun_hours: 0.8534
# tmax_degC_lag_1: 0.1621
# tmax_degC_lag_6: 0.5953
# tmax_degC_lag_12: 2.6935
# totalrain_mm_lag_1: 0.0588
# totalrain_mm_lag_6: 0.1466
# totalrain_mm_lag_12: 0.2837
# totalrain_mm_avg4: 0.3175
# tmax_degC_avg4: 1.1464
# month_sin: 1.9415
# month_cos: 0.2299
#
# Coefficient Magnitudes for Fold 5 (Sorted from Highest to Lowest):
# tmax_degC_lag_12: 2.6935
# month_sin: 1.9415
# tmax_degC_avg4: 1.1464
# airfrost_days: 1.0189
# tmax_degC: 1.0138
# totalsun_hours: 0.8534
# tmax_degC_lag_6: 0.5953
# totalrain_mm_avg4: 0.3175
# totalrain_mm_lag_12: 0.2837
# month_cos: 0.2299
# tmax_degC_lag_1: 0.1621
# totalrain_mm_lag_6: 0.1466
# month: 0.0850
# totalrain_mm_lag_1: 0.0588
# totalrain_mm: 0.0558

# %%
import matplotlib.pyplot as plt
import numpy as np

# Define the features and their coefficient magnitudes
features = [
    "tmax_degC_lag_12", "month_sin", "tmax_degC_avg4", "airfrost_days",
    "tmax_degC", "totalsun_hours", "tmax_degC_lag_6", "totalrain_mm_avg4",
    "totalrain_mm_lag_12", "month_cos", "tmax_degC_lag_1", "totalrain_mm_lag_6",
    "month", "totalrain_mm_lag_1", "totalrain_mm"
]

coefficients = [
    2.6935, 1.9415, 1.1464, 1.0189, 1.0138, 0.8534, 0.5953, 0.3175,
    0.2837, 0.2299, 0.1621, 0.1466, 0.0850, 0.0588, 0.0558
]

# Sort the features and coefficients in descending order of coefficients
sorted_indices = np.argsort(coefficients)[::-1]
sorted_features = [features[i] for i in sorted_indices]
sorted_coefficients = [coefficients[i] for i in sorted_indices]

# Create the horizontal bar chart
plt.figure(figsize=(10, 6))
plt.barh(sorted_features, sorted_coefficients, color="lightblue")

# Add labels and title
plt.xlabel("Coefficient Magnitude")
plt.ylabel("Features")
plt.title("Coefficient Magnitudes for Logistic Regression Fold 5")

# Reverse the y-axis so the highest coefficient is at the top
plt.gca().invert_yaxis()

# Show the plot
plt.tight_layout()
plt.savefig('logistic_regression_coefficient.png')

plt.show()

# %%
# new logistic regression with validation
# F1 scorer
f1_scorer = make_scorer(f1_score)

# param_grid
param_grid = {
    'model__C': np.logspace(-2, 2, 21), 
    'model__penalty': ['l2', None],
    'model__solver': ['saga', 'sag', 'lbfgs', 'newton-cg']
}

metrics = {
    "Accuracy": accuracy_score,
    "F-beta Score": lambda y_true, y_pred: fbeta_score(y_true, y_pred, beta=1.5),
    "F1 Score": f1_score,
    "Recall": recall_score,
    "Precision": precision_score,
    "ROC AUC": roc_auc_score,
    "PR AUC": lambda y_true, y_pred: compute_pr_auc(y_true, y_pred)
}

tscv = TimeSeriesSplit(n_splits=5)

best_models_logistic_regression = []

class_distributions = {}
logistic_regression_baseline_metrics = {}
logistic_regression_means = {}
logistic_regression_stds = {}

# Function to consistently format metric names
def format_metric_name(metric_name):
    return re.sub(r'[^a-zA-Z0-9]+', '_', metric_name.lower())
    
# initialise scores dictionaries
scores_per_fold = {f"train_{format_metric_name(name)}": [] for name in metrics}
scores_per_fold.update({f"test_{format_metric_name(name)}": [] for name in metrics})
scores_per_fold.update({f"val_{format_metric_name(name)}": [] for name in metrics})  # Add validation scores

# data splitting, model training, & evaluation
for fold_idx, (train_index, test_index) in enumerate(tscv.split(X), start=1):
    # Split data into train and test sets
    X_train = X.iloc[train_index]
    Y_train = Y.iloc[train_index]
    X_test_full = X.iloc[test_index]
    Y_test_full = Y.iloc[test_index]

    # Split the test set into 10% validation and 10% test (chronologically)
    split_point = len(X_test_full) // 2
    X_val = X_test_full.iloc[:split_point]
    Y_val = Y_test_full.iloc[:split_point]
    
    X_test = X_test_full.iloc[split_point:]
    Y_test = Y_test_full.iloc[split_point:]

    print(f"\nFold {fold_idx}:")
    print(f"  Training set: X shape = {X_train.shape}, Y shape = {Y_train.shape}, Size = {X_train.shape[0]}")
    print(f"  Validation set:  X shape = {X_val.shape}, Y shape = {Y_val.shape}, Size = {X_val.shape[0]}")
    print(f"  Testing set:  X shape = {X_test.shape}, Y shape = {Y_test.shape}, Size = {X_test.shape[0]}")
    
    # Count class occurrences in Y_test
    class_counts = Y_test.value_counts()
    total = len(Y_test)
    majority_class = class_counts.idxmax()
    majority_class_count = class_counts.max()
    num_class_1 = class_counts.get(1, 0)
    num_class_0 = class_counts.get(0, 0)
    baseline_probs = [1 if majority_class == 1 else 0] * len(Y_test)
    precision_baseline, recall_baseline, _ = precision_recall_curve(Y_test, baseline_probs)

    # Debugging prints for class distribution
    print(f"\nFold {fold_idx} - Class Distribution in Test Set:")
    print(f"  Total samples: {total}")
    print(f"  Class Counts:\n{class_counts}")
    print(f"  Majority Class: {majority_class}")
    print(f"  Majority Class Count: {majority_class_count}")
    
   # Store class distribution
    class_distributions[fold_idx] = {
        "Class 0": num_class_0,
        "Class 1": num_class_1
    }

    # baseline metrics: predicting all points as class 1
    accuracy = majority_class_count / total
    precision = num_class_1 / (num_class_1 + num_class_0)
    recall = (num_class_1 / total) / (num_class_1/ total + 0)
    f1 = 2 * (precision * recall) / (precision + recall)
    f1_5 = (1 + 1.5**2) * (precision * recall) / ((1.5**2 * precision) + recall)
    roc_auc = roc_auc_score(Y_test, baseline_probs)
    pr_auc = auc(recall_baseline, precision_baseline)

    print("\nBaseline Metric Calculations:")
    print(f"  Accuracy: {accuracy}")
    print(f"  Precision: {precision}")
    print(f"  Recall: {recall}")
    print(f"  F1 Score: {f1}")
    print(f"  F1.5 Score: {f1_5}")
    print(f"  ROC AUC: {roc_auc}")
    print(f"  PR AUC: {pr_auc}")
    
    logistic_regression_baseline_metrics[fold_idx] = {
        "Accuracy": accuracy,
        "Precision": precision,
        "Recall": recall,
        "F1": f1,
        "F1.5": f1_5,
        "ROC AUC": roc_auc,
        "PR AUC": pr_auc
    }
    
    # pipeline
    pipeline = Pipeline([
        ('scaler', StandardScaler()),  
        ('model', LogisticRegression(class_weight='balanced', max_iter=1000, tol=1e-4, random_state=1))
    ])
    
    # GridSearchCV with tscv
    grid_search = GridSearchCV(
        estimator=pipeline,
        param_grid=param_grid,
        cv=tscv,
        scoring=f1_scorer,
        refit=True,  # refit best model on the full training data
        n_jobs=-1,  
        verbose=1
    )
    
    with warnings.catch_warnings():
        warnings.simplefilter("ignore")
        grid_search.fit(X_train, Y_train)

    print(X_train.dtypes)
    
    # Use the validation set to select the best model
    best_model_idx = np.argmax([grid_search.score(X_val, Y_val) for model in grid_search.cv_results_['params']])

    # find best parameters using X_train
    best_params = grid_search.best_params_
    best_model_logistic_regression = grid_search.best_estimator_
    print(f"Fold {fold_idx} -> Best Params: {best_params}")

    # Evaluate the best model on the validation set (X_val, Y_val)
    y_val_pred_probs = best_model_logistic_regression.predict_proba(X_val)[:, 1]
    y_val_pred = best_model_logistic_regression.predict(X_val)

    scaler = best_model_logistic_regression.named_steps['scaler']
    X_test_scaled = scaler.transform(X_test)

    if fold_idx == 5:
        with open('best_model_fold_5.pickle', 'wb') as file:
            pickle.dump((best_model_logistic_regression, X_test, Y_test), file)

        print("Best model and test data for fold 5 saved successfully.")

    # Create a SHAP explainer for the best model
    explainer = shap.Explainer(best_model_logistic_regression['model'], X_train)
    
    # Calculate SHAP values for the test set
    shap_values = explainer(X_test)
    
    # Plot SHAP summary for the fold
    shap.summary_plot(shap_values, X_test, show=False)

    plt.savefig(f"shap_summary_logistic_regression_{fold_idx}.png", bbox_inches='tight')
    plt.close()  # Close the plot to avoid overlapping in subsequent iterations
  
    #evalualte on X_train 
    y_train_pred = best_model_logistic_regression.predict(X_train)

    # Evaluate on X_test
    y_test_pred_probs = best_model_logistic_regression.predict_proba(X_test)[:, 1]
    y_test_pred = best_model_logistic_regression.predict(X_test)

    # predict probabilities (needed for PR AUC calculation)
    y_pred_probs = best_model_logistic_regression.predict_proba(X_test)[:, 1]  # Get probabilities for class 1
    
    # calculate PR AUC for the test set
    pr_auc_value = compute_pr_auc(Y_test, y_pred_probs)

    #generate confusion matrix for each fold
    cm = confusion_matrix(Y_test, y_test_pred, labels=[0, 1])
        
    # Plot confusion matrix
    plt.figure(figsize=(6, 5))
    sns.heatmap(cm, annot=True, fmt="d", cmap="Blues", xticklabels=[0, 1], yticklabels=[0, 1])
    plt.xlabel("Predicted")
    plt.ylabel("Actual")
    plt.title(f"Confusion Matrix for Logistic Regression - Fold {fold_idx}")

    #save as high-quality image
    plt.savefig(f"logistic_regression_{fold_idx}.png")
    
    plt.show()
    
    #for loop for calculating train & test metrics
    #print(f"Fold {fold_idx} metrics:")
    for name, func in metrics.items():
        formatted_name = format_metric_name(name)
    
        # Train metrics
        train_score = func(Y_train, y_train_pred)
        print(f"  Train {name}: {train_score:.4f}")
        scores_per_fold[f"train_{formatted_name}"].append(train_score)

        # Validation metrics
        val_score = func(Y_val, y_val_pred)
        print(f"  Validation {name}: {val_score:.4f}")
        scores_per_fold[f"val_{formatted_name}"].append(val_score)
        
        # Test metrics
        test_score = func(Y_test, y_test_pred)
        print(f"  Test {name}: {test_score:.4f}")
        scores_per_fold[f"test_{formatted_name}"].append(test_score)

# Calculate and save mean and std metrics
print("\nOverall Metrics:")
for metric_name in metrics:
    formatted_name = format_metric_name(metric_name)
    train_key = f"train_{formatted_name}"
    val_key = f"val_{formatted_name}"
    test_key = f"test_{formatted_name}"
    
    avg_train = np.mean(scores_per_fold[train_key])
    std_train = np.std(scores_per_fold[train_key], ddof=1)
    avg_val = np.mean(scores_per_fold[val_key])
    std_val = np.std(scores_per_fold[val_key], ddof=1)
    avg_test = np.mean(scores_per_fold[test_key])
    std_test = np.std(scores_per_fold[test_key], ddof=1)

    # Save to dictionaries for model comparison
    logistic_regression_means[f"logistic_regression_{formatted_name}_mean"] = {
        "train": avg_train,
        "val": avg_val,
        "test": avg_test
    }
    logistic_regression_stds[f"logistic_regression_{formatted_name}_std"] = {
        "train": std_train,
        "val": std_val,
        "test": std_test
    }
        
    print(f"{metric_name} - Train: Mean = {avg_train:.4f}, Std Dev = {std_train:.4f}")
    print(f"{metric_name} - Validation: Mean = {avg_val:.4f}, Std Dev = {std_val:.4f}")
    print(f"{metric_name} - Test: Mean = {avg_test:.4f}, Std Dev = {std_test:.4f}")

#print baselines at the end for each fold:
print("\nBaseline Metrics per Fold:")
for fold, metrics in logistic_regression_baseline_metrics.items():
    print(f"Fold {fold}: {metrics}")
# Out:
# Fold 1:
#   Training set: X shape = (90, 15), Y shape = (90,), Size = 90
#   Validation set:  X shape = (43, 15), Y shape = (43,), Size = 43
#   Testing set:  X shape = (44, 15), Y shape = (44,), Size = 44
#
# Fold 1 - Class Distribution in Test Set:
#   Total samples: 44
#   Class Counts:
# wildfire_frequency
# 0    39
# 1     5
# Name: count, dtype: int64
#   Majority Class: 0
#   Majority Class Count: 39
#
# Baseline Metric Calculations:
#   Accuracy: 0.8863636363636364
#   Precision: 0.11363636363636363
#   Recall: 1.0
#   F1 Score: 0.20408163265306123
#   F1.5 Score: 0.29411764705882354
#   ROC AUC: 0.5
#   PR AUC: 0.5568181818181818
# Fitting 5 folds for each of 168 candidates, totalling 840 fits
# month                    int32
# tmax_degC              float64
# airfrost_days            int64
# totalrain_mm           float64
# totalsun_hours         float64
# tmax_degC_lag_1        float64
# tmax_degC_lag_6        float64
# tmax_degC_lag_12       float64
# totalrain_mm_lag_1     float64
# totalrain_mm_lag_6     float64
# totalrain_mm_lag_12    float64
# totalrain_mm_avg4      float64
# tmax_degC_avg4         float64
# month_sin              float64
# month_cos              float64
# dtype: object
# Fold 1 -> Best Params: {'model__C': 0.1, 'model__penalty': 'l2', 'model__solver': 'saga'}
#   Train Accuracy: 0.8222
#   Validation Accuracy: 0.7674
#   Test Accuracy: 0.6818
#   Train F-beta Score: 0.5871
#   Validation F-beta Score: 0.2453
#   Test F-beta Score: 0.1461
#   Train F1 Score: 0.4667
#   Validation F1 Score: 0.1667
#   Test F1 Score: 0.1250
#   Train Recall: 1.0000
#   Validation Recall: 1.0000
#   Test Recall: 0.2000
#   Train Precision: 0.3043
#   Validation Precision: 0.0909
#   Test Precision: 0.0909
#   Train ROC AUC: 0.9036
#   Validation ROC AUC: 0.8810
#   Test ROC AUC: 0.4718
#   Train PR AUC: 0.6522
#   Validation PR AUC: 0.5455
#   Test PR AUC: 0.1909
#
# Fold 2:
#   Training set: X shape = (177, 15), Y shape = (177,), Size = 177
#   Validation set:  X shape = (43, 15), Y shape = (43,), Size = 43
#   Testing set:  X shape = (44, 15), Y shape = (44,), Size = 44
#
# Fold 2 - Class Distribution in Test Set:
#   Total samples: 44
#   Class Counts:
# wildfire_frequency
# 0    33
# 1    11
# Name: count, dtype: int64
#   Majority Class: 0
#   Majority Class Count: 33
#
# Baseline Metric Calculations:
#   Accuracy: 0.75
#   Precision: 0.25
#   Recall: 1.0
#   F1 Score: 0.4
#   F1.5 Score: 0.52
#   ROC AUC: 0.5
#   PR AUC: 0.625
# Fitting 5 folds for each of 168 candidates, totalling 840 fits
# month                    int32
# tmax_degC              float64
# airfrost_days            int64
# totalrain_mm           float64
# totalsun_hours         float64
# tmax_degC_lag_1        float64
# tmax_degC_lag_6        float64
# tmax_degC_lag_12       float64
# totalrain_mm_lag_1     float64
# totalrain_mm_lag_6     float64
# totalrain_mm_lag_12    float64
# totalrain_mm_avg4      float64
# tmax_degC_avg4         float64
# month_sin              float64
# month_cos              float64
# dtype: object
# Fold 2 -> Best Params: {'model__C': 0.15848931924611143, 'model__penalty': 'l2', 'model__solver': 'sag'}
#   Train Accuracy: 0.7966
#   Validation Accuracy: 0.7907
#   Test Accuracy: 0.8182
#   Train F-beta Score: 0.4815
#   Validation F-beta Score: 0.6555
#   Test F-beta Score: 0.6887
#   Train F1 Score: 0.3793
#   Validation F1 Score: 0.5714
#   Test F1 Score: 0.6667
#   Train Recall: 0.8462
#   Validation Recall: 0.8571
#   Test Recall: 0.7273
#   Train Precision: 0.2444
#   Validation Precision: 0.4286
#   Test Precision: 0.6154
#   Train ROC AUC: 0.8194
#   Validation ROC AUC: 0.8175
#   Test ROC AUC: 0.7879
#   Train PR AUC: 0.5509
#   Validation PR AUC: 0.6545
#   Test PR AUC: 0.7054
#
# Fold 3:
#   Training set: X shape = (264, 15), Y shape = (264,), Size = 264
#   Validation set:  X shape = (43, 15), Y shape = (43,), Size = 43
#   Testing set:  X shape = (44, 15), Y shape = (44,), Size = 44
#
# Fold 3 - Class Distribution in Test Set:
#   Total samples: 44
#   Class Counts:
# wildfire_frequency
# 0    34
# 1    10
# Name: count, dtype: int64
#   Majority Class: 0
#   Majority Class Count: 34
#
# Baseline Metric Calculations:
#   Accuracy: 0.7727272727272727
#   Precision: 0.22727272727272727
#   Recall: 1.0
#   F1 Score: 0.37037037037037035
#   F1.5 Score: 0.4887218045112782
#   ROC AUC: 0.5
#   PR AUC: 0.6136363636363636
# Fitting 5 folds for each of 168 candidates, totalling 840 fits
# month                    int32
# tmax_degC              float64
# airfrost_days            int64
# totalrain_mm           float64
# totalsun_hours         float64
# tmax_degC_lag_1        float64
# tmax_degC_lag_6        float64
# tmax_degC_lag_12       float64
# totalrain_mm_lag_1     float64
# totalrain_mm_lag_6     float64
# totalrain_mm_lag_12    float64
# totalrain_mm_avg4      float64
# tmax_degC_avg4         float64
# month_sin              float64
# month_cos              float64
# dtype: object
# Fold 3 -> Best Params: {'model__C': 0.6309573444801934, 'model__penalty': 'l2', 'model__solver': 'lbfgs'}
#   Train Accuracy: 0.7652
#   Validation Accuracy: 0.8140
#   Test Accuracy: 0.6818
#   Train F-beta Score: 0.5670
#   Validation F-beta Score: 0.6783
#   Test F-beta Score: 0.5617
#   Train F1 Score: 0.4655
#   Validation F1 Score: 0.6000
#   Test F1 Score: 0.5000
#   Train Recall: 0.8710
#   Validation Recall: 0.8571
#   Test Recall: 0.7000
#   Train Precision: 0.3176
#   Validation Precision: 0.4615
#   Test Precision: 0.3889
#   Train ROC AUC: 0.8110
#   Validation ROC AUC: 0.8313
#   Test ROC AUC: 0.6882
#   Train PR AUC: 0.6019
#   Validation PR AUC: 0.6710
#   Test PR AUC: 0.5785
#
# Fold 4:
#   Training set: X shape = (351, 15), Y shape = (351,), Size = 351
#   Validation set:  X shape = (43, 15), Y shape = (43,), Size = 43
#   Testing set:  X shape = (44, 15), Y shape = (44,), Size = 44
#
# Fold 4 - Class Distribution in Test Set:
#   Total samples: 44
#   Class Counts:
# wildfire_frequency
# 0    32
# 1    12
# Name: count, dtype: int64
#   Majority Class: 0
#   Majority Class Count: 32
#
# Baseline Metric Calculations:
#   Accuracy: 0.7272727272727273
#   Precision: 0.2727272727272727
#   Recall: 1.0
#   F1 Score: 0.42857142857142855
#   F1.5 Score: 0.5492957746478873
#   ROC AUC: 0.5
#   PR AUC: 0.6363636363636364
# Fitting 5 folds for each of 168 candidates, totalling 840 fits
# month                    int32
# tmax_degC              float64
# airfrost_days            int64
# totalrain_mm           float64
# totalsun_hours         float64
# tmax_degC_lag_1        float64
# tmax_degC_lag_6        float64
# tmax_degC_lag_12       float64
# totalrain_mm_lag_1     float64
# totalrain_mm_lag_6     float64
# totalrain_mm_lag_12    float64
# totalrain_mm_avg4      float64
# tmax_degC_avg4         float64
# month_sin              float64
# month_cos              float64
# dtype: object
# Fold 4 -> Best Params: {'model__C': 39.810717055349734, 'model__penalty': 'l2', 'model__solver': 'saga'}
#   Train Accuracy: 0.7635
#   Validation Accuracy: 0.7907
#   Test Accuracy: 0.7273
#   Train F-beta Score: 0.5735
#   Validation F-beta Score: 0.6303
#   Test F-beta Score: 0.6047
#   Train F1 Score: 0.4845
#   Validation F1 Score: 0.6400
#   Test F1 Score: 0.5714
#   Train Recall: 0.8125
#   Validation Recall: 0.6154
#   Test Recall: 0.6667
#   Train Precision: 0.3451
#   Validation Precision: 0.6667
#   Test Precision: 0.5000
#   Train ROC AUC: 0.7841
#   Validation ROC AUC: 0.7410
#   Test ROC AUC: 0.7083
#   Train PR AUC: 0.5916
#   Validation PR AUC: 0.6992
#   Test PR AUC: 0.6288
#
# Fold 5:
#   Training set: X shape = (438, 15), Y shape = (438,), Size = 438
#   Validation set:  X shape = (43, 15), Y shape = (43,), Size = 43
#   Testing set:  X shape = (44, 15), Y shape = (44,), Size = 44
#
# Fold 5 - Class Distribution in Test Set:
#   Total samples: 44
#   Class Counts:
# wildfire_frequency
# 0    27
# 1    17
# Name: count, dtype: int64
#   Majority Class: 0
#   Majority Class Count: 27
#
# Baseline Metric Calculations:
#   Accuracy: 0.6136363636363636
#   Precision: 0.38636363636363635
#   Recall: 1.0
#   F1 Score: 0.5573770491803279
#   F1.5 Score: 0.6717325227963526
#   ROC AUC: 0.5
#   PR AUC: 0.6931818181818181
# Fitting 5 folds for each of 168 candidates, totalling 840 fits
# month                    int32
# tmax_degC              float64
# airfrost_days            int64
# totalrain_mm           float64
# totalsun_hours         float64
# tmax_degC_lag_1        float64
# tmax_degC_lag_6        float64
# tmax_degC_lag_12       float64
# totalrain_mm_lag_1     float64
# totalrain_mm_lag_6     float64
# totalrain_mm_lag_12    float64
# totalrain_mm_avg4      float64
# tmax_degC_avg4         float64
# month_sin              float64
# month_cos              float64
# dtype: object
# Fold 5 -> Best Params: {'model__C': 1.584893192461114, 'model__penalty': 'l2', 'model__solver': 'saga'}
# Best model and test data for fold 5 saved successfully.
#   Train Accuracy: 0.7580
#   Validation Accuracy: 0.7442
#   Test Accuracy: 0.6364
#   Train F-beta Score: 0.6018
#   Validation F-beta Score: 0.6797
#   Test F-beta Score: 0.6367
#   Train F1 Score: 0.5225
#   Validation F1 Score: 0.5926
#   Test F1 Score: 0.6000
#   Train Recall: 0.7945
#   Validation Recall: 0.8889
#   Test Recall: 0.7059
#   Train Precision: 0.3893
#   Validation Precision: 0.4444
#   Test Precision: 0.5217
#   Train ROC AUC: 0.7726
#   Validation ROC AUC: 0.7974
#   Test ROC AUC: 0.6492
#   Train PR AUC: 0.6090
#   Validation PR AUC: 0.6783
#   Test PR AUC: 0.6706
#
# Overall Metrics:
# Accuracy - Train: Mean = 0.7811, Std Dev = 0.0275
# Accuracy - Validation: Mean = 0.7814, Std Dev = 0.0265
# Accuracy - Test: Mean = 0.7091, Std Dev = 0.0689
# F-beta Score - Train: Mean = 0.5622, Std Dev = 0.0470
# F-beta Score - Validation: Mean = 0.5778, Std Dev = 0.1870
# F-beta Score - Test: Mean = 0.5276, Std Dev = 0.2183
# F1 Score - Train: Mean = 0.4637, Std Dev = 0.0525
# F1 Score - Validation: Mean = 0.5141, Std Dev = 0.1958
# F1 Score - Test: Mean = 0.4926, Std Dev = 0.2140
# Recall - Train: Mean = 0.8648, Std Dev = 0.0811
# Recall - Validation: Mean = 0.8437, Std Dev = 0.1405
# Recall - Test: Mean = 0.6000, Std Dev = 0.2246
# Precision - Train: Mean = 0.3202, Std Dev = 0.0534
# Precision - Validation: Mean = 0.4184, Std Dev = 0.2071
# Precision - Test: Mean = 0.4234, Std Dev = 0.2026
# ROC AUC - Train: Mean = 0.8182, Std Dev = 0.0514
# ROC AUC - Validation: Mean = 0.8136, Std Dev = 0.0510
# ROC AUC - Test: Mean = 0.6611, Std Dev = 0.1173
# PR AUC - Train: Mean = 0.6011, Std Dev = 0.0363
# PR AUC - Validation: Mean = 0.6497, Std Dev = 0.0604
# PR AUC - Test: Mean = 0.5549, Std Dev = 0.2089
#
# Baseline Metrics per Fold:
# Fold 1: {'Accuracy': 0.8863636363636364, 'Precision': 0.11363636363636363, 'Recall': 1.0, 'F1': 0.20408163265306123, 'F1.5': 0.29411764705882354, 'ROC AUC': 0.5, 'PR AUC': 0.5568181818181818}
# Fold 2: {'Accuracy': 0.75, 'Precision': 0.25, 'Recall': 1.0, 'F1': 0.4, 'F1.5': 0.52, 'ROC AUC': 0.5, 'PR AUC': 0.625}
# Fold 3: {'Accuracy': 0.7727272727272727, 'Precision': 0.22727272727272727, 'Recall': 1.0, 'F1': 0.37037037037037035, 'F1.5': 0.4887218045112782, 'ROC AUC': 0.5, 'PR AUC': 0.6136363636363636}
# Fold 4: {'Accuracy': 0.7272727272727273, 'Precision': 0.2727272727272727, 'Recall': 1.0, 'F1': 0.42857142857142855, 'F1.5': 0.5492957746478873, 'ROC AUC': 0.5, 'PR AUC': 0.6363636363636364}
# Fold 5: {'Accuracy': 0.6136363636363636, 'Precision': 0.38636363636363635, 'Recall': 1.0, 'F1': 0.5573770491803279, 'F1.5': 0.6717325227963526, 'ROC AUC': 0.5, 'PR AUC': 0.6931818181818181}

# %%
import pickle
file = open('best_model_fold_5.pickle', 'rb')
model, X_test_scaled, y_test_scaled = pickle.load(file)
file.close()

np.random.seed(42)

nr_runs = 10
scores = np.zeros([len(feature_names),nr_runs])

y_pred_baseline = model.predict(X_test_scaled)
test_score = f1_score(y_test_scaled, y_pred_baseline)
print(test_score)
print('test baseline = ',np.sum(y_test_scaled == 1)/len(y_test_scaled))

for i in range(len(feature_names)):
    print('Shuffling feature: ' + str(feature_names[i]))
    f1_scores = []
    for j in range(nr_runs):
        X_test_shuffled = X_test_scaled.copy()
        X_test_shuffled[feature_names[i]] = np.random.permutation(X_test[feature_names[i]].values)
        
        # Predict and compute the F1 score
        y_pred = model.predict(X_test_shuffled)
        f1 = f1_score(y_test, y_pred)
        f1_scores.append(f1)
    
    # Print the mean and standard deviation of F1 scores
    print(f'   Shuffled test F1 score: {np.mean(f1_scores):.3f} +/- {np.std(f1_scores):.3f}')
    scores[i] = f1_scores
# Out:
# 0.6
# test baseline =  0.38636363636363635
# Shuffling feature: month
#    Shuffled test F1 score: 0.567 +/- 0.006
# Shuffling feature: tmax_degC
#    Shuffled test F1 score: 0.515 +/- 0.045
# Shuffling feature: airfrost_days
#    Shuffled test F1 score: 0.616 +/- 0.025
# Shuffling feature: totalrain_mm
#    Shuffled test F1 score: 0.589 +/- 0.018
# Shuffling feature: totalsun_hours
#    Shuffled test F1 score: 0.518 +/- 0.077
# Shuffling feature: tmax_degC_lag_1
#    Shuffled test F1 score: 0.559 +/- 0.015
# Shuffling feature: tmax_degC_lag_6
#    Shuffled test F1 score: 0.499 +/- 0.037
# Shuffling feature: tmax_degC_lag_12
#    Shuffled test F1 score: 0.452 +/- 0.098
# Shuffling feature: totalrain_mm_lag_1
#    Shuffled test F1 score: 0.599 +/- 0.017
# Shuffling feature: totalrain_mm_lag_6
#    Shuffled test F1 score: 0.595 +/- 0.019
# Shuffling feature: totalrain_mm_lag_12
#    Shuffled test F1 score: 0.558 +/- 0.024
# Shuffling feature: totalrain_mm_avg4
#    Shuffled test F1 score: 0.567 +/- 0.025
# Shuffling feature: tmax_degC_avg4
#    Shuffled test F1 score: 0.662 +/- 0.037
# Shuffling feature: month_sin
#    Shuffled test F1 score: 0.396 +/- 0.100
# Shuffling feature: month_cos
#    Shuffled test F1 score: 0.570 +/- 0.029

# %%
# Sort the features based on the mean F1 score (in descending order)
sorted_indcs = np.argsort(np.mean(scores, axis=1))[::-1]  # Sort by mean F1 score in descending order
sorted_scores = scores[sorted_indcs]  # Sorted F1 scores based on feature importance
sorted_feature_names = np.array(X_test.columns)[sorted_indcs]  # Sorted feature names based on importance

# Plotting boxplot with sorted indices
plt.rcParams.update({'font.size': 10})
plt.figure(figsize=(5, 3))

plt.boxplot(sorted_scores.T, labels=sorted_feature_names, vert=False)

# Add a vertical line for the baseline test score
plt.axvline(test_score, color='red', linestyle='--', label='Test Score')

# Add title and labels
plt.title("Permutation Importances (Test Set)")
plt.xlabel("F1 Score with Perturbed Feature")
plt.legend()

# Adjust layout and show the plot
plt.tight_layout()

plt.savefig('permutation_importances.png')

plt.show()
# Out:
# C:\Users\miaox\AppData\Local\Temp\ipykernel_19204\2301918177.py:10: MatplotlibDeprecationWarning: The 'labels' parameter of boxplot() has been renamed 'tick_labels' since Matplotlib 3.9; support for the old name will be dropped in 3.11.
#   plt.boxplot(sorted_scores.T, labels=sorted_feature_names, vert=False)

# %%
#local feature importance

# %%
# load best model and the test set for fold 5
with open('best_model_fold_5.pickle', 'rb') as file:
    model, X_test_scaled, Y_test_scaled = pickle.load(file)

# Logistic Regression inside pipeline
best_model_logistic_regression = model['model']

# SHAP explainer for the best model
explainer = shap.Explainer(best_model_logistic_regression, X_test_scaled)

# calculate SHAP values for the entire test set
shap_values = explainer(X_test_scaled)

# choosing index in X_test
index = 1
shap_values_for_index = shap_values[index]

# plot SHAP values for the specific instance
shap.initjs()

plt.figure(figsize=(30, 8))

shap.force_plot(shap_values_for_index.base_values, shap_values_for_index.values, X_test_scaled.iloc[index], matplotlib=True)
#plt.savefig(f"shap_force_plot_instance_{index}_fold_5.png", bbox_inches='tight')

plt.close()
# Out:
# <div align='center'><img src='data:image/png;base64,...' /></div><script charset='utf-8'>/*! For license information please see bundle.js.LICENSE.txt */
# (()=>{var e={486:function(e,t,n){var r;e=n.nmd(e),function(){var a,i="Expected a function",o="__lodash_hash_undefined__",u="__lodash_placeholder__",l=32,s=128,c=1/0,f=9007199254740991,p=NaN,d=4294967295,h=[["ary",s],["bind",1],["bindKey",2],["curry",8],["curryRight",16],["flip",512],["partial",l],["partialRight",64],["rearg",256]],v="[object Arguments]",g="[object Array]",y="[object Boolean]",m="[object Date]",b="[object Error]",_="[object Function]",w="[object GeneratorFunction]",x="[object Map]",k="[object Number]",S="[object Object]",E="[object Promise]",C="[object RegExp]",T="[object Set]",M="[object String]",N="[object Symbol]",P="[object WeakMap]",z="[object ArrayBuffer]",L="[object DataView]",O="[object Float32Array]",A="[object Float64Array]",F="[object Int8Array]",D="[object Int16Array]",R="[object Int32Array]",j="[object Uint8Array]",U="[object Uint8ClampedArray]",I="[object Uint16Array]",$="[object Uint32Array]",B=/\b__p \+= '';/g,W=/\b(__p \+=) '' \+/g,V=/(__e\(.*?\)|\b__t\)) \+\n'';/g,H=/&(?:amp|lt|gt|quot|#39);/g,q=/[&<>"']/g,Q=RegExp(H.source),Y=RegExp(q.source),G=/<%-([\s\S]+?)%>/g,K=/<%([\s\S]+?)%>/g,Z=/<%=([\s\S]+?)%>/g,X=/\.|\[(?:[^[\]]*|(["'])(?:(?!\1)[^\\]|\\.)*?\1)\]/,J=/^\w*$/,ee=/[^.[\]]+|\[(?:(-?\d+(?:\.\d+)?)|(["'])((?:(?!\2)[^\\]|\\.)*?)\2)\]|(?=(?:\.|\[\])(?:\.|\[\]|$))/g,te=/[\\^$.*+?()[\]{}|]/g,ne=RegExp(te.source),re=/^\s+/,ae=/\s/,ie=/\{(?:\n\/\* \[wrapped with .+\] \*\/)?\n?/,oe=/\{\n\/\* \[wrapped with (.+)\] \*/,ue=/,? & /,le=/[^\x00-\x2f\x3a-\x40\x5b-\x60\x7b-\x7f]+/g,se=/[()=,{}\[\]\/\s]/,ce=/\\(\\)?/g,fe=/\$\{([^\\}]*(?:\\.[^\\}]*)*)\}/g,pe=/\w*$/,de=/^[-+]0x[0-9a-f]+$/i,he=/^0b[01]+$/i,ve=/^\[object .+?Constructor\]$/,ge=/^0o[0-7]+$/i,ye=/^(?:0|[1-9]\d*)$/,me=/[\xc0-\xd6\xd8-\xf6\xf8-\xff\u0100-\u017f]/g,be=/($^)/,_e=/['\n\r\u2028\u2029\\]/g,we="\\ud800-\\udfff",xe="\\u0300-\\u036f\\ufe20-\\ufe2f\\u20d0-\\u20ff",ke="\\u2700-\\u27bf",Se="a-z\\xdf-\\xf6\\xf8-\\xff",Ee="A-Z\\xc0-\\xd6\\xd8-\\xde",Ce="\\ufe0e\\ufe0f",Te="\\xac\\xb1\\xd7\\xf7\\x00-\\x2f\\x3a-\\x40\\x5b-\\x60\\x7b-\\xbf\\u2000-\\u206f \\t\\x0b\\f\\xa0\\ufeff\\n\\r\\u2028\\u2029\\u1680\\u180e\\u2000\\u2001\\u2002\\u2003\\u2004\\u2005\\u2006\\u2007\\u2008\\u2009\\u200a\\u202f\\u205f\\u3000",Me="["+we+"]",Ne="["+Te+"]",Pe="["+xe+"]",ze="\\d+",Le="["+ke+"]",Oe="["+Se+"]",Ae="[^"+we+Te+ze+ke+Se+Ee+"]",Fe="\\ud83c[\\udffb-\\udfff]",De="[^"+we+"]",Re="(?:\\ud83c[\\udde6-\\uddff]){2}",je="[\\ud800-\\udbff][\\udc00-\\udfff]",Ue="["+Ee+"]",Ie="\\u200d",$e="(?:"+Oe+"|"+Ae+")",Be="(?:"+Ue+"|"+Ae+")",We="(?:['’](?:d|ll|m|re|s|t|ve))?",Ve="(?:['’](?:D|LL|M|RE|S|T|VE))?",He="(?:"+Pe+"|"+Fe+")?",qe="["+Ce+"]?",Qe=qe+He+"(?:"+Ie+"(?:"+[De,Re,je].join("|")+")"+qe+He+")*",Ye="(?:"+[Le,Re,je].join("|")+")"+Qe,Ge="(?:"+[De+Pe+"?",Pe,Re,je,Me].join("|")+")",Ke=RegExp("['’]","g"),Ze=RegExp(Pe,"g"),Xe=RegExp(Fe+"(?="+Fe+")|"+Ge+Qe,"g"),Je=RegExp([Ue+"?"+Oe+"+"+We+"(?="+[Ne,Ue,"$"].join("|")+")",Be+"+"+Ve+"(?="+[Ne,Ue+$e,"$"].join("|")+")",Ue+"?"+$e+"+"+We,Ue+"+"+Ve,"\\d*(?:1ST|2ND|3RD|(?![123])\\dTH)(?=\\b|[a-z_])","\\d*(?:1st|2nd|3rd|(?![123])\\dth)(?=\\b|[A-Z_])",ze,Ye].join("|"),"g"),et=RegExp("["+Ie+we+xe+Ce+"]"),tt=/[a-z][A-Z]|[A-Z]{2}[a-z]|[0-9][a-zA-Z]|[a-zA-Z][0-9]|[^a-zA-Z0-9 ]/,nt=["Array","Buffer","DataView","Date","Error","Float32Array","Float64Array","Function","Int8Array","Int16Array","Int32Array","Map","Math","Object","Promise","RegExp","Set","String","Symbol","TypeError","Uint8Array","Uint8ClampedArray","Uint16Array","Uint32Array","WeakMap","_","clearTimeout","isFinite","parseInt","setTimeout"],rt=-1,at={};at[O]=at[A]=at[F]=at[D]=at[R]=at[j]=at[U]=at[I]=at[$]=!0,at[v]=at[g]=at[z]=at[y]=at[L]=at[m]=at[b]=at[_]=at[x]=at[k]=at[S]=at[C]=at[T]=at[M]=at[P]=!1;var it={};it[v]=it[g]=it[z]=it[L]=it[y]=it[m]=it[O]=it[A]=it[F]=it[D]=it[R]=it[x]=it[k]=it[S]=it[C]=it[T]=it[M]=it[N]=it[j]=it[U]=it[I]=it[$]=!0,it[b]=it[_]=it[P]=!1;var ot={"\\":"\\","'":"'","\n":"n","\r":"r","\u2028":"u2028","\u2029":"u2029"},ut=parseFloat,lt=parseInt,st="object"==typ ...

# %%
# Initialize JavaScript for SHAP visualizations
shap.initjs()

# Load the best model and the test set for fold 5
with open('best_model_fold_5.pickle', 'rb') as file:
    model, X_test_scaled, Y_test_scaled = pickle.load(file)

print(f"X_test shape: {np.shape(X_test_scaled)}")

# Create the SHAP explainer object with the model and transformed X_test
# Using the correct explainer based on the model type
explainer = shap.KernelExplainer(model.predict_proba, X_test_scaled)

# Calculate SHAP values on the test set
shap_values = explainer.shap_values(X_test_scaled)
print(f"SHAP values shape: {np.shape(shap_values)}")

# Plot SHAP summary for fold 5 (global explanation)
shap.summary_plot(shap_values[1], X_test_scaled, show=False)
plt.savefig(f"shap_summary_logistic_regression_fold_5.png", bbox_inches='tight')
plt.close()

# If you want to calculate SHAP values for a specific index (e.g., index 1 in the test set)
index = 1  # Change this to the desired index in the test set
shap_values_for_index = shap_values[1][index]

# Print the structure of SHAP values for this index to debug
print(f"SHAP values for index {index}: {shap_values_for_index}")

# Calculate the log-odds for the instance by adding the base log-odds (expected_value) and the SHAP values
log_odds_class_1 = explainer.expected_value[1] + np.sum(shap_values_for_index)  # Sum of SHAP values + expected_value

# Convert log-odds to probability using the sigmoid function
probability_class_1 = 1 / (1 + np.exp(-log_odds_class_1))
print(f"Probability for class 1 (after converting log-odds): {probability_class_1}")

# Plot SHAP values for the specific instance
plt.figure(figsize=(30, 8))  # Change width and height as needed

# For binary classification:
# The explainer.expected_value[1] is the expected value for class 1 (log-odds)
# We use shap_values_for_index for the contributions of each feature.

shap.force_plot(
    explainer.expected_value[1],  # Expected value for class 1 (log-odds)
    shap_values_for_index,  # SHAP values for the features
    X_test_scaled.iloc[index],  # Features for the specific index (transformed)
    matplotlib=True  # Use matplotlib to render the plot
)

plt.close()
# Out:
# <div align='center'><img src='data:image/png;base64,...' /></div><script charset='utf-8'>/*! For license information please see bundle.js.LICENSE.txt */
# (()=>{var e={486:function(e,t,n){var r;e=n.nmd(e),function(){var a,i="Expected a function",o="__lodash_hash_undefined__",u="__lodash_placeholder__",l=32,s=128,c=1/0,f=9007199254740991,p=NaN,d=4294967295,h=[["ary",s],["bind",1],["bindKey",2],["curry",8],["curryRight",16],["flip",512],["partial",l],["partialRight",64],["rearg",256]],v="[object Arguments]",g="[object Array]",y="[object Boolean]",m="[object Date]",b="[object Error]",_="[object Function]",w="[object GeneratorFunction]",x="[object Map]",k="[object Number]",S="[object Object]",E="[object Promise]",C="[object RegExp]",T="[object Set]",M="[object String]",N="[object Symbol]",P="[object WeakMap]",z="[object ArrayBuffer]",L="[object DataView]",O="[object Float32Array]",A="[object Float64Array]",F="[object Int8Array]",D="[object Int16Array]",R="[object Int32Array]",j="[object Uint8Array]",U="[object Uint8ClampedArray]",I="[object Uint16Array]",$="[object Uint32Array]",B=/\b__p \+= '';/g,W=/\b(__p \+=) '' \+/g,V=/(__e\(.*?\)|\b__t\)) \+\n'';/g,H=/&(?:amp|lt|gt|quot|#39);/g,q=/[&<>"']/g,Q=RegExp(H.source),Y=RegExp(q.source),G=/<%-([\s\S]+?)%>/g,K=/<%([\s\S]+?)%>/g,Z=/<%=([\s\S]+?)%>/g,X=/\.|\[(?:[^[\]]*|(["'])(?:(?!\1)[^\\]|\\.)*?\1)\]/,J=/^\w*$/,ee=/[^.[\]]+|\[(?:(-?\d+(?:\.\d+)?)|(["'])((?:(?!\2)[^\\]|\\.)*?)\2)\]|(?=(?:\.|\[\])(?:\.|\[\]|$))/g,te=/[\\^$.*+?()[\]{}|]/g,ne=RegExp(te.source),re=/^\s+/,ae=/\s/,ie=/\{(?:\n\/\* \[wrapped with .+\] \*\/)?\n?/,oe=/\{\n\/\* \[wrapped with (.+)\] \*/,ue=/,? & /,le=/[^\x00-\x2f\x3a-\x40\x5b-\x60\x7b-\x7f]+/g,se=/[()=,{}\[\]\/\s]/,ce=/\\(\\)?/g,fe=/\$\{([^\\}]*(?:\\.[^\\}]*)*)\}/g,pe=/\w*$/,de=/^[-+]0x[0-9a-f]+$/i,he=/^0b[01]+$/i,ve=/^\[object .+?Constructor\]$/,ge=/^0o[0-7]+$/i,ye=/^(?:0|[1-9]\d*)$/,me=/[\xc0-\xd6\xd8-\xf6\xf8-\xff\u0100-\u017f]/g,be=/($^)/,_e=/['\n\r\u2028\u2029\\]/g,we="\\ud800-\\udfff",xe="\\u0300-\\u036f\\ufe20-\\ufe2f\\u20d0-\\u20ff",ke="\\u2700-\\u27bf",Se="a-z\\xdf-\\xf6\\xf8-\\xff",Ee="A-Z\\xc0-\\xd6\\xd8-\\xde",Ce="\\ufe0e\\ufe0f",Te="\\xac\\xb1\\xd7\\xf7\\x00-\\x2f\\x3a-\\x40\\x5b-\\x60\\x7b-\\xbf\\u2000-\\u206f \\t\\x0b\\f\\xa0\\ufeff\\n\\r\\u2028\\u2029\\u1680\\u180e\\u2000\\u2001\\u2002\\u2003\\u2004\\u2005\\u2006\\u2007\\u2008\\u2009\\u200a\\u202f\\u205f\\u3000",Me="["+we+"]",Ne="["+Te+"]",Pe="["+xe+"]",ze="\\d+",Le="["+ke+"]",Oe="["+Se+"]",Ae="[^"+we+Te+ze+ke+Se+Ee+"]",Fe="\\ud83c[\\udffb-\\udfff]",De="[^"+we+"]",Re="(?:\\ud83c[\\udde6-\\uddff]){2}",je="[\\ud800-\\udbff][\\udc00-\\udfff]",Ue="["+Ee+"]",Ie="\\u200d",$e="(?:"+Oe+"|"+Ae+")",Be="(?:"+Ue+"|"+Ae+")",We="(?:['’](?:d|ll|m|re|s|t|ve))?",Ve="(?:['’](?:D|LL|M|RE|S|T|VE))?",He="(?:"+Pe+"|"+Fe+")?",qe="["+Ce+"]?",Qe=qe+He+"(?:"+Ie+"(?:"+[De,Re,je].join("|")+")"+qe+He+")*",Ye="(?:"+[Le,Re,je].join("|")+")"+Qe,Ge="(?:"+[De+Pe+"?",Pe,Re,je,Me].join("|")+")",Ke=RegExp("['’]","g"),Ze=RegExp(Pe,"g"),Xe=RegExp(Fe+"(?="+Fe+")|"+Ge+Qe,"g"),Je=RegExp([Ue+"?"+Oe+"+"+We+"(?="+[Ne,Ue,"$"].join("|")+")",Be+"+"+Ve+"(?="+[Ne,Ue+$e,"$"].join("|")+")",Ue+"?"+$e+"+"+We,Ue+"+"+Ve,"\\d*(?:1ST|2ND|3RD|(?![123])\\dTH)(?=\\b|[a-z_])","\\d*(?:1st|2nd|3rd|(?![123])\\dth)(?=\\b|[A-Z_])",ze,Ye].join("|"),"g"),et=RegExp("["+Ie+we+xe+Ce+"]"),tt=/[a-z][A-Z]|[A-Z]{2}[a-z]|[0-9][a-zA-Z]|[a-zA-Z][0-9]|[^a-zA-Z0-9 ]/,nt=["Array","Buffer","DataView","Date","Error","Float32Array","Float64Array","Function","Int8Array","Int16Array","Int32Array","Map","Math","Object","Promise","RegExp","Set","String","Symbol","TypeError","Uint8Array","Uint8ClampedArray","Uint16Array","Uint32Array","WeakMap","_","clearTimeout","isFinite","parseInt","setTimeout"],rt=-1,at={};at[O]=at[A]=at[F]=at[D]=at[R]=at[j]=at[U]=at[I]=at[$]=!0,at[v]=at[g]=at[z]=at[y]=at[L]=at[m]=at[b]=at[_]=at[x]=at[k]=at[S]=at[C]=at[T]=at[M]=at[P]=!1;var it={};it[v]=it[g]=it[z]=it[L]=it[y]=it[m]=it[O]=it[A]=it[F]=it[D]=it[R]=it[x]=it[k]=it[S]=it[C]=it[T]=it[M]=it[N]=it[j]=it[U]=it[I]=it[$]=!0,it[b]=it[_]=it[P]=!1;var ot={"\\":"\\","'":"'","\n":"n","\r":"r","\u2028":"u2028","\u2029":"u2029"},ut=parseFloat,lt=parseInt,st="object"==typ ...
# X_test shape: (44, 15)
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[939], line 12
#       8 print(f"X_test shape: {np.shape(X_test_scaled)}")
#      10 # Create the SHAP explainer object with the model and transformed X_test
#      11 # Using the correct explainer based on the model type
# ---> 12 explainer = shap.KernelExplainer(model.predict_proba, X_test_scaled)
#      14 # Calculate SHAP values on the test set
#      15 shap_values = explainer.shap_values(X_test_scaled)
#
# File ~\.anaconda\envs\data1030\Lib\site-packages\shap\explainers\_kernel.py:95, in KernelExplainer.__init__(self, model, data, feature_names, link, **kwargs)
#      93 self.keep_index = kwargs.get("keep_index", False)
#      94 self.keep_index_ordered = kwargs.get("keep_index_ordered", False)
# ---> 95 self.model = convert_to_model(model, keep_index=self.keep_index)
#      96 self.data = convert_to_data(data, keep_index=self.keep_index)
#      97 model_null = match_model_to_data(self.model, self.data)
#
# File ~\.anaconda\envs\data1030\Lib\site-packages\shap\utils\_legacy.py:126, in convert_to_model(val, keep_index)
#     123     if f_self and hasattr(f_self, "feature_names_in_"):
#     124         # Make a copy so that the feature names are not removed from the original model
#     125         out = copy.deepcopy(out)
# --> 126         out.f.__self__.feature_names_in_ = None
#     128 return out
#
# AttributeError: property 'feature_names_in_' of 'Pipeline' object has no setter
